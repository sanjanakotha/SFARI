# %%
import pandas as pd
import glob
import numpy as np
import protfasta

# %% [markdown]
# ## Summary of counts:
# - Patient variants
# - AlphaMissense 10 most + least pathogenic variants per AD
# - All gnomAD variants in AD
# - All Clinvar variants in AD

# %% [markdown]
# ### Patient variants

# %%
# Loading in the AD names
variant_fasta_filepaths = glob.glob('../output/caitlin_experiment/variant fastas/*')
ADs = pd.DataFrame({"filepath" : variant_fasta_filepaths})
ADs["gene"] = ADs["filepath"].str.split("fastas/").str[1].str.split("_").str[0]
ADs["uniprotID"] = ADs["filepath"].str.split("_").str[2]
ADs["start"] = ADs["filepath"].str.split("_AD_").str[1].str.split("-").str[0].astype(int)
ADs["end"] = ADs["filepath"].str.split("_AD_").str[1].str.split("-").str[1].str.split("_").str[0].astype(int)
ADs["name"] = ADs["filepath"].str.split("/").str[-1].str.split("_seq_adj").str[0]
ADs
# Out:
#                                              filepath    gene uniprotID  \
# 0   ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 1   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 2   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 3   ../output/caitlin_experiment/variant fastas/OT...    OTX1    P32242
# 4   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 5   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 6   ../output/caitlin_experiment/variant fastas/IK...   IKZF1    Q13422
# 7   ../output/caitlin_experiment/variant fastas/NK...  NKX2-2    O95096
# 8   ../output/caitlin_experiment/variant fastas/PA...    PAX6    P26367
# 9   ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 10  ../output/caitlin_experiment/variant fastas/ME...   MEIS2    O14770
# 11  ../output/caitlin_experiment/variant fastas/PI...   PITX1    P78337
# 12  ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 13  ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 14  ../output/caitlin_experiment/variant fastas/PA...    PAX5    Q02548
#
#     start   end                       name
# 0     118   261      ERG_P11308_AD_118-261
# 1     840  1011   NCOA1_Q15788_AD_840-1011
# 2     472   581   CAMTA2_O94983_AD_472-581
# 3     172   354     OTX1_P32242_AD_172-354
# 4    1241  1385  NCOA1_Q15788_AD_1241-1385
# 5     285   468   CAMTA2_O94983_AD_285-468
# 6     284   365    IKZF1_Q13422_AD_284-365
# 7     220   273   NKX2-2_O95096_AD_220-273
# 8     271   422     PAX6_P26367_AD_271-422
# 9     584   598    NR4A2_P43354_AD_584-598
# 10    340   477    MEIS2_O14770_AD_340-477
# 11    234   283    PITX1_P78337_AD_234-283
# 12    433   479      ERG_P11308_AD_433-479
# 13      1    91       NR4A2_P43354_AD_1-91
# 14    304   358     PAX5_Q02548_AD_304-358

# %%
patient_variant_counts = []
for AD in ADs["name"]:
    patient_variant_counts.append(len(protfasta.read_fasta("../soto_analysis/outputs/AD_variant_fasta/" + AD)))
ADs["patient"] = patient_variant_counts
ADs
# Out:
#                                              filepath    gene uniprotID  \
# 0   ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 1   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 2   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 3   ../output/caitlin_experiment/variant fastas/OT...    OTX1    P32242
# 4   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 5   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 6   ../output/caitlin_experiment/variant fastas/IK...   IKZF1    Q13422
# 7   ../output/caitlin_experiment/variant fastas/NK...  NKX2-2    O95096
# 8   ../output/caitlin_experiment/variant fastas/PA...    PAX6    P26367
# 9   ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 10  ../output/caitlin_experiment/variant fastas/ME...   MEIS2    O14770
# 11  ../output/caitlin_experiment/variant fastas/PI...   PITX1    P78337
# 12  ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 13  ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 14  ../output/caitlin_experiment/variant fastas/PA...    PAX5    Q02548
#
#     start   end                       name  patient
# 0     118   261      ERG_P11308_AD_118-261       37
# 1     840  1011   NCOA1_Q15788_AD_840-1011       47
# 2     472   581   CAMTA2_O94983_AD_472-581       41
# 3     172   354     OTX1_P32242_AD_172-354       67
# 4    1241  1385  NCOA1_Q15788_AD_1241-1385       48
# 5     285   468   CAMTA2_O94983_AD_285-468       67
# 6     284   365    IKZF1_Q13422_AD_284-365       36
# 7     220   273   NKX2-2_O95096_AD_220-273       35
# 8     271   422     PAX6_P26367_AD_271-422       42
# 9     584   598    NR4A2_P43354_AD_584-598        3
# 10    340   477    MEIS2_O14770_AD_340-477       67
# 11    234   283    PITX1_P78337_AD_234-283       23
# 12    433   479      ERG_P11308_AD_433-479       18
# 13      1    91       NR4A2_P43354_AD_1-91       13
# 14    304   358     PAX5_Q02548_AD_304-358       15

# %% [markdown]
# ### AlphaMissense
# 10 most pathogenic + 10 least pathogenic = 20 variants per AD

# %%
ADs["am_top"] = 10
ADs["am_bottom"] = 10
ADs
# Out:
#                                              filepath    gene uniprotID  \
# 0   ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 1   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 2   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 3   ../output/caitlin_experiment/variant fastas/OT...    OTX1    P32242
# 4   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 5   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 6   ../output/caitlin_experiment/variant fastas/IK...   IKZF1    Q13422
# 7   ../output/caitlin_experiment/variant fastas/NK...  NKX2-2    O95096
# 8   ../output/caitlin_experiment/variant fastas/PA...    PAX6    P26367
# 9   ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 10  ../output/caitlin_experiment/variant fastas/ME...   MEIS2    O14770
# 11  ../output/caitlin_experiment/variant fastas/PI...   PITX1    P78337
# 12  ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 13  ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 14  ../output/caitlin_experiment/variant fastas/PA...    PAX5    Q02548
#
#     start   end                       name  patient  am_top  am_bottom
# 0     118   261      ERG_P11308_AD_118-261       37      10         10
# 1     840  1011   NCOA1_Q15788_AD_840-1011       47      10         10
# 2     472   581   CAMTA2_O94983_AD_472-581       41      10         10
# 3     172   354     OTX1_P32242_AD_172-354       67      10         10
# 4    1241  1385  NCOA1_Q15788_AD_1241-1385       48      10         10
# 5     285   468   CAMTA2_O94983_AD_285-468       67      10         10
# 6     284   365    IKZF1_Q13422_AD_284-365       36      10         10
# 7     220   273   NKX2-2_O95096_AD_220-273       35      10         10
# 8     271   422     PAX6_P26367_AD_271-422       42      10         10
# 9     584   598    NR4A2_P43354_AD_584-598        3      10         10
# 10    340   477    MEIS2_O14770_AD_340-477       67      10         10
# 11    234   283    PITX1_P78337_AD_234-283       23      10         10
# 12    433   479      ERG_P11308_AD_433-479       18      10         10
# 13      1    91       NR4A2_P43354_AD_1-91       13      10         10
# 14    304   358     PAX5_Q02548_AD_304-358       15      10         10

# %% [markdown]
# ### gnomAD

# %%
gnomAD_counts = []
for AD in ADs["name"]:
    gnomAD_counts.append(len(protfasta.read_fasta("../soto_analysis/outputs/AD_gnomad_variant_fasta/" + AD)))
ADs["gnomAD"] = gnomAD_counts
ADs
# Out:
#                                              filepath    gene uniprotID  \
# 0   ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 1   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 2   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 3   ../output/caitlin_experiment/variant fastas/OT...    OTX1    P32242
# 4   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 5   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 6   ../output/caitlin_experiment/variant fastas/IK...   IKZF1    Q13422
# 7   ../output/caitlin_experiment/variant fastas/NK...  NKX2-2    O95096
# 8   ../output/caitlin_experiment/variant fastas/PA...    PAX6    P26367
# 9   ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 10  ../output/caitlin_experiment/variant fastas/ME...   MEIS2    O14770
# 11  ../output/caitlin_experiment/variant fastas/PI...   PITX1    P78337
# 12  ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 13  ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 14  ../output/caitlin_experiment/variant fastas/PA...    PAX5    Q02548
#
#     start   end                       name  patient  am_top  am_bottom  gnomAD
# 0     118   261      ERG_P11308_AD_118-261       37      10         10     135
# 1     840  1011   NCOA1_Q15788_AD_840-1011       47      10         10     190
# 2     472   581   CAMTA2_O94983_AD_472-581       41      10         10     127
# 3     172   354     OTX1_P32242_AD_172-354       67      10         10     244
# 4    1241  1385  NCOA1_Q15788_AD_1241-1385       48      10         10     187
# 5     285   468   CAMTA2_O94983_AD_285-468       67      10         10     238
# 6     284   365    IKZF1_Q13422_AD_284-365       36      10         10     113
# 7     220   273   NKX2-2_O95096_AD_220-273       35      10         10      86
# 8     271   422     PAX6_P26367_AD_271-422       42      10         10     163
# 9     584   598    NR4A2_P43354_AD_584-598        3      10         10       9
# 10    340   477    MEIS2_O14770_AD_340-477       67      10         10     186
# 11    234   283    PITX1_P78337_AD_234-283       23      10         10      78
# 12    433   479      ERG_P11308_AD_433-479       18      10         10      56
# 13      1    91       NR4A2_P43354_AD_1-91       13      10         10      81
# 14    304   358     PAX5_Q02548_AD_304-358       15      10         10      71

# %%
ADs = ADs.sort_values(by = "gnomAD", ascending = False)
ADs
# Out:
#                                              filepath    gene uniprotID  \
# 3   ../output/caitlin_experiment/variant fastas/OT...    OTX1    P32242
# 5   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 1   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 4   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 10  ../output/caitlin_experiment/variant fastas/ME...   MEIS2    O14770
# 8   ../output/caitlin_experiment/variant fastas/PA...    PAX6    P26367
# 0   ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 2   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 6   ../output/caitlin_experiment/variant fastas/IK...   IKZF1    Q13422
# 7   ../output/caitlin_experiment/variant fastas/NK...  NKX2-2    O95096
# 13  ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 11  ../output/caitlin_experiment/variant fastas/PI...   PITX1    P78337
# 14  ../output/caitlin_experiment/variant fastas/PA...    PAX5    Q02548
# 12  ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 9   ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
#
#     start   end                       name  patient  am_top  am_bottom  gnomAD
# 3     172   354     OTX1_P32242_AD_172-354       67      10         10     244
# 5     285   468   CAMTA2_O94983_AD_285-468       67      10         10     238
# 1     840  1011   NCOA1_Q15788_AD_840-1011       47      10         10     190
# 4    1241  1385  NCOA1_Q15788_AD_1241-1385       48      10         10     187
# 10    340   477    MEIS2_O14770_AD_340-477       67      10         10     186
# 8     271   422     PAX6_P26367_AD_271-422       42      10         10     163
# 0     118   261      ERG_P11308_AD_118-261       37      10         10     135
# 2     472   581   CAMTA2_O94983_AD_472-581       41      10         10     127
# 6     284   365    IKZF1_Q13422_AD_284-365       36      10         10     113
# 7     220   273   NKX2-2_O95096_AD_220-273       35      10         10      86
# 13      1    91       NR4A2_P43354_AD_1-91       13      10         10      81
# 11    234   283    PITX1_P78337_AD_234-283       23      10         10      78
# 14    304   358     PAX5_Q02548_AD_304-358       15      10         10      71
# 12    433   479      ERG_P11308_AD_433-479       18      10         10      56
# 9     584   598    NR4A2_P43354_AD_584-598        3      10         10       9

# %% [markdown]
# #### Clinvar

# %%
clinvar_counts = []
ADs_with_clinvar_vars = [_.split("/")[-1] for _ in glob.glob("../soto_analysis/outputs/AD_clinvar_for_15_variant_fasta/*")]

for AD in ADs["name"]:
    if AD in ADs_with_clinvar_vars:
        clinvar_counts.append(len(protfasta.read_fasta("../soto_analysis/outputs/AD_clinvar_for_15_variant_fasta/" + AD)))
    else:
        clinvar_counts.append(0)
ADs["clinvar"] = clinvar_counts
ADs
# Out:
#                                              filepath    gene uniprotID  \
# 3   ../output/caitlin_experiment/variant fastas/OT...    OTX1    P32242
# 5   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 1   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 4   ../output/caitlin_experiment/variant fastas/NC...   NCOA1    Q15788
# 10  ../output/caitlin_experiment/variant fastas/ME...   MEIS2    O14770
# 8   ../output/caitlin_experiment/variant fastas/PA...    PAX6    P26367
# 0   ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 2   ../output/caitlin_experiment/variant fastas/CA...  CAMTA2    O94983
# 6   ../output/caitlin_experiment/variant fastas/IK...   IKZF1    Q13422
# 7   ../output/caitlin_experiment/variant fastas/NK...  NKX2-2    O95096
# 13  ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
# 11  ../output/caitlin_experiment/variant fastas/PI...   PITX1    P78337
# 14  ../output/caitlin_experiment/variant fastas/PA...    PAX5    Q02548
# 12  ../output/caitlin_experiment/variant fastas/ER...     ERG    P11308
# 9   ../output/caitlin_experiment/variant fastas/NR...   NR4A2    P43354
#
#     start   end                       name  patient  am_top  am_bottom  \
# 3     172   354     OTX1_P32242_AD_172-354       67      10         10
# 5     285   468   CAMTA2_O94983_AD_285-468       67      10         10
# 1     840  1011   NCOA1_Q15788_AD_840-1011       47      10         10
# 4    1241  1385  NCOA1_Q15788_AD_1241-1385       48      10         10
# 10    340   477    MEIS2_O14770_AD_340-477       67      10         10
# 8     271   422     PAX6_P26367_AD_271-422       42      10         10
# 0     118   261      ERG_P11308_AD_118-261       37      10         10
# 2     472   581   CAMTA2_O94983_AD_472-581       41      10         10
# 6     284   365    IKZF1_Q13422_AD_284-365       36      10         10
# 7     220   273   NKX2-2_O95096_AD_220-273       35      10         10
# 13      1    91       NR4A2_P43354_AD_1-91       13      10         10
# 11    234   283    PITX1_P78337_AD_234-283       23      10         10
# 14    304   358     PAX5_Q02548_AD_304-358       15      10         10
# 12    433   479      ERG_P11308_AD_433-479       18      10         10
# 9     584   598    NR4A2_P43354_AD_584-598        3      10         10
#
#     gnomAD  clinvar
# 3      244        0
# 5      238        0
# 1      190        0
# 4      187        0
# 10     186        4
# 8      163       33
# 0      135        1
# 2      127        0
# 6      113        7
# 7       86        2
# 13      81        2
# 11      78        3
# 14      71       13
# 12      56        0
# 9        9        1

# %% [markdown]
# ### Summary

# %%
summary = ADs[["name", "patient", "gnomAD", "am_top", "am_bottom", "clinvar"]]
summary
# Out:
#                          name  patient  gnomAD  am_top  am_bottom  clinvar
# 3      OTX1_P32242_AD_172-354       67     244      10         10        0
# 5    CAMTA2_O94983_AD_285-468       67     238      10         10        0
# 1    NCOA1_Q15788_AD_840-1011       47     190      10         10        0
# 4   NCOA1_Q15788_AD_1241-1385       48     187      10         10        0
# 10    MEIS2_O14770_AD_340-477       67     186      10         10        4
# 8      PAX6_P26367_AD_271-422       42     163      10         10       33
# 0       ERG_P11308_AD_118-261       37     135      10         10        1
# 2    CAMTA2_O94983_AD_472-581       41     127      10         10        0
# 6     IKZF1_Q13422_AD_284-365       36     113      10         10        7
# 7    NKX2-2_O95096_AD_220-273       35      86      10         10        2
# 13       NR4A2_P43354_AD_1-91       13      81      10         10        2
# 11    PITX1_P78337_AD_234-283       23      78      10         10        3
# 14     PAX5_Q02548_AD_304-358       15      71      10         10       13
# 12      ERG_P11308_AD_433-479       18      56      10         10        0
# 9     NR4A2_P43354_AD_584-598        3       9      10         10        1

# %%
summary["variant_sum"] = summary["patient"] + summary["gnomAD"] + 20
summary = summary.sort_values(by = "variant_sum", ascending = False)
summary
# Out:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_11095/1916455419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary["variant_sum"] = summary["patient"] + summary["gnomAD"] + 20
#                          name  patient  gnomAD  am_top  am_bottom  clinvar  \
# 3      OTX1_P32242_AD_172-354       67     244      10         10        0
# 5    CAMTA2_O94983_AD_285-468       67     238      10         10        0
# 10    MEIS2_O14770_AD_340-477       67     186      10         10        4
# 1    NCOA1_Q15788_AD_840-1011       47     190      10         10        0
# 4   NCOA1_Q15788_AD_1241-1385       48     187      10         10        0
# 8      PAX6_P26367_AD_271-422       42     163      10         10       33
# 0       ERG_P11308_AD_118-261       37     135      10         10        1
# 2    CAMTA2_O94983_AD_472-581       41     127      10         10        0
# 6     IKZF1_Q13422_AD_284-365       36     113      10         10        7
# 7    NKX2-2_O95096_AD_220-273       35      86      10         10        2
# 11    PITX1_P78337_AD_234-283       23      78      10         10        3
# 13       NR4A2_P43354_AD_1-91       13      81      10         10        2
# 14     PAX5_Q02548_AD_304-358       15      71      10         10       13
# 12      ERG_P11308_AD_433-479       18      56      10         10        0
# 9     NR4A2_P43354_AD_584-598        3       9      10         10        1
#
#     variant_sum
# 3           331
# 5           325
# 10          273
# 1           257
# 4           255
# 8           225
# 0           192
# 2           188
# 6           169
# 7           141
# 11          121
# 13          114
# 14          106
# 12           94
# 9            32

# %%
summary["gene"] = summary["name"].str.split("_").str[0]
summary["start"] = summary["name"].str.split("_").str[-1].str.split("-").str[0]
summary["end"] = summary["name"].str.split("_").str[-1].str.split("-").str[1]
summary["length"] = summary["end"].astype(int) - summary["start"].astype(int) + 1
summary
# Out:
#                          name  patient  gnomAD  am_top  am_bottom  clinvar  \
# 3      OTX1_P32242_AD_172-354       67     244      10         10        0
# 5    CAMTA2_O94983_AD_285-468       67     238      10         10        0
# 10    MEIS2_O14770_AD_340-477       67     186      10         10        4
# 1    NCOA1_Q15788_AD_840-1011       47     190      10         10        0
# 4   NCOA1_Q15788_AD_1241-1385       48     187      10         10        0
# 8      PAX6_P26367_AD_271-422       42     163      10         10       33
# 0       ERG_P11308_AD_118-261       37     135      10         10        1
# 2    CAMTA2_O94983_AD_472-581       41     127      10         10        0
# 6     IKZF1_Q13422_AD_284-365       36     113      10         10        7
# 7    NKX2-2_O95096_AD_220-273       35      86      10         10        2
# 11    PITX1_P78337_AD_234-283       23      78      10         10        3
# 13       NR4A2_P43354_AD_1-91       13      81      10         10        2
# 14     PAX5_Q02548_AD_304-358       15      71      10         10       13
# 12      ERG_P11308_AD_433-479       18      56      10         10        0
# 9     NR4A2_P43354_AD_584-598        3       9      10         10        1
#
#     variant_sum    gene start   end  length
# 3           331    OTX1   172   354     183
# 5           325  CAMTA2   285   468     184
# 10          273   MEIS2   340   477     138
# 1           257   NCOA1   840  1011     172
# 4           255   NCOA1  1241  1385     145
# 8           225    PAX6   271   422     152
# 0           192     ERG   118   261     144
# 2           188  CAMTA2   472   581     110
# 6           169   IKZF1   284   365      82
# 7           141  NKX2-2   220   273      54
# 11          121   PITX1   234   283      50
# 13          114   NR4A2     1    91      91
# 14          106    PAX5   304   358      55
# 12           94     ERG   433   479      47
# 9            32   NR4A2   584   598      15

# %%
summary.to_csv("../output/caitlin_experiment/counts.csv")
