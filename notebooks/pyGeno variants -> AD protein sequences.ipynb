# %%
import pandas as pd

# %%
import pyGeno.bootstrap as B

# %%
B.importRemoteGenome(name = "GRCh38.109", batchSize=100)
# Out:
# http://bioinfo.iric.ca/~feghalya/pyGeno_datawraps
# ~~~:>
# ...
# 	done.
# ~~~:>
# Importing genome package: /var/folders/bl/vk0fy7xd0n9gls0jljgdzvxc0000gn/T/pyGeno_remote_8afgpf76/GRCh38.109... (This may take a while)
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# ...
# done.
# Importing:
# 	description:  Human reference genome
# 	maintainer:  Albert Feghaly
# 	maintainer_contact:  albert.feghaly@umontreal.ca
# 	version:  1
# Genome:
# 	species:  human
# 	name:  GRCh38.109
# 	source:  http://useast.ensembl.org/info/data/ftp/index.html
# ...
# Importing gene set infos from /var/folders/bl/vk0fy7xd0n9gls0jljgdzvxc0000gn/T/pyGeno_import_3e1n335x/Homo_sapiens.GRCh38.109.gtf.gz...
# Backuping indexes...
# Dropping all your indexes (don't worry I'll restore them later)...
# Parsing gene set...
# Done. Importation begins!
# ...
