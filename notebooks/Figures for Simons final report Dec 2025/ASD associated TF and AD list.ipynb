# %%
import pandas as pd

# %% [markdown]
# Looked at [SFARI ADs.ipynb](/Users/sanjanakotha/Desktop/Staller_Lab/SFARI/notebooks/SFARI%20ADs.ipynb) to confirm ASD-associated TFs and ADs. There are 127 TFs on SFARI gene list with 63 corresponding ADs.
