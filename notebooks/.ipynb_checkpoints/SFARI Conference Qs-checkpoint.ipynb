# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# For 20 hits:
# - SFARI Gene scores
# - Acidic/S/P/Q rich?

# %% [markdown]
# # 20 HIts

# %% [markdown]
# ## SFARI Gene scores

# %%
hits = [
    "ARX", "CASZ1", "CAMTA2", "ERG", "HIVEP3", "IKZF1", "KDM5B", 
    "KLF16", "KLF7", "MEIS2", "MTF1", "MYT1L", "NR1D1", "NKX2-2", 
    "OTX1", "PAX5", "PAX6", "PITX1", "TFE3", "YY1"
]
len(hits)
# Out:
# 20

# %%
SFARI_gene = pd.read_csv("../data/SFARI-Gene_genes_01-23-2023release_03-21-2023export.csv")
SFARI_gene
# Out:
#       status gene-symbol                                          gene-name  \
# 0          9        ABAT                   4-aminobutyrate aminotransferase
# 1          9      ABCA10  ATP-binding cassette, sub-family A (ABC1), mem...
# 2          9      ABCA13         ATP binding cassette subfamily A member 13
# 3          9       ABCA7  ATP-binding cassette, sub-family A (ABC1), mem...
# 4          9        ABL2  ABL proto-oncogene 2, non-receptor tyrosine ki...
# ...      ...         ...                                                ...
# 1113       9      ZNF774                            Zinc finger protein 774
# 1114       9     ZNF804A                           Zinc finger protein 804A
# 1115       9      ZNF827                            Zinc finger protein 827
# 1116       9      ZSWIM6                 zinc finger SWIM-type containing 6
# 1117       9      ZWILCH                          zwilchkinetochore protein
#
#            ensembl-id chromosome  \
# ...

# %%
len(SFARI_gene[SFARI_gene["gene-symbol"].isin(hits)])
# Out:
# 20

# %%
SFARI_gene_hits = SFARI_gene[SFARI_gene["gene-symbol"].isin(hits)]
SFARI_gene_hits.to_csv("../data/sfari_gene_dbd_hits.csv")
SFARI_gene_hits
# Out:
#       status gene-symbol                                          gene-name  \
# 62         9         ARX                        aristaless related homeobox
# 135        9       CASZ1                               castor zinc finger 1
# 153        9      CAMTA2       calmodulin binding transcription activator 2
# 399        9         ERG                      ERG, ETS transcription factor
# 429        9      HIVEP3  human immunodeficiency virus type I enhancer b...
# 456        9       IKZF1                        IKAROS family zinc finger 1
# 501        9       KDM5B                 Lysine (K)-specific demethylase 5B
# 513        9       KLF16                             Kruppel like factor 16
# 514        9        KLF7                              Kruppel like factor 7
# 581        9       MEIS2                                    Meis homeobox 2
# 596        9        MTF1            metal-regulatory transcription factor 1
# ...

# %%
SFARI_gene_hits["syndromic"].value_counts()
# Out:
# syndromic
# 0    15
# 1     5
# Name: count, dtype: int64

# %%
SFARI_gene_hits["gene-score"].value_counts()
# Out:
# gene-score
# 1.0    8
# 2.0    7
# 3.0    3
# Name: count, dtype: int64

# %%
sns.barplot(SFARI_gene_hits["gene-score"].value_counts())
sns.despine()
plt.title("AD vs DBD Hits")
plt.xlabel("SFARI Gene Score")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.barplot(SFARI_gene_hits["syndromic"].value_counts())
sns.despine()
plt.title("AD vs DBD Hits")
plt.xlabel("Syndromic")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# X chromosome?

# %%
known_ADs = pd.read_csv("../output/known_ADs_considering_isoforms_and_canonical.csv")
hit_ADs = known_ADs[known_ADs["Gene"].isin(hits)]
hit_ADs = hit_ADs[~hit_ADs["uniprotID"].str.contains("-")]
hit_uniprotIDs = hit_ADs[["Gene", "uniprotID"]].drop_duplicates()
hit_uniprotIDs
# Out:
#        Gene uniprotID
# 22      ARX    Q96QS3
# 48   CAMTA2    O94983
# 50    CASZ1    Q86V15
# 125     ERG    P11308
# 234  HIVEP3    Q5T1R4
# 267   IKZF1    Q13422
# 291   KDM5B    Q9UGL1
# 297   KLF16    Q9BXK1
# 303    KLF7    O75840
# 333   MEIS2    O14770
# 348    MTF1    Q14872
# 367   MYT1L    Q9UL68
# 411  NKX2-2    O95096
# 418   NR1D1    P20393
# 449    OTX1    P32242
# 459    PAX5    Q02548
# 460    PAX6    P26367
# 476   PITX1    P78337
# 655    TFE3    P19532
# 699     YY1    P25490

# %%
TF_tbl = pd.read_csv("../soto_analysis/outputs/all_TFs_table_proteins.txt", sep = "\t")
hit_tbl = pd.merge(hit_uniprotIDs, TF_tbl, how = 'left')
hit_tbl
# Out:
#       Gene uniprotID  Unnamed: 0   1   2  ENSG             ENST  \
# 0      ARX    Q96QS3         567 NaN NaN   NaN  ENST00000379044
# 1   CAMTA2    O94983         822 NaN NaN   NaN  ENST00000348066
# 2    CASZ1    Q86V15        1243 NaN NaN   NaN  ENST00000377022
# 3      ERG    P11308         861 NaN NaN   NaN  ENST00000288319
# 4   HIVEP3    Q5T1R4        1167 NaN NaN   NaN  ENST00000372583
# 5    IKZF1    Q13422        1084 NaN NaN   NaN  ENST00000331340
# 6    KDM5B    Q9UGL1        1518 NaN NaN   NaN  ENST00000367265
# 7    KLF16    Q9BXK1         605 NaN NaN   NaN  ENST00000250916
# 8     KLF7    O75840         819 NaN NaN   NaN  ENST00000309446
# 9    MEIS2    O14770         765 NaN NaN   NaN  ENST00000561208
# 10    MTF1    Q14872         310 NaN NaN   NaN  ENST00000373036
# 11   MYT1L    Q9UL68        1545 NaN NaN   NaN  ENST00000428368
# 12  NKX2-2    O95096          98 NaN NaN   NaN  ENST00000377142
# 13   NR1D1    P20393         166 NaN NaN   NaN  ENST00000246672
# ...

# %%
for i in hit_tbl.index:
    ENST_df = pd.read_csv("../soto_analysis/outputs/mutations/cds_bed_format/" + hit_tbl["ENST"].iloc[i], sep = "\t", header = None)
    if ENST_df[0].iloc[0] == "X":
        print(hit_tbl["Gene"].iloc[i] + "\t" + str(ENST_df[0].iloc[0]))
# Out:
# ARX	X
# TFE3	X

# %%
for i in hit_tbl.index:
    ENST_df = pd.read_csv("../soto_analysis/outputs/mutations/cds_bed_format/" + hit_tbl["ENST"].iloc[i], sep = "\t", header = None)
    print(hit_tbl["Gene"].iloc[i] + "\t" + str(ENST_df[0].iloc[0]))
# Out:
# ARX	X
# CAMTA2	17
# CASZ1	1
# ERG	21
# HIVEP3	1
# IKZF1	7
# KDM5B	1
# KLF16	19
# KLF7	2
# MEIS2	15
# MTF1	1
# MYT1L	2
# NKX2-2	20
# NR1D1	17
# OTX1	2
# PAX5	9
# PAX6	11
# PITX1	5
# TFE3	X
# YY1	14
