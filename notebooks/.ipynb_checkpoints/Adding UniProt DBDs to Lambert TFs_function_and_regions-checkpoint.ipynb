# %%
import pandas as pd
import re

# %% [markdown]
# ## Adding UniProt DBDs to Lambert TFs

# %%
# Loading in supplemental table 1 from Lambert et al 2018
lambert_TFs = pd.read_excel("../data/lambert_supp_tables.xlsx", sheet_name = "Table S1. Related to Figure 1B")
lambert_TFs = lambert_TFs[lambert_TFs["Is TF?"] == "Yes"]
lambert_TFs.head()
# Out:
#   Gene Information Unnamed: 1 Unnamed: 2 Is TF? Final Assesment  \
# 1  ENSG00000137203     TFAP2A       AP-2    Yes     Known motif
# 2  ENSG00000008196     TFAP2B       AP-2    Yes     Known motif
# 3  ENSG00000087510     TFAP2C       AP-2    Yes     Known motif
# 4  ENSG00000008197     TFAP2D       AP-2    Yes     Known motif
# 5  ENSG00000116819     TFAP2E       AP-2    Yes     Known motif
#
#                   Unnamed: 5                Unnamed: 6  \
# 1  1 Monomer or homomultimer  High-throughput in vitro
# 2  1 Monomer or homomultimer  High-throughput in vitro
# 3  1 Monomer or homomultimer  High-throughput in vitro
# 4  1 Monomer or homomultimer       In vivo/Misc source
# 5  1 Monomer or homomultimer  High-throughput in vitro
#
#                                           Unnamed: 7  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Only known motifs are from Transfac or HocoMoc...
# 5                                                NaN
#
#                                           Unnamed: 8  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Binds the same GCCTGAGGC sequence as the other...
# 5                                                NaN
#
#   Notes from re-reviewed genes  ...      Unnamed: 22  \
# 1                          NaN  ...  Has known motif
# 2                          NaN  ...  Has known motif
# 3                          NaN  ...  Has known motif
# 4                          NaN  ...  Has known motif
# 5                          NaN  ...  Has known motif
#
#                  Unnamed: 23                          Unnamed: 24 Unnamed: 25  \
# 1  1 Monomer or homomultimer                                  NaN         NaN
# 2  1 Monomer or homomultimer                                  NaN         NaN
# 3  1 Monomer or homomultimer                                  NaN         NaN
# 4  1 Monomer or homomultimer  Source of Hocomoco motif is unclear         NaN
# 5  1 Monomer or homomultimer                                  NaN         NaN
#
#   Prior classifications Unnamed: 27 Unnamed: 28  \
# 1                     a         Yes         Yes
# 2                     a         Yes         Yes
# 3                     a         Yes         Yes
# 4                     a         Yes         Yes
# 5                     a         Yes         Yes
#
#                                          Unnamed: 29 Unnamed: 30 Unnamed: 31
# 1  TF Gene_DNA-Binding: sequence-specific_DNA Bin...         Yes         NaN
# 2  TF Gene_DNA-Binding: sequence-specific_DNA Bin...         Yes         NaN
# 3                                                 No         Yes         NaN
# 4                                                 No         Yes         NaN
# 5  TF Gene_DNA-Binding: sequence-specific_DNA Bin...         Yes         NaN
#
# [5 rows x 32 columns]

# %%
# Downloading all Lambert TF ENSG codes
lambert_TFs_ENSG = lambert_TFs[["Gene Information"]]
lambert_TFs_ENSG.to_csv("../data/LambertTFs_ENSG.csv", header = None, index = False)
lambert_TFs_ENSG
# Out:
#      Gene Information
# 1     ENSG00000137203
# 2     ENSG00000008196
# 3     ENSG00000087510
# 4     ENSG00000008197
# 5     ENSG00000116819
# ...               ...
# 2760  ENSG00000177683
# 2761  ENSG00000174796
# 2762  ENSG00000184436
# 2763  ENSG00000161277
# 2764  ENSG00000168152
#
# [1639 rows x 1 columns]

# %% [markdown]
# Steps
# 1. Uploaded to UniProt ID mapping: https://www.uniprot.org/id-mapping
# 2. Selected: From database "Ensembl" To database "UniProtKB" then hit enter
# 4. Once search completed, filtered to only reviewed entries
# 5. Downloaded TSV, and added "DNA binding" column and "regions"

# %%
# Output from uniprot
uniprot_DBD_output = pd.read_csv("../data/Lambert_TFs_DBD_uniprot_more_info.txt", sep = "\t")
uniprot_DBD_output
# Out:
#                  From       Entry  Reviewed   Entry Name  \
# 0     ENSG00000233757  A0A087WUV0  reviewed  ZN892_HUMAN
# 1     ENSG00000129173      A0AVK6  reviewed   E2F8_HUMAN
# 2     ENSG00000128610      A0PJY2  reviewed  FEZF1_HUMAN
# 3     ENSG00000164334      A1A519  reviewed  F170A_HUMAN
# 4     ENSG00000184828      A1YPR0  reviewed  ZBT7C_HUMAN
# ...               ...         ...       ...          ...
# 1608  ENSG00000124151      Q9Y6Q9  reviewed  NCOA3_HUMAN
# 1609  ENSG00000128000      Q9Y6R6  reviewed  Z780B_HUMAN
# 1610  ENSG00000152217      Q9Y6X0  reviewed  SETBP_HUMAN
# 1611  ENSG00000178764      Q9Y6X8  reviewed   ZHX2_HUMAN
# 1612  ENSG00000171735      Q9Y6Y1  reviewed  CMTA1_HUMAN
#
#                                           Protein names  \
# 0                               Zinc finger protein 892
# 1                     Transcription factor E2F8 (E2F-8)
# 2     Fez family zinc finger protein 1 (Zinc finger ...
# 3     Protein FAM170A (Zinc finger domain-containing...
# 4     Zinc finger and BTB domain-containing protein ...
# ...                                                 ...
# 1608  Nuclear receptor coactivator 3 (NCoA-3) (EC 2....
# 1609  Zinc finger protein 780B (Zinc finger protein ...
# 1610                          SET-binding protein (SEB)
# 1611  Zinc fingers and homeoboxes protein 2 (Alpha-f...
# 1612       Calmodulin-binding transcription activator 1
#
#                          Gene Names              Organism  Length  \
# 0                            ZNF892  Homo sapiens (Human)     522
# 1                              E2F8  Homo sapiens (Human)     867
# 2                 FEZF1 FEZ ZNF312B  Homo sapiens (Human)     475
# 3                      FAM170A ZNFD  Homo sapiens (Human)     330
# 4        ZBTB7C APM1 ZBTB36 ZNF857C  Homo sapiens (Human)     619
# ...                             ...                   ...     ...
# 1608  NCOA3 AIB1 BHLHE42 RAC3 TRAM1  Homo sapiens (Human)    1424
# 1609                 ZNF780B ZNF779  Homo sapiens (Human)     833
# 1610                SETBP1 KIAA0437  Homo sapiens (Human)    1596
# 1611         ZHX2 AFR1 KIAA0854 RAF  Homo sapiens (Human)     837
# 1612        CAMTA1 KIAA0833 MSTP023  Homo sapiens (Human)    1673
#
#                                             DNA binding Coiled coil  \
# 0                                                   NaN         NaN
# 1     DNA_BIND 113..182; /evidence="ECO:0000255"; DN...         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 1608                                                NaN         NaN
# 1609                                                NaN         NaN
# 1610  DNA_BIND 584..596; /note="A.T hook 1"; DNA_BIN...         NaN
# 1611  DNA_BIND 263..324; /note="Homeobox 1"; /eviden...         NaN
# 1612  DNA_BIND 63..188; /note="CG-1"; /evidence="ECO...         NaN
#
#                                      Compositional bias  \
# 0     COMPBIAS 1..19; /note="Basic and acidic residu...
# 1     COMPBIAS 410..432; /note="Polar residues"; /ev...
# 2     COMPBIAS 436..466; /note="Pro residues"; /evid...
# 3     COMPBIAS 30..54; /note="Polar residues"; /evid...
# 4     COMPBIAS 130..176; /note="Acidic residues"; /e...
# ...                                                 ...
# 1608  COMPBIAS 503..520; /note="Polar residues"; /ev...
# 1609                                                NaN
# 1610  COMPBIAS 145..163; /note="Basic and acidic res...
# 1611  COMPBIAS 164..182; /note="Polar residues"; /ev...
# 1612  COMPBIAS 305..331; /note="Basic and acidic res...
#
#                                             Domain [CC]  \
# 0                                                   NaN
# 1     DOMAIN: In contrast to classical members of th...
# 2                                                   NaN
# 3     DOMAIN: The N-terminus is necessary for nuclea...
# 4                                                   NaN
# ...                                                 ...
# 1608  DOMAIN: Contains three Leu-Xaa-Xaa-Leu-Leu (LX...
# 1609                                                NaN
# 1610                                                NaN
# 1611                                                NaN
# 1612                                                NaN
#
#                                             Domain [FT]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     DOMAIN 34..101; /note="BTB"; /evidence="ECO:00...
# ...                                                 ...
# 1608  DOMAIN 25..82; /note="bHLH"; /evidence="ECO:00...
# 1609  DOMAIN 6..77; /note="KRAB"; /evidence="ECO:000...
# 1610                                                NaN
# 1611                                                NaN
# 1612  DOMAIN 875..953; /note="IPT/TIG"; /evidence="E...
#
#                                                  Region  \
# 0     REGION 1..22; /note="Disordered"; /evidence="E...
# 1     REGION 38..58; /note="Disordered"; /evidence="...
# 2     REGION 428..475; /note="Disordered"; /evidence...
# 3     REGION 1..54; /note="Disordered"; /evidence="E...
# 4     REGION 129..218; /note="Disordered"; /evidence...
# ...                                                 ...
# 1608  REGION 1..38; /note="Disordered"; /evidence="E...
# 1609                                                NaN
# 1610  REGION 1..83; /note="Disordered"; /evidence="E...
# 1611  REGION 27..77; /note="Interaction with EFNB1";...
# 1612  REGION 283..375; /note="Disordered"; /evidence...
#
#                                                  Repeat  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1608                                                NaN
# 1609                                                NaN
# 1610  REPEAT 1520..1527; /note="1"; REPEAT 1528..153...
# 1611                                                NaN
# 1612  REPEAT 1064..1093; /note="ANK 1"; REPEAT 1109....
#
#                                    Protein families  \
# 0     Krueppel C2H2-type zinc-finger protein family
# 1                                     E2F/DP family
# 2     Krueppel C2H2-type zinc-finger protein family
# 3                                     FAM170 family
# 4                                               NaN
# ...                                             ...
# 1608   SRC/p160 nuclear receptor coactivator family
# 1609  Krueppel C2H2-type zinc-finger protein family
# 1610                                            NaN
# 1611                                     ZHX family
# 1612                                   CAMTA family
#
#                                                   Motif  \
# 0                                                   NaN
# 1                                                   NaN
# 2     MOTIF 28..43; /note="Engrailed homology 1 repr...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1608  MOTIF 685..689; /note="LXXLL motif 1"; MOTIF 7...
# 1609                                                NaN
# 1610                                                NaN
# 1611                                                NaN
# 1612  MOTIF 112..119; /note="Nuclear localization si...
#
#                                   Sequence similarities  \
# 0     SIMILARITY: Belongs to the krueppel C2H2-type ...
# 1     SIMILARITY: Belongs to the E2F/DP family. {ECO...
# 2     SIMILARITY: Belongs to the krueppel C2H2-type ...
# 3     SIMILARITY: Belongs to the FAM170 family. {ECO...
# 4                                                   NaN
# ...                                                 ...
# 1608  SIMILARITY: Belongs to the SRC/p160 nuclear re...
# 1609  SIMILARITY: Belongs to the krueppel C2H2-type ...
# 1610                                                NaN
# 1611  SIMILARITY: Belongs to the ZHX family. {ECO:00...
# 1612  SIMILARITY: Belongs to the CAMTA family. {ECO:...
#
#                                             Zinc finger
# 0     ZN_FING 221..243; /note="C2H2-type 1"; /eviden...
# 1                                                   NaN
# 2     ZN_FING 260..282; /note="C2H2-type 1"; /eviden...
# 3       ZN_FING 228..252; /note="C2H2-type; degenerate"
# 4     ZN_FING 364..386; /note="C2H2-type 1"; /eviden...
# ...                                                 ...
# 1608                                                NaN
# 1609  ZN_FING 165..187; /note="C2H2-type 1"; /eviden...
# 1610                                                NaN
# 1611  ZN_FING 78..101; /note="C2H2-type 1"; /evidenc...
# 1612                                                NaN
#
# [1613 rows x 19 columns]

# %% [markdown]
# #### Plan
# - Get info from:
# 1. DNA binding
# 2. Domain [FT]
# 3. Region
# 4. Zinc finger

# %%
uniprot_DBD_output = uniprot_DBD_output.fillna("")

# %%
# NO info for these
uniprot_DBD_output[(uniprot_DBD_output["DNA binding"] == "") & (uniprot_DBD_output["Region"] == "") & (uniprot_DBD_output["Zinc finger"] == "") & (uniprot_DBD_output["Domain [FT]"] == "")]
# Out:
#                  From   Entry  Reviewed   Entry Name  \
# 33    ENSG00000169689  A8MT69  reviewed  CENPX_HUMAN
# 230   ENSG00000237765  P0CF97  reviewed  F200B_HUMAN
# 511   ENSG00000028839  P62380  reviewed  TBPL1_HUMAN
# 654   ENSG00000257923  Q13948  reviewed   CASP_HUMAN
# 775   ENSG00000120832  Q49AM1  reviewed  MTEF2_HUMAN
# 844   ENSG00000174428  Q6EKJ0  reviewed  GTD2B_HUMAN
# 951   ENSG00000196275  Q86UP8  reviewed  GTD2A_HUMAN
# 1120  ENSG00000198715  Q8WWB7  reviewed   GLMP_HUMAN
# 1495  ENSG00000163320  Q9UFW8  reviewed  CGBP1_HUMAN
#
#                                           Protein names  \
# 33    Centromere protein X (CENP-X) (FANCM-associate...
# 230                                     Protein FAM200B
# 511   TATA box-binding protein-like 1 (TBP-like 1) (...
# 654                                        Protein CASP
# 775   Transcription termination factor 2, mitochondr...
# 844   General transcription factor II-I repeat domai...
# 951   General transcription factor II-I repeat domai...
# 1120  Glycosylated lysosomal membrane protein (Lysos...
# 1495  CGG triplet repeat-binding protein 1 (CGG-bind...
#
#                                  Gene Names              Organism  Length  \
# 33                 CENPX FAAP10 MHF2 STRA13  Homo sapiens (Human)      81
# 230                         FAM200B C4orf53  Homo sapiens (Human)     657
# 511            TBPL1 TLF TLP TLP21 TRF2 TRP  Homo sapiens (Human)     186
# 654                              CUX1 CUTL1  Homo sapiens (Human)     678
# 775                          MTERF2 MTERFD3  Homo sapiens (Human)     385
# 844                               GTF2IRD2B  Homo sapiens (Human)     949
# 951                      GTF2IRD2 GTF2IRD2A  Homo sapiens (Human)     949
# 1120  GLMP C1orf85 PSEC0030 UNQ2553/PRO6182  Homo sapiens (Human)     406
# 1495                           CGGBP1 CGGBP  Homo sapiens (Human)     167
#
#      DNA binding                                        Coiled coil  \
# 33
# 230
# 511
# 654               COILED 67..450; /evidence="ECO:0000255"; COILE...
# 775
# 844
# 951
# 1120
# 1495
#
#      Compositional bias Domain [CC] Domain [FT] Region  \
# 33
# 230
# 511
# 654
# 775
# 844
# 951
# 1120
# 1495
#
#                                                  Repeat    Protein families  \
# 33                                                       CENP-X/MHF2 family
# 230                                                           FAM200 family
# 511                                                              TBP family
# 654                                                             CASP family
# 775                                                            MTERF family
# 844   REPEAT 98..192; /note="GTF2I-like 1"; REPEAT 3...       TFII-I family
# 951   REPEAT 98..192; /note="GTF2I-like 1"; REPEAT 3...       TFII-I family
# 1120                                                            GLMP family
# 1495
#
#                                                   Motif  \
# 33
# 230
# 511
# 654
# 775
# 844
# 951
# 1120  MOTIF 402..406; /note="Lysosomal targeting mot...
# 1495  MOTIF 80..84; /note="Nuclear localization sign...
#
#                                   Sequence similarities Zinc finger
# 33    SIMILARITY: Belongs to the CENP-X/MHF2 family....
# 230   SIMILARITY: Belongs to the FAM200 family. {ECO...
# 511   SIMILARITY: Belongs to the TBP family. {ECO:00...
# 654   SIMILARITY: Belongs to the CASP family. {ECO:0...
# 775   SIMILARITY: Belongs to the mTERF family. {ECO:...
# 844   SIMILARITY: Belongs to the TFII-I family. {ECO...
# 951   SIMILARITY: Belongs to the TFII-I family. {ECO...
# 1120  SIMILARITY: Belongs to the GLMP family. {ECO:0...
# 1495

# %%
# Will add to this
DBD_list = uniprot_DBD_output.copy(deep = True)[["From", "Entry", "Entry Name"]]
DBD_list
# Out:
#                  From       Entry   Entry Name
# 0     ENSG00000233757  A0A087WUV0  ZN892_HUMAN
# 1     ENSG00000129173      A0AVK6   E2F8_HUMAN
# 2     ENSG00000128610      A0PJY2  FEZF1_HUMAN
# 3     ENSG00000164334      A1A519  F170A_HUMAN
# 4     ENSG00000184828      A1YPR0  ZBT7C_HUMAN
# ...               ...         ...          ...
# 1608  ENSG00000124151      Q9Y6Q9  NCOA3_HUMAN
# 1609  ENSG00000128000      Q9Y6R6  Z780B_HUMAN
# 1610  ENSG00000152217      Q9Y6X0  SETBP_HUMAN
# 1611  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN
# 1612  ENSG00000171735      Q9Y6Y1  CMTA1_HUMAN
#
# [1613 rows x 3 columns]

# %% [markdown]
# 1. DNA Binding column

# %%
# DNA_binding_col_matches = uniprot_DBD_output["DNA binding"].str.extractall(r'DNA_BIND (\d+\.\.\d+)')
# DNA_binding_col_matches = DNA_binding_col_matches.reset_index()
# DNA_binding_col_matches

# %%
DBD_list = pd.merge(DBD_list, DNA_binding_col_matches, left_index = True, right_on = "level_0", how = "left")
DBD_list
# Out:
#                   From       Entry   Entry Name  level_0  match         0
# NaN    ENSG00000233757  A0A087WUV0  ZN892_HUMAN        0    NaN       NaN
# 0.0    ENSG00000129173      A0AVK6   E2F8_HUMAN        1    0.0  113..182
# 1.0    ENSG00000129173      A0AVK6   E2F8_HUMAN        1    1.0  261..347
# NaN    ENSG00000128610      A0PJY2  FEZF1_HUMAN        2    NaN       NaN
# NaN    ENSG00000164334      A1A519  F170A_HUMAN        3    NaN       NaN
# ...                ...         ...          ...      ...    ...       ...
# 593.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611    0.0  263..324
# 594.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611    1.0  439..501
# 595.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611    2.0  530..591
# 596.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611    3.0  628..690
# 597.0  ENSG00000171735      Q9Y6Y1  CMTA1_HUMAN     1612    0.0   63..188
#
# [1696 rows x 6 columns]

# %%
DBD_list = DBD_list.fillna("")
DBD_list
# Out:
#                   From       Entry   Entry Name  level_0 match         0
# NaN    ENSG00000233757  A0A087WUV0  ZN892_HUMAN        0
# 0.0    ENSG00000129173      A0AVK6   E2F8_HUMAN        1   0.0  113..182
# 1.0    ENSG00000129173      A0AVK6   E2F8_HUMAN        1   1.0  261..347
# NaN    ENSG00000128610      A0PJY2  FEZF1_HUMAN        2
# NaN    ENSG00000164334      A1A519  F170A_HUMAN        3
# ...                ...         ...          ...      ...   ...       ...
# 593.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   0.0  263..324
# 594.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   1.0  439..501
# 595.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   2.0  530..591
# 596.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   3.0  628..690
# 597.0  ENSG00000171735      Q9Y6Y1  CMTA1_HUMAN     1612   0.0   63..188
#
# [1696 rows x 6 columns]

# %%
start_ints = DBD_list[0].str.extract(r'(\d+)\.\.')[0]
end_ints =  DBD_list[0].str.extract(r'\.\.(\d+)')[0]
DBD_list[0] = list(zip(start_ints, end_ints))
DBD_list
# Out:
#                   From       Entry   Entry Name  level_0 match           0
# NaN    ENSG00000233757  A0A087WUV0  ZN892_HUMAN        0        (nan, nan)
# 0.0    ENSG00000129173      A0AVK6   E2F8_HUMAN        1   0.0  (113, 182)
# 1.0    ENSG00000129173      A0AVK6   E2F8_HUMAN        1   1.0  (261, 347)
# NaN    ENSG00000128610      A0PJY2  FEZF1_HUMAN        2        (nan, nan)
# NaN    ENSG00000164334      A1A519  F170A_HUMAN        3        (nan, nan)
# ...                ...         ...          ...      ...   ...         ...
# 593.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   0.0  (263, 324)
# 594.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   1.0  (439, 501)
# 595.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   2.0  (530, 591)
# 596.0  ENSG00000178764      Q9Y6X8   ZHX2_HUMAN     1611   3.0  (628, 690)
# 597.0  ENSG00000171735      Q9Y6Y1  CMTA1_HUMAN     1612   0.0   (63, 188)
#
# [1696 rows x 6 columns]

# %%
#DBD_list[0] = DBD_list[0].astype(str)
DBD_list_func_joined = DBD_list.groupby(["From", "Entry", "Entry Name"])[0].apply(list).reset_index()
DBD_list_func_joined
# Out:
#                  From   Entry   Entry Name             0
# 0     ENSG00000001167  P23511   NFYA_HUMAN  [(296, 321)]
# 1     ENSG00000004848  Q96QS3    ARX_HUMAN  [(328, 387)]
# 2     ENSG00000005073  P31270  HXA11_HUMAN  [(241, 300)]
# 3     ENSG00000005102  P50221  MEOX1_HUMAN  [(171, 230)]
# 4     ENSG00000005513  P57073   SOX8_HUMAN  [(102, 170)]
# ...               ...     ...          ...           ...
# 1608  ENSG00000277258  P35227  PCGF2_HUMAN  [(nan, nan)]
# 1609  ENSG00000277462  Q9BS34  ZN670_HUMAN  [(nan, nan)]
# 1610  ENSG00000278129  P17098   ZNF8_HUMAN  [(nan, nan)]
# 1611  ENSG00000278318  Q9UJW7  ZN229_HUMAN  [(nan, nan)]
# 1612  ENSG00000278570  Q9Y5X4  NR2E3_HUMAN   [(44, 120)]
#
# [1613 rows x 4 columns]

# %%
DBD_list_func_joined = DBD_list_func_joined.rename(columns = {0: "Function"})
DBD_list_func_joined
# Out:
#                  From   Entry   Entry Name      Function
# 0     ENSG00000001167  P23511   NFYA_HUMAN  [(296, 321)]
# 1     ENSG00000004848  Q96QS3    ARX_HUMAN  [(328, 387)]
# 2     ENSG00000005073  P31270  HXA11_HUMAN  [(241, 300)]
# 3     ENSG00000005102  P50221  MEOX1_HUMAN  [(171, 230)]
# 4     ENSG00000005513  P57073   SOX8_HUMAN  [(102, 170)]
# ...               ...     ...          ...           ...
# 1608  ENSG00000277258  P35227  PCGF2_HUMAN  [(nan, nan)]
# 1609  ENSG00000277462  Q9BS34  ZN670_HUMAN  [(nan, nan)]
# 1610  ENSG00000278129  P17098   ZNF8_HUMAN  [(nan, nan)]
# 1611  ENSG00000278318  Q9UJW7  ZN229_HUMAN  [(nan, nan)]
# 1612  ENSG00000278570  Q9Y5X4  NR2E3_HUMAN   [(44, 120)]
#
# [1613 rows x 4 columns]

# %% [markdown]
# ---
# 2. Now, using Regions

# %%
uniprot_DBD_output["Region"]
# Out:
# 0       REGION 1..22; /note="Disordered"; /evidence="E...
# 1       REGION 38..58; /note="Disordered"; /evidence="...
# 2       REGION 428..475; /note="Disordered"; /evidence...
# 3       REGION 1..54; /note="Disordered"; /evidence="E...
# 4       REGION 129..218; /note="Disordered"; /evidence...
#                               ...
# 1608    REGION 1..38; /note="Disordered"; /evidence="E...
# 1609
# 1610    REGION 1..83; /note="Disordered"; /evidence="E...
# 1611    REGION 27..77; /note="Interaction with EFNB1";...
# 1612    REGION 283..375; /note="Disordered"; /evidence...
# Name: Region, Length: 1613, dtype: object

# %%
for _ in uniprot_DBD_output["Region"].str.extractall(r'note="(.+?)"').reset_index().sort_values(by = 0)[0].unique():
    print(_)
# Out:
# 10 X 4 AA tandem repeats of S-P-[RGMKC]-[RK]
# 11 X 7 AA tandem repeats of [DR]-P-Y-R-[LI][AG][QHP]
# 13 X 2 AA tandem repeats of G-Q
# 14 X 6 AA repeats of [ED]-R-S-M-M-S
# 15 X 9 AA tandem repeats of P-P-x-x-P-x-P-P-x
# 17 X 10 AA tandem repeats of L-A-[ST]-[NSG]-[TS]-MDSQM
# 2 X 19 AA repeats of P-S-R-R-R-R-S-R-S-V-V-R-R-R-S-F-S-I-S
# 2 X 2 AA tandem repeats of G-Q
# 2 approximate SP repeats
# 3 X 11 AA tandem repats of P-P-L-P-P-E-E-P-P-[TME]-[MTG]
# 3 X 12 AA approximate repeats
# 3 X 7 AA repeat of P-E-V-E-A-A-E
# 3 X 8 AA tandem repeats of P-P-L-P-P-P-P-P
# 3 X SP repeats
# 3 X approximate SP repeats
# 3 X tandem repeats of [ST]-P-[VLI]-R-[RL]-[RK]-[RF]-S-R
# 4 X 5 AA repeat of P-X-G-E-A
# 4 X 67 AA tandem repeats
# 4 X 7 AA repeats of P-[LV]-T-[IL]-T-[ST]-P
# 4 X 8 AA tandem repeats of V-L-E-SS-[AVT]-VT
# 4 X approximate tandem repeats
# 6 X 2 AA tandem repeats of K-G
# 6 X 4 AA tandem repeats of S-P-X-[RK]
# 7 X 7 AA repeats of P-S-R-R-S-R-[TS]
# 8 X repeats starting with a Trp in each unit
# A domain
# AF-2
# AF-2 domain
# AF1; mediates transcriptional activation
# AF2; mediates transcriptional activation
# AF3; mediates transcriptional activation (in isoform B)
# Acetyltransferase
# Acidic
# Acidic 1
# Acidic 2
# Acidic 3
# Activates transcription; Inhibition of nuclear import due to lack of NLS and KPNA2 interaction
# Activation domain; required for transcription activation
# Activation function (AF)-1 domain
# Active repression domain
# Autoinhibitory linker
# B domain
# Bactericidal and antifungal activity
# Basic (repression of DNA-binding)
# Basic motif
# Basic motif; degenerate
# Basic motif; required for the activation of phospholipid synthesis, but not for CDS1-binding
# Beta domain
# Bind to RHO promoter
# Binding to CtBP
# Binding to DNA
# Binds lipopolysaccharide
# C domain
# C-terminal VHL recognition site
# C-terminal conserved inhibitory domain (CCID)
# C-terminal domain; essential for histone methyltransferase activity, nuclear localization and mediates interaction with HSP90AA1
# C-terminal subdomain A
# C-terminal subdomain B
# C5-methylcytosine binding
# CASP8AP2-binding
# CATD
# CPD
# CR1; interaction with HDAC1, HDAC2, MBD2 and MTA2
# CR1; interaction with MBD2 and MBD3
# CR2; histone tail-binding
# CR2; histone tail-binding and interaction with CHD4 and CDK2AP1
# CTAD
# CTBP1-binding
# CTNNB1-binding
# Calcineurin-binding
# Catalytic
# Catalytic domain
# Cholesterol recognition/amino acid consensus (CRAC) region
# Class A specific domain
# Core promoter DNA-binding
# Critical for glycosaminoglycan, lipid A, lysozyme and DNA binding
# Crucial for activation of GJA1
# Cyclin A/CDK2 binding
# Cyclin A:CDK2 binding
# D domain
# DACHbox-C
# DACHbox-N
# DCB1
# DCB2
# DNA replication foci-targeting sequence
# DNA-binding
# DNA-binding domain
# DNA-binding regulation
# DNA-binding; major groove
# DNA-binding; minor groove
# Decreased nuclear import with localization in the nucleus but also in the cytoplasm
# Dehydrogenase domain
# Dimerization
# Dimerization (DIM)
# Dimerization with NSUN4
# Disordered
# Does not affect nuclear localization pattern
# Domain D
# E3 ubiquitin-protein ligase activity
# Enhances binding of RB protein to E2F
# Essential for ESRRB transcriptional activity and interaction with NCOA3
# Essential for MYOD1 inhibition
# Essential for binding adenovirus 2 E1A
# Essential for interaction with BMAL1, E-box binding and repressor activity against the CLOCK-BMAL1 heterodimer
# Essential for interaction with HIF1AN
# Essential for its histone acetyltransferase activity
# Essential for nuclear localization, interaction with RORG, repression of RORG transcriptional activator activity
# Essential for transcriptional repressor activity and for interaction with KAT5 and HDAC7
# Flexible linker
# Flexible stalk domain
# GLEBS
# GRR
# Globular domain
# Gly-rich region involved in interaction with HCFC1
# H-S-H (helix-span-helix), dimerization
# HATC (Hobo-Ac-Tam3) domain
# HYB domain
# Has GTPase activity, required for proper localization
# Helix H4
# Helix H5
# Helix HI-1
# Helix HI-2
# Helix-loop-helix motif
# Hinge
# Histone H3K36me3 binding
# Homeo-Prospero
# Homodimerization
# Hydrophobic
# Hydrophobic repeat HR-A/B
# Hydrophobic repeat HR-C
# ID
# Implicated in the circadian rhythmicity
# Important for DNA and nucleosome binding
# Important for PRC2 dimer stability
# Important for coactivator binding
# Important for cytoplasmic localization
# Important for dimerization
# Important for flexibility of DNA ends that protrude from nucleosomes
# Important for full bactericidal and antifungal activities
# Important for interaction with SMAD4
# Important for interaction with SUMO1 and SUMO2
# Important for interaction with target DNA
# Important for nuclear localization
# Important for nuclear localization and chromatin binding
# Important for nucleosome binding activity of the PRC2 complex
# Important for transcriptional activation
# Important for transcriptional activation of target genes
# Important for transcriptional repression activity
# Important for ubiquitin binding
# Interaction with 5-mCpG DNA
# Interaction with ACSS2
# Interaction with AKAP13
# Interaction with AR
# Interaction with ARID3A
# Interaction with ARIH2
# Interaction with ATXN1
# Interaction with AURKA
# Interaction with AURKA and FBXW7
# Interaction with AXIN1
# Interaction with BIRC2/c-IAP1
# Interaction with BMAL1
# Interaction with BMI1
# Interaction with CALCOCO1
# Interaction with CARM1
# Interaction with CBFA2T2
# Interaction with CBFA2T3
# Interaction with CCAR1
# Interaction with CCAR2
# Interaction with CCND1, CCND2 and CCND3
# Interaction with CCND2
# Interaction with CEBPA
# Interaction with CEP164 and required for UV resistance
# Interaction with CFLAR
# Interaction with CIART
# Interaction with CIITA
# Interaction with CLOCK
# Interaction with CREBBP
# Interaction with CRY1
# Interaction with CTBP1
# Interaction with CTBP1 and CTBP2 1
# Interaction with CTBP1 and CTBP2 2
# Interaction with CTBP1, CTBP2 and ZNF516
# Interaction with CTBP2
# Interaction with CTNNA2
# Interaction with CTNND1
# Interaction with DAPK3
# Interaction with DCAF5
# Interaction with DDX5
# Interaction with DDX5; self-association
# Interaction with DMAP1
# Interaction with DNA
# Interaction with DNMT3A
# Interaction with DNMT3B
# Interaction with DPY30
# Interaction with E4F1
# Interaction with EFNB1
# Interaction with Elongin BC complex
# Interaction with FAM120B
# Interaction with FHL3
# Interaction with FOXO1
# Interaction with FOXP3
# Interaction with GABBR1
# Interaction with HCFC1
# Interaction with HDGFL2
# Interaction with HERC5
# Interaction with HIPK1
# Interaction with HIPK2
# Interaction with HIPK2 and NLK
# Interaction with HIPK3
# Interaction with HRMT1L2
# Interaction with IKZF4
# Interaction with IRF3
# Interaction with KAT2B
# Interaction with KAT6A
# Interaction with KAT6B
# Interaction with KAT7
# Interaction with KCND2
# Interaction with KDM1B
# Interaction with KDM5B
# Interaction with KEAP1
# Interaction with KPNA2
# Interaction with LMNA
# Interaction with LMO4
# Interaction with LPXN
# Interaction with MAP3K14/NIK
# Interaction with MAPK1 and MAPK3
# Interaction with MAPK9, SMAD3 and probably SUV39H1
# Interaction with MAZ
# Interaction with MCM2
# Interaction with MED1 and CCAR1
# Interaction with MORN3
# Interaction with MSX2
# Interaction with MYC
# Interaction with NANOG
# Interaction with NCOA1, NCOA2, NCOA3 and KAT2B
# Interaction with NCOR1
# Interaction with NCOR2
# Interaction with NPAT
# Interaction with NR2F6
# Interaction with NR3C1
# Interaction with NRIP1
# Interaction with OTX2 and is required for repressor activity
# Interaction with PABPC1 and PABC4
# Interaction with PAGE4
# Interaction with PBX1
# Interaction with PCNA
# Interaction with PER2
# Interaction with PIAS1
# Interaction with PIT-1
# Interaction with PLRG1
# Interaction with POLR2A. Interaction with SFRS1; SFRS9 and SFRS10
# Interaction with PPP1R8
# Interaction with PTEN
# Interaction with PTP4A1
# Interaction with PspA
# Interaction with RB1
# Interaction with RBBP4
# Interaction with RBL1 and RBL2
# Interaction with RBPJ. Required for transcription repressor activity on Notch target genes
# Interaction with RBPSUH
# Interaction with RCOR1
# Interaction with RLIM
# Interaction with RNA
# Interaction with RNF31
# Interaction with RORG
# Interaction with RUNX1
# Interaction with RUNX1T1
# Interaction with SAFB1
# Interaction with SAFB2
# Interaction with SFTSV virus NSs
# Interaction with SIN3A
# Interaction with SIN3A and SIN3B
# Interaction with SIN3B
# Interaction with SIRT1
# Interaction with SIX6 and HDAC3
# Interaction with SLBP/pre-mRNA complex
# Interaction with SOX13
# Interaction with SOX9
# Interaction with STAT3
# Interaction with SUFU
# Interaction with SUMO1
# Interaction with SUMO2 1
# Interaction with SUMO2 2
# Interaction with SUZ12
# Interaction with TAB2
# Interaction with TACC3
# Interaction with TAF4B
# Interaction with TBL1XR1
# Interaction with TBX21
# Interaction with TERF1
# Interaction with TERF2IP
# Interaction with THBS4
# Interaction with TLE5
# Interaction with TOP1
# Interaction with TRIB3
# Interaction with TSGA10
# Interaction with UBE2I
# Interaction with USP7
# Interaction with WWOX
# Interaction with WWP1
# Interaction with ZFP90
# Interaction with ZFPM2
# Interaction with ZMYND8
# Interaction with ZNF296
# Interaction with ZNF318
# Interaction with ZNHIT1
# Interaction with coactivator LXXLL motif
# Interaction with heartland virus NSs
# Interaction with hepatitis C virus E2 glycoprotein
# Interaction with histone H3
# Interaction with histone H3 not methylated at 'Lys-4'
# Interaction with histone H3K4me3
# Interaction with importin alpha-1
# Interaction with lipopolysaccharide
# Interaction with monomethylated and dimethylated peptides
# Interaction with p53/TP53
# Interaction with ss-DNA
# Interaction with target DNA
# Interaction with the 53BP2 SH3 domain
# Interaction with the PRC2/EED-EZH2 complex
# Interaction with the SMAD1/SMAD4 complex
# Interactions with DUSP26, MAPK1 and MAPK2
# Involved in DNA-binding
# Involved in chromatin-binding
# Involved in condensin complex recruitment
# Involved in dimerization
# Involved in glycosaminoglycan binding
# Involved in homodimer formation
# Involved in masking transactivation domain
# Involved in negatively regulating E2F activity
# Involved in nuclear matrix association
# Involved in repression of activated transcription
# Involved in the interaction with CCAR2
# Involved in the interaction with H3C15 and H3C1
# KRNB
# L3 loop
# LATS2 binding
# LEUTX region
# LIM-binding domain (LID)
# Leucine-rich region; critical for dimer formation and for interaction with RFXAP
# Leucine-zipper
# Leucine-zipper 1
# Leucine-zipper 2
# Linker
# MIU
# Massively activates transcription
# May be involved in interaction with ARF
# May mediate active transcriptional repression
# Mediates HDAC-dependent transcriptional repression
# Mediates dimerization, DNA-binding, transcription repression of CCNA2 and interaction with HMGA2
# Mediates direct interaction with RBBP4
# Mediates heterotypic interactions between MLXIP and MLX and is required for cytoplasmic localization
# Mediates homodimerization
# Mediates homodimerization and heterodimerization
# Mediates interaction with ALDH1A1
# Mediates interaction with CBFA2T3
# Mediates interaction with CDKN2A
# Mediates interaction with CHD6 and is necessary to activate transcription
# Mediates interaction with CHUK/IKKA and IKBKB/IKKB
# Mediates interaction with DNTTIP2
# Mediates interaction with DZIP1
# Mediates interaction with GATA1
# Mediates interaction with GDI2 and RAB8A
# Mediates interaction with GLI3
# Mediates interaction with GLI3 and localization to the cilium basal body
# Mediates interaction with KHDRBS1
# Mediates interaction with MAD2L2
# Mediates interaction with PCM1
# Mediates interaction with RASSF1
# Mediates interaction with RELA
# Mediates interaction with RNF4
# Mediates interaction with SKI and regulation of TGF-beta signaling
# Mediates interaction with SMAD4
# Mediates interaction with TP53
# Mediates interaction with TRIM28
# Mediates interaction with USP18
# Mediates interaction with ZBTB7A
# Mediates interaction with ZDHHC11
# Mediates localization to the chromosome and the spindle and negatively regulates chromosome alignment
# Mediates localization to the spindle and the kinetochore and is required for the attachment of spindle microtubules to the kinetochore
# Mediates promoter DNA-binding and activation of transcription
# Mediates the transcription activity and dimerization of the AHR:ARNT complex
# Mediates transcriptional activation
# Mediates transcriptional activity
# Mediates transcriptional repression
# Mediates transcriptional transrepression (in isoform A)
# Microtubule-binding region
# Minimal transactivation domain (MTD)
# Modulating
# Modulating (transactivation AF-1); mediates interaction with MACROD1
# Modulating, Pro-Rich
# N-terminal
# N-terminal VHL recognition site
# N-terminal domain
# N-terminal region (NRD)
# NTAD
# Necessary and sufficient for nuclear localization
# Necessary for TATA box-bound TBP complex formation
# Necessary for binding to ITPR1, CEBPA and p53/TP53 mRNAs
# Necessary for cytoplasmic localization
# Necessary for dimerization
# Necessary for interaction with CCND1
# Necessary for interaction with EHD1
# Necessary for interaction with MDFIC and transcriptional activation or repression
# Necessary for interaction with RAB4A
# Necessary for interaction with RAB5A
# Necessary for interaction with RXRA and repressor activity against RXRA
# Necessary for interaction with RXRA and repressor activity towards RXRA
# Necessary for interaction with SLC9A3R2
# Necessary for interaction with ZNF208 isoform KRAB-O
# Necessary for nuclear localization
# Necessary for nucleolar localization
# Necessary for stress granule assembly and correct localization in dcp1 bodies
# Necessary for the correct targeting to endosomes
# Necessary for the interaction with NMI
# Necessary for the translational pausing of its own mRNA
# Necessary for transcription activation
# Necessary for transcriptional repression and sufficient for interaction with DR1
# Necessary for transcriptional transactivation
# Negative regulatory domain
# Neuroprotective peptide (NAP)
# Nitrobindin
# No DNA binding activity or transactivation activity, but complete prevention of TRAF-dependent NF-Kappa-B activation; associates with TRAF2 and JUN
# Nuclear export signal
# Nuclear hormone receptor interaction
# Nuclear localization signal
# Nuclear localization signal (NLS); in isoforms 1 and isoform 2
# Nuclear matrix targeting sequence (NMTS)
# ODD
# Oligomerization
# PAI subdomain
# PBC-A
# PBC-B
# PEST
# PQA
# Proline-rich domain (PRD)
# Promoter-specific activation domain
# R1 epitope (recognized by Chagas's antibodies)
# R3 epitope (recognized by Chagas's antibodies)
# RB1 binding
# RBL2 association
# RED subdomain
# RII-binding
# RNA-binding
# RUNX1-binding
# Regulatory domain
# Represses ARE-mediated transcription
# Represses transcription
# Repression domain 1 (RD1)
# Repression domain; contains 3 sumoylation motifs and massively decrease transcription activity
# Repressive function
# Repressor domain
# Required and sufficient for interaction with KDM1A
# Required for DNA binding
# Required for DNA-PK heterotrimer
# Required for DNA-binding
# Required for DNA-binding and interaction with NFKBIA
# Required for DNA-binding and transcriptional repression
# Required for FBXL14-triggered degradation
# Required for Lys-174 sumoylation
# Required for MYC transcriptional repression
# Required for WNT signaling induction
# Required for activation of histone H4 transcription and contributes to DNA-binding
# Required for activity
# Required for binding NBRE-containing DNA
# Required for binding PP1CC
# Required for binding corepressor NCOR1
# Required for binding to the neuron-restrictive silencer element
# Required for both high-affinity DNA binding and pericentromeric heterochromatin localization
# Required for correct nuclear localization and exclusion from the nucleoli
# Required for cytoplasmic localization
# Required for cytoplasmic retention
# Required for cytoplasmic retention of the phosphorylated form
# Required for dimerization
# Required for formation of RAD51 foci
# Required for heterodimer formation with ARNT
# Required for heterodimer formation with EPAS1
# Required for heterodimer formation with HIF1A
# Required for heterodimerization with RXRA
# Required for high transcriptional activity of isoform Alpha-C3
# Required for homodimerization
# Required for homodimerization and interaction with NFYA
# Required for homodimerization and nuclear accumulation
# Required for induction of apoptosis
# Required for interaction with ASXL1/2/3
# Required for interaction with CTNNBL1
# Required for interaction with DAZ1
# Required for interaction with DHX9 and PRMT5
# Required for interaction with DVL2 and SUDS3
# Required for interaction with EHMT2
# Required for interaction with EP300 and CREBBP, and for transcriptional activation of target genes
# Required for interaction with FBXO42
# Required for interaction with FOXO1
# Required for interaction with FOXO4 and MEF2C
# Required for interaction with KAT2B
# Required for interaction with LDB1
# Required for interaction with MAPK8
# Required for interaction with MAPKs
# Required for interaction with MBD2
# Required for interaction with MBD3L2
# Required for interaction with MYCBP
# Required for interaction with NCOA1
# Required for interaction with NFYA
# Required for interaction with NMI
# Required for interaction with NR2C2
# Required for interaction with NRIP1
# Required for interaction with NuRD complex and for transcriptional repressor activity
# Required for interaction with PBX1
# Required for interaction with RB1
# Required for interaction with RELA
# Required for interaction with RUNX2
# Required for interaction with TBP and formation of a ternary complex with DNA and TBP
# Required for interaction with TGFBR1 and promotion of TGF-beta signaling
# Required for interaction with TLE6
# Required for interaction with TRIB1
# Required for interaction with TRIM28
# Required for interaction with TSC22D1
# Required for interaction with ZFPM1
# Required for interaction with ZNF385A
# Required for interaction with ZXDC
# Required for interaction with and acetylation by EP300
# Required for interaction with human adenovirus early E1A protein
# Required for interaction with nucleosomes and DNA
# Required for mRNA-binding
# Required for maintaining the overall integrity of the AHR:ARNT heterodimer and its transcriptional activity
# Required for mitochondrial import
# Required for nuclear body formation and for SUMO1 recruitment
# Required for nuclear export
# Required for nuclear import
# Required for nuclear localization
# Required for nuclear localization and apoptosis-inducing activity
# Required for nuclear localization and homodimerization
# Required for nuclear localization and interaction with KPNB1, NOTCH1 and PARP1
# Required for nucleolar localization
# Required for phospholipid binding and regulation of the substrate preference
# Required for phosphorylation by CSNK1E and cytoplasmic localization
# Required for protein stabilization induced by IL1B
# Required for repressor activity
# Required for sumoylation and localization to discrete nuclear foci
# Required for suppression of NFATC1-mediated transcription
# Required for the formation of a ternary complex with DNA and TBP; not required for interaction with TBP in the absence of DNA
# Required for the formation of higher order complexes of ZBED1 with consensus DNA binding sequences
# Required for the interaction with RXRA
# Required for transcription activation
# Required for transcriptional activation
# Required for transcriptional activation activity and synergistic coactivation of transcriptional activity with POU3F2
# Required for transcriptional inhibition
# Required for transcriptional repression
# Required for transcriptional repression activity; probably mediates sequence-specific DNA-binding
# Required for ubiquitin ligase activity
# Required to functionally cooperate with SREBF1 in promoter activation
# Required to induce adipocyte differentiation
# Required to promote HAND1 transcriptional activator activity
# Required to repress E2F1:TFDP1-mediated transcription, to inhibit cell cycle and to induce adipocyte differentiation
# Retinoblastoma protein binding
# SAD
# SAM2-like domain
# SMAD-MH2 binding domain
# SMAD-interaction domain (SID)
# SNAG domain
# SNAPC2-binding
# SNAPC5-binding
# Self-association
# Seven-bladed beta propeller repeats
# Spacer
# Strong transcription activation domain
# Subunit association domain (SAD)
# Sufficient for E3 SUMO-protein ligase activity
# Sufficient for activation of CTE-mediated expression
# Sufficient for binding to RE2 sequence motifs
# Sufficient for binding to genomic CpG islands
# Sufficient for heterodimer formation with BMAL1, E-box binding and for the effect of NADPH
# Sufficient for interaction with EP300
# Sufficient for interaction with KPNB1
# Sufficient for interaction with MAD2L2
# Sufficient for interaction with NLK
# Sufficient for interaction with UIMC1
# Sufficient for interaction with XPO4
# Sufficient for strong transactivation activity
# Sufficient for transactivation activity
# Sufficient to mediate interaction with ETS1
# Sufficient to mediate interaction with PAXBP1
# TAD1 (Acidic)
# TAD2
# TRFH dimerization
# TRFH mediates dimerization
# TRIAD supradomain
# Transactivation
# Transactivation AF-1; required for ligand-independent transactivation function
# Transactivation AF-2
# Transactivation AF-2; required for ligand-dependent transactivation function; mediates interaction with CCAR2
# Transactivation domain
# Transactivation domain (Gln-rich)
# Transactivation domain (TAC)
# Transactivation domain (TAM)
# Transactivation domain 1
# Transactivation domain 2
# Transactivation domain A (Gln-rich)
# Transactivation domain A (TAD-A)
# Transactivation domain B (Gln-rich)
# Transactivation domain B (TAD-B)
# Transactivation domain C (highly charged)
# Transactivation inhibition
# Transcription activation
# Transcription activation (acidic)
# Transcription activation domain (PubMed:2189102)
# Transcription repression
# Transcription repressor
# Transcriptional activation
# Transcriptional activation (acidic)
# Transcriptional activation domain
# Transcriptional activation domain 1
# Transcriptional activation domain 2
# Transcriptional activation domain 3
# Transcriptional repression and interaction with NCOR1 and SIN3A
# Transcriptional repression domain (TRD)
# Transcriptional repressor domain
# VCP/p97-interacting motif (VIM)
# VZV IE62-binding
# Winged helix-turn-helix (wHTH)
# ZAS1
# ZAS2
# zUBD/ZHA

# %%
for _ in uniprot_DBD_output["Region"].str.extractall(r'note="(.+?)"').reset_index().sort_values(by = 0)[0].unique():
    if "DNA" in _:
        print(_)
# Out:
# Basic (repression of DNA-binding)
# Binding to DNA
# Core promoter DNA-binding
# Critical for glycosaminoglycan, lipid A, lysozyme and DNA binding
# DNA replication foci-targeting sequence
# DNA-binding
# DNA-binding domain
# DNA-binding regulation
# DNA-binding; major groove
# DNA-binding; minor groove
# Important for DNA and nucleosome binding
# Important for flexibility of DNA ends that protrude from nucleosomes
# Important for interaction with target DNA
# Interaction with 5-mCpG DNA
# Interaction with DNA
# Interaction with ss-DNA
# Interaction with target DNA
# Involved in DNA-binding
# Mediates dimerization, DNA-binding, transcription repression of CCNA2 and interaction with HMGA2
# Mediates promoter DNA-binding and activation of transcription
# No DNA binding activity or transactivation activity, but complete prevention of TRAF-dependent NF-Kappa-B activation; associates with TRAF2 and JUN
# Required for DNA binding
# Required for DNA-PK heterotrimer
# Required for DNA-binding
# Required for DNA-binding and interaction with NFKBIA
# Required for DNA-binding and transcriptional repression
# Required for activation of histone H4 transcription and contributes to DNA-binding
# Required for binding NBRE-containing DNA
# Required for both high-affinity DNA binding and pericentromeric heterochromatin localization
# Required for interaction with TBP and formation of a ternary complex with DNA and TBP
# Required for interaction with nucleosomes and DNA
# Required for the formation of a ternary complex with DNA and TBP; not required for interaction with TBP in the absence of DNA
# Required for the formation of higher order complexes of ZBED1 with consensus DNA binding sequences
# Required for transcriptional repression activity; probably mediates sequence-specific DNA-binding

# %% [markdown]
# Keep the following regions:
#
# DNA-binding
# DNA-binding domain
# DNA-binding; major groove
# DNA-binding; minor groove

# %%
DNA_binding_region_terms = ["DNA-binding", "DNA-binding domain", "DNA-binding; major groove", "DNA-binding; minor groove"]
DNA_binding_region_terms
# Out:
# ['DNA-binding',
#  'DNA-binding domain',
#  'DNA-binding; major groove',
#  'DNA-binding; minor groove']

# %%
pat = r'(REGION (\d+\.\.\d+?); \/note="(.+?)"?;)'
string_to_search = 'REGION 1..22; /note="DNA-binding; minor groove"; /evidence="ECO:0000256|SAM:MobiDB-lite"; REGION 96..124; /note="Disordered"; /evidence="ECO:0000256|SAM:MobiDB-lite"'
print(string_to_search)
# Out:
# REGION 1..22; /note="DNA-binding; minor groove"; /evidence="ECO:0000256|SAM:MobiDB-lite"; REGION 96..124; /note="Disordered"; /evidence="ECO:0000256|SAM:MobiDB-lite"

# %%
re.findall(pat, string_to_search)
# Out:
# [('REGION 1..22; /note="DNA-binding;', '1..22', 'DNA-binding'),
#  ('REGION 96..124; /note="Disordered";', '96..124', 'Disordered')]

# %%
import numpy as np
np.nan
# Out:
# nan

# %%
DBD_list_func_joined
# Out:
#                  From   Entry   Entry Name      Function
# 0     ENSG00000001167  P23511   NFYA_HUMAN  [(296, 321)]
# 1     ENSG00000004848  Q96QS3    ARX_HUMAN  [(328, 387)]
# 2     ENSG00000005073  P31270  HXA11_HUMAN  [(241, 300)]
# 3     ENSG00000005102  P50221  MEOX1_HUMAN  [(171, 230)]
# 4     ENSG00000005513  P57073   SOX8_HUMAN  [(102, 170)]
# ...               ...     ...          ...           ...
# 1608  ENSG00000277258  P35227  PCGF2_HUMAN  [(nan, nan)]
# 1609  ENSG00000277462  Q9BS34  ZN670_HUMAN  [(nan, nan)]
# 1610  ENSG00000278129  P17098   ZNF8_HUMAN  [(nan, nan)]
# 1611  ENSG00000278318  Q9UJW7  ZN229_HUMAN  [(nan, nan)]
# 1612  ENSG00000278570  Q9Y5X4  NR2E3_HUMAN   [(44, 120)]
#
# [1613 rows x 4 columns]

# %%
region_DBDs = []

for i in uniprot_DBD_output.index:
    row_DBDs = []
    
    row = uniprot_DBD_output.iloc[i]
    region_descrip = row["Region"]
    pat = r'(REGION (\d+\.\.\d+?); \/note="(.+?)"?;)'
    regex_find = re.findall(pat, region_descrip)
    
    for find in regex_find:
        if find[2] in DNA_binding_region_terms:
            coords = find[1]
            start = re.search(r'(\d+)', coords)[0]
            end = re.search(r'\d+\.\.(\d+)', coords)[1]
            row_DBDs.append((start, end))
            
    if len(row_DBDs) == 0:
        row_DBDs.append((np.nan, np.nan))
    else:
        print(row["Entry Name"])
        print(row_DBDs)
        
        
    region_DBDs.append(row_DBDs)

uniprot_DBD_output["Region_extrac"] = region_DBDs
uniprot_DBD_output
# Out:
# P73_HUMAN
# [('131', '310')]
# ARNT_HUMAN
# [('88', '128')]
# AHR_HUMAN
# [('38', '66')]
# HSF1_HUMAN
# [('15', '120')]
# FOXK2_HUMAN
# [('300', '318'), ('328', '332'), ('348', '353')]
# PO5F1_HUMAN
# [('180', '186'), ('193', '196')]
# SUH_HUMAN
# [('57', '67'), ('165', '170'), ('192', '197')]
# FOXO1_HUMAN
# [('211', '218'), ('234', '237')]
# TFCP2_HUMAN
# [('133', '395')]
# HIF1A_HUMAN
# [('21', '30')]
# LIN54_HUMAN
# [('523', '536'), ('599', '612')]
# NPAS3_HUMAN
# [('53', '64')]
# PURB_HUMAN
# [('28', '254')]
# EPAS1_HUMAN
# [('26', '53')]
# PRDM9_HUMAN
# [('730', '820')]
# RBPJL_HUMAN
# [('78', '88'), ('193', '198'), ('220', '225')]
#                  From       Entry  Reviewed   Entry Name  \
# 0     ENSG00000233757  A0A087WUV0  reviewed  ZN892_HUMAN
# 1     ENSG00000129173      A0AVK6  reviewed   E2F8_HUMAN
# 2     ENSG00000128610      A0PJY2  reviewed  FEZF1_HUMAN
# 3     ENSG00000164334      A1A519  reviewed  F170A_HUMAN
# 4     ENSG00000184828      A1YPR0  reviewed  ZBT7C_HUMAN
# ...               ...         ...       ...          ...
# 1608  ENSG00000124151      Q9Y6Q9  reviewed  NCOA3_HUMAN
# 1609  ENSG00000128000      Q9Y6R6  reviewed  Z780B_HUMAN
# 1610  ENSG00000152217      Q9Y6X0  reviewed  SETBP_HUMAN
# 1611  ENSG00000178764      Q9Y6X8  reviewed   ZHX2_HUMAN
# 1612  ENSG00000171735      Q9Y6Y1  reviewed  CMTA1_HUMAN
#
#                                           Protein names  \
# 0                               Zinc finger protein 892
# 1                     Transcription factor E2F8 (E2F-8)
# 2     Fez family zinc finger protein 1 (Zinc finger ...
# 3     Protein FAM170A (Zinc finger domain-containing...
# 4     Zinc finger and BTB domain-containing protein ...
# ...                                                 ...
# 1608  Nuclear receptor coactivator 3 (NCoA-3) (EC 2....
# 1609  Zinc finger protein 780B (Zinc finger protein ...
# 1610                          SET-binding protein (SEB)
# 1611  Zinc fingers and homeoboxes protein 2 (Alpha-f...
# 1612       Calmodulin-binding transcription activator 1
#
#                          Gene Names              Organism  Length  \
# 0                            ZNF892  Homo sapiens (Human)     522
# 1                              E2F8  Homo sapiens (Human)     867
# 2                 FEZF1 FEZ ZNF312B  Homo sapiens (Human)     475
# 3                      FAM170A ZNFD  Homo sapiens (Human)     330
# 4        ZBTB7C APM1 ZBTB36 ZNF857C  Homo sapiens (Human)     619
# ...                             ...                   ...     ...
# 1608  NCOA3 AIB1 BHLHE42 RAC3 TRAM1  Homo sapiens (Human)    1424
# 1609                 ZNF780B ZNF779  Homo sapiens (Human)     833
# 1610                SETBP1 KIAA0437  Homo sapiens (Human)    1596
# 1611         ZHX2 AFR1 KIAA0854 RAF  Homo sapiens (Human)     837
# 1612        CAMTA1 KIAA0833 MSTP023  Homo sapiens (Human)    1673
#
#                                             DNA binding Coiled coil  \
# 0
# 1     DNA_BIND 113..182; /evidence="ECO:0000255"; DN...
# 2
# 3
# 4
# ...                                                 ...         ...
# 1608
# 1609
# 1610  DNA_BIND 584..596; /note="A.T hook 1"; DNA_BIN...
# 1611  DNA_BIND 263..324; /note="Homeobox 1"; /eviden...
# 1612  DNA_BIND 63..188; /note="CG-1"; /evidence="ECO...
#
#                                      Compositional bias  \
# 0     COMPBIAS 1..19; /note="Basic and acidic residu...
# 1     COMPBIAS 410..432; /note="Polar residues"; /ev...
# 2     COMPBIAS 436..466; /note="Pro residues"; /evid...
# 3     COMPBIAS 30..54; /note="Polar residues"; /evid...
# 4     COMPBIAS 130..176; /note="Acidic residues"; /e...
# ...                                                 ...
# 1608  COMPBIAS 503..520; /note="Polar residues"; /ev...
# 1609
# 1610  COMPBIAS 145..163; /note="Basic and acidic res...
# 1611  COMPBIAS 164..182; /note="Polar residues"; /ev...
# 1612  COMPBIAS 305..331; /note="Basic and acidic res...
#
#                                             Domain [CC]  \
# 0
# 1     DOMAIN: In contrast to classical members of th...
# 2
# 3     DOMAIN: The N-terminus is necessary for nuclea...
# 4
# ...                                                 ...
# 1608  DOMAIN: Contains three Leu-Xaa-Xaa-Leu-Leu (LX...
# 1609
# 1610
# 1611
# 1612
#
#                                             Domain [FT]  \
# 0
# 1
# 2
# 3
# 4     DOMAIN 34..101; /note="BTB"; /evidence="ECO:00...
# ...                                                 ...
# 1608  DOMAIN 25..82; /note="bHLH"; /evidence="ECO:00...
# 1609  DOMAIN 6..77; /note="KRAB"; /evidence="ECO:000...
# 1610
# 1611
# 1612  DOMAIN 875..953; /note="IPT/TIG"; /evidence="E...
#
#                                                  Region  \
# 0     REGION 1..22; /note="Disordered"; /evidence="E...
# 1     REGION 38..58; /note="Disordered"; /evidence="...
# 2     REGION 428..475; /note="Disordered"; /evidence...
# 3     REGION 1..54; /note="Disordered"; /evidence="E...
# 4     REGION 129..218; /note="Disordered"; /evidence...
# ...                                                 ...
# 1608  REGION 1..38; /note="Disordered"; /evidence="E...
# 1609
# 1610  REGION 1..83; /note="Disordered"; /evidence="E...
# 1611  REGION 27..77; /note="Interaction with EFNB1";...
# 1612  REGION 283..375; /note="Disordered"; /evidence...
#
#                                                  Repeat  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 1608
# 1609
# 1610  REPEAT 1520..1527; /note="1"; REPEAT 1528..153...
# 1611
# 1612  REPEAT 1064..1093; /note="ANK 1"; REPEAT 1109....
#
#                                    Protein families  \
# 0     Krueppel C2H2-type zinc-finger protein family
# 1                                     E2F/DP family
# 2     Krueppel C2H2-type zinc-finger protein family
# 3                                     FAM170 family
# 4
# ...                                             ...
# 1608   SRC/p160 nuclear receptor coactivator family
# 1609  Krueppel C2H2-type zinc-finger protein family
# 1610
# 1611                                     ZHX family
# 1612                                   CAMTA family
#
#                                                   Motif  \
# 0
# 1
# 2     MOTIF 28..43; /note="Engrailed homology 1 repr...
# 3
# 4
# ...                                                 ...
# 1608  MOTIF 685..689; /note="LXXLL motif 1"; MOTIF 7...
# 1609
# 1610
# 1611
# 1612  MOTIF 112..119; /note="Nuclear localization si...
#
#                                   Sequence similarities  \
# 0     SIMILARITY: Belongs to the krueppel C2H2-type ...
# 1     SIMILARITY: Belongs to the E2F/DP family. {ECO...
# 2     SIMILARITY: Belongs to the krueppel C2H2-type ...
# 3     SIMILARITY: Belongs to the FAM170 family. {ECO...
# 4
# ...                                                 ...
# 1608  SIMILARITY: Belongs to the SRC/p160 nuclear re...
# 1609  SIMILARITY: Belongs to the krueppel C2H2-type ...
# 1610
# 1611  SIMILARITY: Belongs to the ZHX family. {ECO:00...
# 1612  SIMILARITY: Belongs to the CAMTA family. {ECO:...
#
#                                             Zinc finger Region_extrac
# 0     ZN_FING 221..243; /note="C2H2-type 1"; /eviden...  [(nan, nan)]
# 1                                                        [(nan, nan)]
# 2     ZN_FING 260..282; /note="C2H2-type 1"; /eviden...  [(nan, nan)]
# 3       ZN_FING 228..252; /note="C2H2-type; degenerate"  [(nan, nan)]
# 4     ZN_FING 364..386; /note="C2H2-type 1"; /eviden...  [(nan, nan)]
# ...                                                 ...           ...
# 1608                                                     [(nan, nan)]
# 1609  ZN_FING 165..187; /note="C2H2-type 1"; /eviden...  [(nan, nan)]
# 1610                                                     [(nan, nan)]
# 1611  ZN_FING 78..101; /note="C2H2-type 1"; /evidenc...  [(nan, nan)]
# 1612                                                     [(nan, nan)]
#
# [1613 rows x 20 columns]

# %%
DBD_list_func_joined = pd.merge(DBD_list_func_joined, uniprot_DBD_output[["Entry", "Region_extrac"]], on = "Entry", how = "left")
DBD_list_func_joined
# Out:
#                  From   Entry   Entry Name      Function Region_extrac
# 0     ENSG00000001167  P23511   NFYA_HUMAN  [(296, 321)]  [(nan, nan)]
# 1     ENSG00000004848  Q96QS3    ARX_HUMAN  [(328, 387)]  [(nan, nan)]
# 2     ENSG00000005073  P31270  HXA11_HUMAN  [(241, 300)]  [(nan, nan)]
# 3     ENSG00000005102  P50221  MEOX1_HUMAN  [(171, 230)]  [(nan, nan)]
# 4     ENSG00000005513  P57073   SOX8_HUMAN  [(102, 170)]  [(nan, nan)]
# ...               ...     ...          ...           ...           ...
# 1608  ENSG00000277258  P35227  PCGF2_HUMAN  [(nan, nan)]  [(nan, nan)]
# 1609  ENSG00000277462  Q9BS34  ZN670_HUMAN  [(nan, nan)]  [(nan, nan)]
# 1610  ENSG00000278129  P17098   ZNF8_HUMAN  [(nan, nan)]  [(nan, nan)]
# 1611  ENSG00000278318  Q9UJW7  ZN229_HUMAN  [(nan, nan)]  [(nan, nan)]
# 1612  ENSG00000278570  Q9Y5X4  NR2E3_HUMAN   [(44, 120)]  [(nan, nan)]
#
# [1613 rows x 5 columns]

# %%
null_val = DBD_list_func_joined["Function"].value_counts().reset_index()["Function"].iloc[0]
null_val
# Out:
# [(nan, nan)]

# %%
null_val[0]
# Out:
# (nan, nan)

# %%
DBD_list_func_joined[[null_val[0] not in _ for _ in DBD_list_func_joined["Function"]] and [null_val[0] not in _ for _ in DBD_list_func_joined["Region_extrac"]]]
# Out:
#                  From   Entry   Entry Name      Function  \
# 105   ENSG00000078900  O15350    P73_HUMAN  [(nan, nan)]
# 158   ENSG00000100644  Q16665  HIF1A_HUMAN  [(nan, nan)]
# 229   ENSG00000106546  P35869    AHR_HUMAN  [(nan, nan)]
# 305   ENSG00000116016  Q99814  EPAS1_HUMAN  [(nan, nan)]
# 400   ENSG00000124232  Q9UBG7  RBPJL_HUMAN  [(nan, nan)]
# 533   ENSG00000135457  Q12800  TFCP2_HUMAN  [(nan, nan)]
# 602   ENSG00000141568  Q01167  FOXK2_HUMAN  [(258, 353)]
# 630   ENSG00000143437  P27540   ARNT_HUMAN  [(nan, nan)]
# 650   ENSG00000146676  Q96QR8   PURB_HUMAN  [(nan, nan)]
# 677   ENSG00000150907  Q12778  FOXO1_HUMAN  [(159, 235)]
# 679   ENSG00000151322  Q8IXF0  NPAS3_HUMAN  [(nan, nan)]
# 802   ENSG00000164256  Q9NQV7  PRDM9_HUMAN  [(nan, nan)]
# 887   ENSG00000168214  Q06330    SUH_HUMAN  [(nan, nan)]
# 1204  ENSG00000185122  Q00613   HSF1_HUMAN  [(nan, nan)]
# 1298  ENSG00000189308  Q6MZP7  LIN54_HUMAN  [(nan, nan)]
# 1463  ENSG00000204531  Q01860  PO5F1_HUMAN  [(230, 289)]
#
#                              Region_extrac
# 105                           [(131, 310)]
# 158                             [(21, 30)]
# 229                             [(38, 66)]
# 305                             [(26, 53)]
# 400     [(78, 88), (193, 198), (220, 225)]
# 533                           [(133, 395)]
# 602   [(300, 318), (328, 332), (348, 353)]
# 630                            [(88, 128)]
# 650                            [(28, 254)]
# 677               [(211, 218), (234, 237)]
# 679                             [(53, 64)]
# 802                           [(730, 820)]
# 887     [(57, 67), (165, 170), (192, 197)]
# 1204                           [(15, 120)]
# 1298              [(523, 536), (599, 612)]
# 1463              [(180, 186), (193, 196)]

# %%
filtered_list = [item for item in DBD_list_func_joined["Function"] if null_val[0] in item]

# %%
uniprot_DBD_output[uniprot_DBD_output["Entry Name"] == "SOX4_HUMAN"]["Region"].iloc[0]
# Out:
# 'REGION 1..58; /note="Disordered"; /evidence="ECO:0000256|SAM:MobiDB-lite"; REGION 128..228; /note="Disordered"; /evidence="ECO:0000256|SAM:MobiDB-lite"; REGION 262..286; /note="Disordered"; /evidence="ECO:0000256|SAM:MobiDB-lite"; REGION 302..416; /note="Disordered"; /evidence="ECO:0000256|SAM:MobiDB-lite"'

# %%
uniprot_DBD_output[uniprot_DBD_output["Entry Name"] == "SOX4_HUMAN"]["DNA binding"].iloc[0]
# Out:
# 'DNA_BIND 59..127; /note="HMG box"; /evidence="ECO:0000255|PROSITE-ProRule:PRU00267"'

# %%
# Checking how many DBDs found per TF
uniprot_DBD_output["DBD_count"] = uniprot_DBD_output["DNA binding"].str.count("DNA_BIND")
uniprot_DBD_output
# Out:
#                  From       Entry  Reviewed   Entry Name  \
# 0     ENSG00000233757  A0A087WUV0  reviewed  ZN892_HUMAN
# 1     ENSG00000129173      A0AVK6  reviewed   E2F8_HUMAN
# 2     ENSG00000128610      A0PJY2  reviewed  FEZF1_HUMAN
# 3     ENSG00000164334      A1A519  reviewed  F170A_HUMAN
# 4     ENSG00000184828      A1YPR0  reviewed  ZBT7C_HUMAN
# ...               ...         ...       ...          ...
# 1608  ENSG00000124151      Q9Y6Q9  reviewed  NCOA3_HUMAN
# 1609  ENSG00000128000      Q9Y6R6  reviewed  Z780B_HUMAN
# 1610  ENSG00000152217      Q9Y6X0  reviewed  SETBP_HUMAN
# 1611  ENSG00000178764      Q9Y6X8  reviewed   ZHX2_HUMAN
# 1612  ENSG00000171735      Q9Y6Y1  reviewed  CMTA1_HUMAN
#
#                          Gene Names  \
# 0                            ZNF892
# 1                              E2F8
# 2                 FEZF1 FEZ ZNF312B
# 3                      FAM170A ZNFD
# 4        ZBTB7C APM1 ZBTB36 ZNF857C
# ...                             ...
# 1608  NCOA3 AIB1 BHLHE42 RAC3 TRAM1
# 1609                 ZNF780B ZNF779
# 1610                SETBP1 KIAA0437
# 1611         ZHX2 AFR1 KIAA0854 RAF
# 1612        CAMTA1 KIAA0833 MSTP023
#
#                                             DNA binding  DBD_count
# 0                                                   NaN        NaN
# 1     DNA_BIND 113..182; /evidence="ECO:0000255"; DN...        2.0
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 1608                                                NaN        NaN
# 1609                                                NaN        NaN
# 1610  DNA_BIND 584..596; /note="A.T hook 1"; DNA_BIN...        3.0
# 1611  DNA_BIND 263..324; /note="Homeobox 1"; /eviden...        4.0
# 1612  DNA_BIND 63..188; /note="CG-1"; /evidence="ECO...        1.0
#
# [1613 rows x 7 columns]

# %%
# Extracting DBDs and saving as integers

# One row per DBD
uniprot_DBD_output["DBD_split"] = uniprot_DBD_output["DNA binding"].str.split("DNA_BIND")
DBDs = uniprot_DBD_output.explode("DBD_split")
DBDs = DBDs.dropna()
DBDs
# Out:
#                  From   Entry  Reviewed   Entry Name               Gene Names  \
# 1     ENSG00000129173  A0AVK6  reviewed   E2F8_HUMAN                     E2F8
# 1     ENSG00000129173  A0AVK6  reviewed   E2F8_HUMAN                     E2F8
# 1     ENSG00000129173  A0AVK6  reviewed   E2F8_HUMAN                     E2F8
# 6     ENSG00000188816  A2RU54  reviewed   HMX2_HUMAN                     HMX2
# 6     ENSG00000188816  A2RU54  reviewed   HMX2_HUMAN                     HMX2
# ...               ...     ...       ...          ...                      ...
# 1611  ENSG00000178764  Q9Y6X8  reviewed   ZHX2_HUMAN   ZHX2 AFR1 KIAA0854 RAF
# 1611  ENSG00000178764  Q9Y6X8  reviewed   ZHX2_HUMAN   ZHX2 AFR1 KIAA0854 RAF
# 1611  ENSG00000178764  Q9Y6X8  reviewed   ZHX2_HUMAN   ZHX2 AFR1 KIAA0854 RAF
# 1612  ENSG00000171735  Q9Y6Y1  reviewed  CMTA1_HUMAN  CAMTA1 KIAA0833 MSTP023
# 1612  ENSG00000171735  Q9Y6Y1  reviewed  CMTA1_HUMAN  CAMTA1 KIAA0833 MSTP023
#
#                                             DNA binding  DBD_count  \
# 1     DNA_BIND 113..182; /evidence="ECO:0000255"; DN...        2.0
# 1     DNA_BIND 113..182; /evidence="ECO:0000255"; DN...        2.0
# 1     DNA_BIND 113..182; /evidence="ECO:0000255"; DN...        2.0
# 6     DNA_BIND 149..208; /note="Homeobox"; /evidence...        1.0
# 6     DNA_BIND 149..208; /note="Homeobox"; /evidence...        1.0
# ...                                                 ...        ...
# 1611  DNA_BIND 263..324; /note="Homeobox 1"; /eviden...        4.0
# 1611  DNA_BIND 263..324; /note="Homeobox 1"; /eviden...        4.0
# 1611  DNA_BIND 263..324; /note="Homeobox 1"; /eviden...        4.0
# 1612  DNA_BIND 63..188; /note="CG-1"; /evidence="ECO...        1.0
# 1612  DNA_BIND 63..188; /note="CG-1"; /evidence="ECO...        1.0
#
#                                               DBD_split
# 1
# 1                   113..182; /evidence="ECO:0000255";
# 1                     261..347; /evidence="ECO:0000255"
# 6
# 6      149..208; /note="Homeobox"; /evidence="ECO:00...
# ...                                                 ...
# 1611   439..501; /note="Homeobox 2"; /evidence="ECO:...
# 1611   530..591; /note="Homeobox 3"; /evidence="ECO:...
# 1611   628..690; /note="Homeobox 4"; /evidence="ECO:...
# 1612
# 1612   63..188; /note="CG-1"; /evidence="ECO:0000255...
#
# [1113 rows x 8 columns]

# %%
# Formatting, regex to extact DBDs
DBDs["Start"] = DBDs["DBD_split"].str.extract(r'(\d*)\.\.')
DBDs["End"] = DBDs["DBD_split"].str.extract(r'\d*\.\.(\d*)')
DBDs = DBDs[["From", "Start", "End"]]
DBDs = DBDs.rename(columns = {"From" : "Gene Information"})
DBDs = DBDs.dropna()
DBDs["Start"] = DBDs["Start"].astype(int)
DBDs["End"] = DBDs["End"].astype(int)
DBDs = DBDs.drop_duplicates()
DBDs
# Out:
#      Gene Information  Start  End
# 1     ENSG00000129173    113  182
# 1     ENSG00000129173    261  347
# 6     ENSG00000188816    149  208
# 8     ENSG00000180053    132  191
# 11    ENSG00000204595     16   75
# ...               ...    ...  ...
# 1611  ENSG00000178764    263  324
# 1611  ENSG00000178764    439  501
# 1611  ENSG00000178764    530  591
# 1611  ENSG00000178764    628  690
# 1612  ENSG00000171735     63  188
#
# [598 rows x 3 columns]

# %%
# Merging back to original Lambert TF table
lambert_TFs_with_DBDs = pd.merge(lambert_TFs, DBDs, how = "left")
lambert_TFs_with_DBDs
# Out:
#      Gene Information Unnamed: 1   Unnamed: 2 Is TF?  \
# 0     ENSG00000137203     TFAP2A         AP-2    Yes
# 1     ENSG00000008196     TFAP2B         AP-2    Yes
# 2     ENSG00000087510     TFAP2C         AP-2    Yes
# 3     ENSG00000008197     TFAP2D         AP-2    Yes
# 4     ENSG00000116819     TFAP2E         AP-2    Yes
# ...               ...        ...          ...    ...
# 1717  ENSG00000177683      THAP5  THAP finger    Yes
# 1718  ENSG00000174796      THAP6  THAP finger    Yes
# 1719  ENSG00000184436      THAP7  THAP finger    Yes
# 1720  ENSG00000161277      THAP8  THAP finger    Yes
# 1721  ENSG00000168152      THAP9  THAP finger    Yes
#
#                         Final Assesment                 Unnamed: 5  \
# 0                           Known motif  1 Monomer or homomultimer
# 1                           Known motif  1 Monomer or homomultimer
# 2                           Known motif  1 Monomer or homomultimer
# 3                           Known motif  1 Monomer or homomultimer
# 4                           Known motif  1 Monomer or homomultimer
# ...                                 ...                        ...
# 1717  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1718  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1719  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1720  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1721  Likely to be sequence specific TF  1 Monomer or homomultimer
#
#                     Unnamed: 6  \
# 0     High-throughput in vitro
# 1     High-throughput in vitro
# 2     High-throughput in vitro
# 3          In vivo/Misc source
# 4     High-throughput in vitro
# ...                        ...
# 1717                  No motif
# 1718                  No motif
# 1719                  No motif
# 1720                  No motif
# 1721                  No motif
#
#                                              Unnamed: 7  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Only known motifs are from Transfac or HocoMoc...
# 4                                                   NaN
# ...                                                 ...
# 1717                                                NaN
# 1718                                                NaN
# 1719                                                NaN
# 1720                                                NaN
# 1721                                                NaN
#
#                                              Unnamed: 8  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Binds the same GCCTGAGGC sequence as the other...
# 4                                                   NaN
# ...                                                 ...
# 1717                                                NaN
# 1718                                                NaN
# 1719                                                NaN
# 1720                                                NaN
# 1721  Human THAP9 Gene Encodes an Active P-Element D...
#
#      Notes from re-reviewed genes  ...                            Unnamed: 24  \
# 0                             NaN  ...                                    NaN
# 1                             NaN  ...                                    NaN
# 2                             NaN  ...                                    NaN
# 3                             NaN  ...    Source of Hocomoco motif is unclear
# 4                             NaN  ...                                    NaN
# ...                           ...  ...                                    ...
# 1717                          NaN  ...                                    NaN
# 1718                          NaN  ...                                    NaN
# 1719                          NaN  ...                                    NaN
# 1720                          NaN  ...  PMID: 12575992 says it has unique DBD
# 1721                          NaN  ...                                    NaN
#
#                                 Unnamed: 25 Prior classifications Unnamed: 27  \
# 0                                       NaN                     a         Yes
# 1                                       NaN                     a         Yes
# 2                                       NaN                     a         Yes
# 3                                       NaN                     a         Yes
# 4                                       NaN                     a         Yes
# ...                                     ...                   ...         ...
# 1717                                    NaN                     c         Yes
# 1718                                    NaN                     c         Yes
# 1719                                    NaN                     c         Yes
# 1720  need revisit as it has C2CH signature                     c         Yes
# 1721                                    NaN                     c         Yes
#
#      Unnamed: 28                                        Unnamed: 29  \
# 0            Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# 1            Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# 2            Yes                                                 No
# 3            Yes                                                 No
# 4            Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# ...          ...                                                ...
# 1717         Yes                                                 No
# 1718         Yes                                                 No
# 1719         Yes                                                 No
# 1720         Yes                                                 No
# 1721         Yes                                                 No
#
#      Unnamed: 30 Unnamed: 31 Start End
# 0            Yes         NaN   NaN NaN
# 1            Yes         NaN   NaN NaN
# 2            Yes         NaN   NaN NaN
# 3            Yes         NaN   NaN NaN
# 4            Yes         NaN   NaN NaN
# ...          ...         ...   ...  ..
# 1717          No         NaN   NaN NaN
# 1718          No         NaN   NaN NaN
# 1719          No         NaN   NaN NaN
# 1720          No         NaN   NaN NaN
# 1721          No         NaN   NaN NaN
#
# [1722 rows x 34 columns]

# %%
len(set(lambert_TFs_with_DBDs[lambert_TFs_with_DBDs["Start"].isna()]["Gene Information"]))
# Out:
# 1124

# %%
len(set(lambert_TFs_with_DBDs[~lambert_TFs_with_DBDs["Start"].isna()]["Gene Information"]))
# Out:
# 515

# %%
len(lambert_TFs)
# Out:
# 1639

# %%
lambert_TFs_with_DBDs.to_csv("../output/lambert_TFs_with_uniprot_DBDs.csv")

# %%
DBDs_found = lambert_TFs_with_DBDs[~lambert_TFs_with_DBDs["Start"].isna()]
DBDs_found
# Out:
#      Gene Information Unnamed: 1        Unnamed: 2 Is TF?  \
# 11    ENSG00000189079      ARID2  ARID/BRIGHT; RFX    Yes
# 12    ENSG00000153207     AHCTF1           AT hook    Yes
# 13    ENSG00000126705      AHDC1           AT hook    Yes
# 14    ENSG00000126705      AHDC1           AT hook    Yes
# 15    ENSG00000106948       AKNA           AT hook    Yes
# ...               ...        ...               ...    ...
# 1701  ENSG00000149922       TBX6             T-box    Yes
# 1706  ENSG00000187079      TEAD1               TEA    Yes
# 1707  ENSG00000074219      TEAD2               TEA    Yes
# 1708  ENSG00000007866      TEAD3               TEA    Yes
# 1709  ENSG00000197905      TEAD4               TEA    Yes
#
#                         Final Assesment                 Unnamed: 5  \
# 11    Likely to be sequence specific TF  1 Monomer or homomultimer
# 12    Likely to be sequence specific TF  1 Monomer or homomultimer
# 13    Likely to be sequence specific TF  1 Monomer or homomultimer
# 14    Likely to be sequence specific TF  1 Monomer or homomultimer
# 15    Likely to be sequence specific TF  1 Monomer or homomultimer
# ...                                 ...                        ...
# 1701                        Known motif  1 Monomer or homomultimer
# 1706                        Known motif  1 Monomer or homomultimer
# 1707                        Known motif  1 Monomer or homomultimer
# 1708                        Known motif  1 Monomer or homomultimer
# 1709                        Known motif  1 Monomer or homomultimer
#
#                     Unnamed: 6 Unnamed: 7  \
# 11                    No motif        NaN
# 12                    No motif        NaN
# 13                    No motif        NaN
# 14                    No motif        NaN
# 15                    No motif        NaN
# ...                        ...        ...
# 1701  High-throughput in vitro        NaN
# 1706  High-throughput in vitro        NaN
# 1707  High-throughput in vitro        NaN
# 1708  High-throughput in vitro        NaN
# 1709  High-throughput in vitro        NaN
#
#                                              Unnamed: 8  \
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15    Binds AT-rich promoters of CD40 and CD40L and ...
# ...                                                 ...
# 1701                                                NaN
# 1706                                                NaN
# 1707                                                NaN
# 1708                                                NaN
# 1709                                                NaN
#
#      Notes from re-reviewed genes  ...  \
# 11                            NaN  ...
# 12                            NaN  ...
# 13                            NaN  ...
# 14                            NaN  ...
# 15                            NaN  ...
# ...                           ...  ...
# 1701                          NaN  ...
# 1706                          NaN  ...
# 1707                          NaN  ...
# 1708                          NaN  ...
# 1709                          NaN  ...
#
#                                             Unnamed: 24  \
# 11                                                  NaN
# 12    Recruits nucleoporins to chromatin [PMID: 1723...
# 13                                                  NaN
# 14                                                  NaN
# 15    Debatable - binds AT-rich promoters of CD40 an...
# ...                                                 ...
# 1701                                                NaN
# 1706                                                NaN
# 1707                                                NaN
# 1708                                                NaN
# 1709  Hocomoco and transfac models are probably base...
#
#                                             Unnamed: 25 Prior classifications  \
# 11                                                  NaN                     x
# 12                Should not be initial assessment 1a1?                     c
# 13                                                  NaN                     x
# 14                                                  NaN                     x
# 15    Debatable - binds AT-rich promoters of CD40 an...                     c
# ...                                                 ...                   ...
# 1701                                                NaN                     a
# 1706                                                NaN                     a
# 1707                                                NaN                     a
# 1708                                                NaN                     a
# 1709                                                NaN                     a
#
#      Unnamed: 27 Unnamed: 28  \
# 11           Yes         Yes
# 12            No          No
# 13            No          No
# 14            No          No
# 15            No          No
# ...          ...         ...
# 1701         Yes         Yes
# 1706         Yes         Yes
# 1707         Yes         Yes
# 1708         Yes         Yes
# 1709         Yes         Yes
#
#                                             Unnamed: 29 Unnamed: 30  \
# 11    TF Gene_Transcription Factor Binding: tf co-fa...          No
# 12                                                   No          No
# 13                                                   No          No
# 14                                                   No          No
# 15                                                   No         Yes
# ...                                                 ...         ...
# 1701  TF Gene_DNA-Binding: sequence-specific_DNA Bin...          No
# 1706                                                 No          No
# 1707  TF Gene_DNA-Binding: sequence-specific_DNA Bin...         Yes
# 1708                                                 No          No
# 1709  TF Gene_DNA-Binding: sequence-specific_DNA Bin...          No
#
#      Unnamed: 31   Start     End
# 11           NaN   524.0   603.0
# 12           NaN  1971.0  1983.0
# 13           NaN   396.0   408.0
# 14           NaN   544.0   556.0
# 15           NaN  1115.0  1123.0
# ...          ...     ...     ...
# 1701         NaN   100.0   273.0
# 1706         NaN    28.0   104.0
# 1707         NaN    38.0   114.0
# 1708         NaN    28.0   104.0
# 1709         NaN    36.0   112.0
#
# [598 rows x 34 columns]

# %%
DBDs_not_found = lambert_TFs_with_DBDs[lambert_TFs_with_DBDs["Start"].isna()]
DBDs_not_found
# Out:
#      Gene Information Unnamed: 1   Unnamed: 2 Is TF?  \
# 0     ENSG00000137203     TFAP2A         AP-2    Yes
# 1     ENSG00000008196     TFAP2B         AP-2    Yes
# 2     ENSG00000087510     TFAP2C         AP-2    Yes
# 3     ENSG00000008197     TFAP2D         AP-2    Yes
# 4     ENSG00000116819     TFAP2E         AP-2    Yes
# ...               ...        ...          ...    ...
# 1717  ENSG00000177683      THAP5  THAP finger    Yes
# 1718  ENSG00000174796      THAP6  THAP finger    Yes
# 1719  ENSG00000184436      THAP7  THAP finger    Yes
# 1720  ENSG00000161277      THAP8  THAP finger    Yes
# 1721  ENSG00000168152      THAP9  THAP finger    Yes
#
#                         Final Assesment                 Unnamed: 5  \
# 0                           Known motif  1 Monomer or homomultimer
# 1                           Known motif  1 Monomer or homomultimer
# 2                           Known motif  1 Monomer or homomultimer
# 3                           Known motif  1 Monomer or homomultimer
# 4                           Known motif  1 Monomer or homomultimer
# ...                                 ...                        ...
# 1717  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1718  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1719  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1720  Likely to be sequence specific TF  1 Monomer or homomultimer
# 1721  Likely to be sequence specific TF  1 Monomer or homomultimer
#
#                     Unnamed: 6  \
# 0     High-throughput in vitro
# 1     High-throughput in vitro
# 2     High-throughput in vitro
# 3          In vivo/Misc source
# 4     High-throughput in vitro
# ...                        ...
# 1717                  No motif
# 1718                  No motif
# 1719                  No motif
# 1720                  No motif
# 1721                  No motif
#
#                                              Unnamed: 7  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Only known motifs are from Transfac or HocoMoc...
# 4                                                   NaN
# ...                                                 ...
# 1717                                                NaN
# 1718                                                NaN
# 1719                                                NaN
# 1720                                                NaN
# 1721                                                NaN
#
#                                              Unnamed: 8  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Binds the same GCCTGAGGC sequence as the other...
# 4                                                   NaN
# ...                                                 ...
# 1717                                                NaN
# 1718                                                NaN
# 1719                                                NaN
# 1720                                                NaN
# 1721  Human THAP9 Gene Encodes an Active P-Element D...
#
#      Notes from re-reviewed genes  ...                            Unnamed: 24  \
# 0                             NaN  ...                                    NaN
# 1                             NaN  ...                                    NaN
# 2                             NaN  ...                                    NaN
# 3                             NaN  ...    Source of Hocomoco motif is unclear
# 4                             NaN  ...                                    NaN
# ...                           ...  ...                                    ...
# 1717                          NaN  ...                                    NaN
# 1718                          NaN  ...                                    NaN
# 1719                          NaN  ...                                    NaN
# 1720                          NaN  ...  PMID: 12575992 says it has unique DBD
# 1721                          NaN  ...                                    NaN
#
#                                 Unnamed: 25 Prior classifications Unnamed: 27  \
# 0                                       NaN                     a         Yes
# 1                                       NaN                     a         Yes
# 2                                       NaN                     a         Yes
# 3                                       NaN                     a         Yes
# 4                                       NaN                     a         Yes
# ...                                     ...                   ...         ...
# 1717                                    NaN                     c         Yes
# 1718                                    NaN                     c         Yes
# 1719                                    NaN                     c         Yes
# 1720  need revisit as it has C2CH signature                     c         Yes
# 1721                                    NaN                     c         Yes
#
#      Unnamed: 28                                        Unnamed: 29  \
# 0            Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# 1            Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# 2            Yes                                                 No
# 3            Yes                                                 No
# 4            Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# ...          ...                                                ...
# 1717         Yes                                                 No
# 1718         Yes                                                 No
# 1719         Yes                                                 No
# 1720         Yes                                                 No
# 1721         Yes                                                 No
#
#      Unnamed: 30 Unnamed: 31 Start End
# 0            Yes         NaN   NaN NaN
# 1            Yes         NaN   NaN NaN
# 2            Yes         NaN   NaN NaN
# 3            Yes         NaN   NaN NaN
# 4            Yes         NaN   NaN NaN
# ...          ...         ...   ...  ..
# 1717          No         NaN   NaN NaN
# 1718          No         NaN   NaN NaN
# 1719          No         NaN   NaN NaN
# 1720          No         NaN   NaN NaN
# 1721          No         NaN   NaN NaN
#
# [1124 rows x 34 columns]

# %%
DBDs_not_found.columns
# Out:
# Index(['Gene Information', 'Unnamed: 1', 'Unnamed: 2', 'Is TF?',
#        'Final Assesment', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Notes from re-reviewed genes', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Curator Disagreement Flags', 'Unnamed: 15', 'Curator 1', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Curator 2', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Prior classifications',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Start', 'End'],
#       dtype='object')

# %%
pd.read_csv("../data/DBDs/S3_41576_2009_BFnrg2538_MOESM6_ESM.txt", header = 7, sep = "\t")
# Out:
#      Class       Ensembl ID                                           IPI ID  \
# 0        a  ENSG00000001167                          IPI00218470;IPI00333568
# 1        a  ENSG00000004848                                      IPI00045066
# 2        a  ENSG00000005073                          IPI00010754;IPI00807582
# 3        a  ENSG00000005513                          IPI00299069;IPI00386303
# 4        a  ENSG00000005889  IPI00012336;IPI00169385;IPI00179465;IPI00607877
# ...    ...              ...                                              ...
# 1982     x  ENSG00000215812                                      IPI00874268
# 1983     x  ENSG00000215887                                      IPI00873740
# 1984     x  ENSG00000218788                                      IPI00902657
# 1985     x  ENSG00000219340                                      IPI00397740
# 1986     x  ENSG00000219492                                      IPI00902447
#
#                                  Interpro DBD Interpro DNA-binding family  \
# 0                                         NaN                   IPR001289
# 1     IPR000047;IPR001356;IPR009057;IPR012287                         NaN
# 2               IPR001356;IPR009057;IPR012287                         NaN
# 3                         IPR000910;IPR009071                         NaN
# 4                         IPR007087;IPR015880                   IPR006794
# ...                                       ...                         ...
# 1982                      IPR007087;IPR015880                         NaN
# 1983                      IPR007087;IPR015880                         NaN
# 1984            IPR004826;IPR004827;IPR008917                         NaN
# 1985                      IPR007087;IPR015880                         NaN
# 1986                      IPR007087;IPR015880                         NaN
#
#      HGNC symbol Tissue-specificity
# 0           NFYA                NaN
# 1            ARX                NaN
# 2         HOXA11             uterus
# 3           SOX8                NaN
# 4            ZFX            general
# ...          ...                ...
# 1982         NaN                NaN
# 1983         NaN                NaN
# 1984         NaN                NaN
# 1985         NaN                NaN
# 1986         NaN                NaN
#
# [1987 rows x 7 columns]
