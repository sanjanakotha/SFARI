# %%
# %load_ext autoreload

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %autoreload 2
# %aimport AD_predictor_tools
# %aimport AD_comparison_tools
# %aimport PlottingTools

# %%
SFARI_Gene = pd.read_csv("../data/SFARI-Gene_genes_01-23-2023release_03-21-2023export.csv")
SFARI_Gene
# Out:
#       status gene-symbol                                          gene-name  \
# 0          9        ABAT                   4-aminobutyrate aminotransferase
# 1          9      ABCA10  ATP-binding cassette, sub-family A (ABC1), mem...
# 2          9      ABCA13         ATP binding cassette subfamily A member 13
# 3          9       ABCA7  ATP-binding cassette, sub-family A (ABC1), mem...
# 4          9        ABL2  ABL proto-oncogene 2, non-receptor tyrosine ki...
# ...      ...         ...                                                ...
# 1113       9      ZNF774                            Zinc finger protein 774
# 1114       9     ZNF804A                           Zinc finger protein 804A
# 1115       9      ZNF827                            Zinc finger protein 827
# 1116       9      ZSWIM6                 zinc finger SWIM-type containing 6
# 1117       9      ZWILCH                          zwilchkinetochore protein
#
#            ensembl-id chromosome  \
# ...

# %%
SFARI_Gene[SFARI_Gene["ensembl-id"].isna()]
# Out:
#      status     gene-symbol  \
# 11        9             ADA
# 66        9              AR
# 559       9        MAPT-AS1
# 583       9             MET
# 588       9          MIR137
# 631       9         MSNP1AS
# 792       9       PTCHD1-AS
# 847       9  RP11-1407O15.2
# 871       9     RPS10P2-AS1
#
#                                              gene-name ensembl-id chromosome  \
# 11                                 adenosine deaminase        NaN         20
# 66                                   androgen receptor        NaN          X
# 559                               MAPT antisense RNA 1        NaN         17
# 583  met proto-oncogene (hepatocyte growth factor r...        NaN          7
# 588                                       microRNA 137        NaN          1
# 631                      Moesinpseudogene 1, antisense        NaN          5
# 792                 PTCHD1antisense RNA (head to head)        NaN          X
# ...

# %%
# Redownloading lambert TFs from uniprot.

# First, downloaded tables s1-s4 from lambert review
lambert_table_s1 = pd.read_excel(open('../data/lambert_supp_tables.xlsx', 'rb'),
                               sheet_name='Table S1. Related to Figure 1B')
# Keeping TF rows
lambert_table_s1_TF_rows = lambert_table_s1[lambert_table_s1["Is TF?"] == "Yes"]
lambert_table_s1_TF_rows
# Out:
#      Gene Information Unnamed: 1   Unnamed: 2 Is TF?  \
# 1     ENSG00000137203     TFAP2A         AP-2    Yes
# 2     ENSG00000008196     TFAP2B         AP-2    Yes
# 3     ENSG00000087510     TFAP2C         AP-2    Yes
# 4     ENSG00000008197     TFAP2D         AP-2    Yes
# 5     ENSG00000116819     TFAP2E         AP-2    Yes
# ...               ...        ...          ...    ...
# 2760  ENSG00000177683      THAP5  THAP finger    Yes
# 2761  ENSG00000174796      THAP6  THAP finger    Yes
# 2762  ENSG00000184436      THAP7  THAP finger    Yes
# 2763  ENSG00000161277      THAP8  THAP finger    Yes
# 2764  ENSG00000168152      THAP9  THAP finger    Yes
#
#                         Final Assesment                 Unnamed: 5  \
# 1                           Known motif  1 Monomer or homomultimer
# 2                           Known motif  1 Monomer or homomultimer
# 3                           Known motif  1 Monomer or homomultimer
# ...

# %%
lambert_TF_ensg_codes = lambert_table_s1_TF_rows["Gene Information"]
lambert_TF_ensg_codes
# Out:
# 1       ENSG00000137203
# 2       ENSG00000008196
# 3       ENSG00000087510
# 4       ENSG00000008197
# 5       ENSG00000116819
#              ...
# 2760    ENSG00000177683
# 2761    ENSG00000174796
# 2762    ENSG00000184436
# 2763    ENSG00000161277
# 2764    ENSG00000168152
# Name: Gene Information, Length: 1639, dtype: object

# %%
# Rows of SFARI Gene with ENSG codes in lambert TFs
SFARI_TFs = SFARI_Gene[SFARI_Gene["ensembl-id"].isin(lambert_TF_ensg_codes)]
SFARI_TFs
# Out:
#       status gene-symbol                                         gene-name  \
# 16         9        ADNP        Activity-dependent neuroprotector homeobox
# 31         9       AHDC1            AT-hook DNA binding motif containing 1
# 60         9       ARID2                      AT-rich interaction domain 2
# 61         9       ARNT2  aryl-hydrocarbon receptor nuclear translocator 2
# 62         9         ARX                       aristaless related homeobox
# ...      ...         ...                                               ...
# 1111       9      ZNF711                           zinc finger protein 711
# 1112       9      ZNF713                           Zinc finger protein 713
# 1113       9      ZNF774                           Zinc finger protein 774
# 1114       9     ZNF804A                          Zinc finger protein 804A
# 1115       9      ZNF827                           Zinc finger protein 827
#
#            ensembl-id chromosome  \
# ...

# %%
import numpy as np
from scipy.stats import hypergeom
import matplotlib.pyplot as plt

# %%
k = 1118 ## Number of SFARI Genes
m = 1639 ## Number of TFs
N = 20000 ## Total number of genes 
n = N - m ## Number of non TF genes
x = 126 ## Number of SFARI TFs

# Python
hypergeom(M=N, 
                n=m, 
                N=k).sf(x-1)
# Out:
# 0.00013579589468489987

# %%
SFARI_gene_category_counts = dict(SFARI_Gene["gene-score"].value_counts())
SFARI_gene_category_counts
# Out:
# {2.0: 699, 1.0: 232, 3.0: 97}

# %%
SFARI_TFs_cateogry_counts = dict(SFARI_TFs["gene-score"].value_counts())
SFARI_TFs_cateogry_counts
# Out:
# {2.0: 57, 1.0: 51, 3.0: 8}

# %%
def return_p_val(category):
    k = SFARI_gene_category_counts[category] ## Number of SFARI category Genes
    m = 1639 ## Number of TFs
    N = 20000 ## Total number of genes 
    n = N - m ## Number of non TF genes
    x = SFARI_TFs_cateogry_counts[category] ## Number of SFARI TFs

    print("There are " + str(x) + " TFs out of " + str(k) + " Category " + str(category) + " Genes")
    
    # Python
    print(hypergeom(M=N, 
                    n=m, 
                    N=k).sf(x-1))

# %%
return_p_val(1)
# Out:
# There are 51 TFs out of 232 Category 1 Genes
# 5.610522037071283e-11

# %%
return_p_val(2)
# Out:
# There are 57 TFs out of 699 Category 2 Genes
# 0.5365914889839618

# %%
return_p_val(3)
# Out:
# There are 8 TFs out of 97 Category 3 Genes
# 0.5459567503411658

# %%
51/232
# Out:
# 0.21982758620689655

# %%
8/ 97
# Out:
# 0.08247422680412371

# %%
57/699
# Out:
# 0.0815450643776824

# %%
1639 / 20000
# Out:
# 0.08195

# %%
hypergeom.sf(x-1, M = 20000, n = 126, N = 1118)
