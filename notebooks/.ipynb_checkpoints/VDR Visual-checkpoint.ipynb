# %%
import pandas as pd
import numpy as np
from dna_features_viewer import GraphicFeature, GraphicRecord
import matplotlib.pyplot as plt
import gffpandas.gffpandas as gffpd

# %% [markdown]
# ## VDR Analysis
#
# Goal: Create a visual overlapping VDR with
# - Uniprot PFam domains
# - AD screen Stanford + Soto + GSL
# - SFARI gene mutations
# - (later) gNOMAD
# - (later) ClinVar
# - (later) alphafold
# - (later) cosmic

# %% [markdown]
# Will use dna_features_viewer from https://pypi.org/project/dna-features-viewer/ to plot

# %%
features=[
    GraphicFeature(start=0, end=20, strand=+1, color="#ffd700",
                   label="Small feature"),
    GraphicFeature(start=20, end=500, strand=+1, color="#ffcccc",
                   label="Gene 1 with a very long name"),
    GraphicFeature(start=400, end=700, strand=-1, color="#cffccc",
                   label="Gene 2"),
    GraphicFeature(start=600, end=900, strand=+1, color="#ccccff",
                   label="Gene 3")
]

fig, ax1 = plt.subplots(figsize = (12,1), dpi = 300)

record = GraphicRecord(sequence_length=1000, features=features)
record.plot(ax = ax1, figure_width=5);

# %% [markdown]
# 1. Downloading regions from Uniprot and reading in the gff file as a dataframe.
# https://www.uniprot.org/uniprotkb/P11473/entry

# %%
VDR_regions = gffpd.read_gff3('../data/P11473.gff').df
VDR_regions.reset_index(inplace = True)
new_col_names = list(VDR_regions.columns[1:])
new_col_names.append("drop")
VDR_regions.set_axis(new_col_names, axis = 1, inplace = True)
VDR_regions.drop(columns = ["drop"], inplace = True)
VDR_regions
# Out:
#     seq_id     source         type  start  end score strand phase  \
# 0   P11473  UniProtKB        Chain      1  427     .      .     .
# 1   P11473  UniProtKB       Domain    127  423     .      .     .
# 2   P11473  UniProtKB  DNA binding     21   96     .      .     .
# 3   P11473  UniProtKB  Zinc finger     24   44     .      .     .
# 4   P11473  UniProtKB  Zinc finger     60   84     .      .     .
# ..     ...        ...          ...    ...  ...   ...    ...   ...
# 65  P11473  UniProtKB        Helix    349  370     .      .     .
# 66  P11473  UniProtKB         Turn    373  378     .      .     .
# 67  P11473  UniProtKB        Helix    379  404     .      .     .
# 68  P11473  UniProtKB        Helix    410  413     .      .     .
# 69  P11473  UniProtKB        Helix    416  422     .      .     .
#
#                                            attributes
# 0          ID=PRO_0000053542;Note=Vitamin D3 receptor
# 1   Note=NR LBD;Ontology_term=ECO:0000255;evidence...
# 2   Note=Nuclear receptor;Ontology_term=ECO:000025...
# 3   Note=NR C4-type;Ontology_term=ECO:0000255;evid...
# 4   Note=NR C4-type;Ontology_term=ECO:0000255;evid...
# ..                                                ...
# 65  Ontology_term=ECO:0007829;evidence=ECO:0007829...
# 66  Ontology_term=ECO:0007829;evidence=ECO:0007829...
# 67  Ontology_term=ECO:0007829;evidence=ECO:0007829...
# 68  Ontology_term=ECO:0007829;evidence=ECO:0007829...
# 69  Ontology_term=ECO:0007829;evidence=ECO:0007829...
#
# [70 rows x 9 columns]

# %%
features = []
for i in VDR_regions.index:
    features.append(GraphicFeature(start=VDR_regions["start"].iloc[i], 
                                   end=VDR_regions["end"].iloc[i], strand=+1, color="#ffd700",
                   label=VDR_regions["type"].iloc[i]))
fig, ax1 = plt.subplots(figsize = (12,1), dpi = 300)

record = GraphicRecord(sequence_length= 427, features=features)
record.plot(ax = ax1, figure_width=20);
