# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(rc={'figure.figsize':(6,6), 'figure.dpi':300})
sns.set_style("white")

# %% [markdown]
# ## 1. Adding LOEUF to all Lambert TF genes
#
# Downloaded constraint metrics here https://gnomad.broadinstitute.org/downloads#v4

# %%
gnomad_lof_metrics = pd.read_csv("../data/gnomad.v4.1.constraint_metrics.tsv", sep = "\t")
gnomad_lof_metrics = gnomad_lof_metrics[gnomad_lof_metrics["canonical"] == True]
gnomad_lof_metrics
# Out:
#         gene          gene_id       transcript  canonical  mane_select  \
# 0       A1BG                1      NM_130786.4       True         True
# 1       A1BG  ENSG00000121410  ENST00000263100       True         True
# 8       A1CF            29974      NM_014576.4       True         True
# 18      A1CF  ENSG00000148584  ENST00000373997       True         True
# 23       A2M                2      NM_000014.6       True         True
# ...      ...              ...              ...        ...          ...
# 211517   NaN  ENSG00000289282  ENST00000687518       True        False
# 211518   NaN  ENSG00000289346  ENST00000625377       True        False
# 211519   NaN  ENSG00000289503  ENST00000553426       True        False
# 211520   NaN  ENSG00000289517  ENST00000617178       True        False
# 211521   NaN  ENSG00000289565  ENST00000632040       True        False
#
#         lof_hc_lc.obs  lof_hc_lc.exp  lof_hc_lc.possible  lof_hc_lc.oe  \
# 0                45.0         43.048               193.0       1.04540
# 1                45.0         43.048               193.0       1.04540
# 8                45.0         69.962               352.0       0.64320
# 18               45.0         69.962               352.0       0.64320
# 23               95.0        147.240               745.0       0.64522
# ...               ...            ...                 ...           ...
# 211517            3.0         27.914               105.0       0.10747
# 211518            5.0         12.136                71.0       0.41201
# 211519            NaN            NaN                 NaN           NaN
# 211520            NaN            NaN                 NaN           NaN
# 211521            NaN            NaN                 NaN           NaN
#
#         lof_hc_lc.mu  ...  syn.oe_ci.lower  syn.oe_ci.upper  syn.z_raw  \
# 0       7.063300e-07  ...            0.973            1.172  -1.166000
# 1       7.063300e-07  ...            0.973            1.172  -1.166000
# 8       9.547100e-07  ...            0.903            1.103   0.032727
# 18      9.547100e-07  ...            0.903            1.103   0.032727
# 23      1.344500e-06  ...            0.806            0.929   3.368800
# ...              ...  ...              ...              ...        ...
# 211517  7.913800e-07  ...            0.908            1.317  -0.767990
# 211518  1.796400e-07  ...            0.191            0.412   5.816400
# 211519           NaN  ...            0.633            1.457   0.208200
# 211520           NaN  ...            0.833            1.217  -0.038967
# 211521           NaN  ...            0.691            1.153   0.755130
#
#         syn.z_score  constraint_flags  level          transcript_type  \
# 0         -0.635490                []    NaN                      NaN
# 1         -0.635490                []    2.0           protein_coding
# 8          0.017838                []    NaN                      NaN
# 18         0.017838                []    2.0           protein_coding
# 23         1.836200                []    NaN                      NaN
# ...             ...               ...    ...                      ...
# 211517    -0.418590                []    2.0           protein_coding
# 211518     3.170200                []    2.0           protein_coding
# 211519     0.113480    ["no_exp_lof"]    2.0  nonsense_mediated_decay
# 211520    -0.021239    ["no_exp_lof"]    2.0  nonsense_mediated_decay
# 211521     0.411580    ["no_exp_lof"]    2.0  nonsense_mediated_decay
#
#         chromosome  cds_length  num_coding_exons
# 0              NaN         NaN               NaN
# 1            chr19      1485.0               8.0
# 8              NaN         NaN               NaN
# 18           chr10      1758.0              11.0
# 23             NaN         NaN               NaN
# ...            ...         ...               ...
# 211517        chr6       390.0               5.0
# 211518        chr7      2847.0              15.0
# 211519       chr14       208.0               3.0
# 211520       chr22       440.0               4.0
# 211521        chr1       317.0               3.0
#
# [36315 rows x 55 columns]

# %%
gnomad_lof_metrics = gnomad_lof_metrics[["gene", "gene_id", "lof.oe_ci.upper", "transcript"]]
gnomad_lof_metrics = gnomad_lof_metrics.drop_duplicates()
gnomad_lof_metrics = gnomad_lof_metrics.rename(columns = {"lof.oe_ci.upper" : "LOEUF"})
gnomad_lof_metrics
# Out:
#         gene          gene_id  LOEUF       transcript
# 0       A1BG                1  1.340      NM_130786.4
# 1       A1BG  ENSG00000121410  1.340  ENST00000263100
# 8       A1CF            29974  0.825      NM_014576.4
# 18      A1CF  ENSG00000148584  0.825  ENST00000373997
# 23       A2M                2  0.765      NM_000014.6
# ...      ...              ...    ...              ...
# 211517   NaN  ENSG00000289282  0.278  ENST00000687518
# 211518   NaN  ENSG00000289346  0.871  ENST00000625377
# 211519   NaN  ENSG00000289503    NaN  ENST00000553426
# 211520   NaN  ENSG00000289517    NaN  ENST00000617178
# 211521   NaN  ENSG00000289565    NaN  ENST00000632040
#
# [36315 rows x 4 columns]

# %%
lambert_TFs = pd.read_excel("../data/lambert_supp_tables.xlsx", sheet_name = "Table S1. Related to Figure 1B")
# lambert_TFs["uniprotID"] = lambert_TFs["GeneName"].str.split("|").str[1]
lambert_TFs = lambert_TFs[lambert_TFs["Is TF?"] == "Yes"]
lambert_TFs = lambert_TFs.rename(columns = {"Gene Information" : "gene_id", "Unnamed: 1" : "gene"})
lambert_TFs = lambert_TFs[["gene_id", "gene"]]
lambert_TFs
# Out:
#               gene_id    gene
# 1     ENSG00000137203  TFAP2A
# 2     ENSG00000008196  TFAP2B
# 3     ENSG00000087510  TFAP2C
# 4     ENSG00000008197  TFAP2D
# 5     ENSG00000116819  TFAP2E
# ...               ...     ...
# 2760  ENSG00000177683   THAP5
# 2761  ENSG00000174796   THAP6
# 2762  ENSG00000184436   THAP7
# 2763  ENSG00000161277   THAP8
# 2764  ENSG00000168152   THAP9
#
# [1639 rows x 2 columns]

# %%
lambert_TFs = pd.merge(lambert_TFs, gnomad_lof_metrics, how = "left", on = "gene_id")

# %%
lambert_TFs = lambert_TFs.drop(columns = "gene_y").rename(columns = {"gene_x" : "gene"})
lambert_TFs
# Out:
#               gene_id    gene  LOEUF       transcript
# 0     ENSG00000137203  TFAP2A  0.334  ENST00000379613
# 1     ENSG00000008196  TFAP2B  0.353  ENST00000393655
# 2     ENSG00000087510  TFAP2C  0.417  ENST00000201031
# 3     ENSG00000008197  TFAP2D  0.389  ENST00000008391
# 4     ENSG00000116819  TFAP2E  1.418  ENST00000373235
# ...               ...     ...    ...              ...
# 1634  ENSG00000177683   THAP5  1.089  ENST00000415914
# 1635  ENSG00000174796   THAP6  1.028  ENST00000311638
# 1636  ENSG00000184436   THAP7  1.147  ENST00000215742
# 1637  ENSG00000161277   THAP8  1.615  ENST00000292894
# 1638  ENSG00000168152   THAP9  0.791  ENST00000302236
#
# [1639 rows x 4 columns]

# %%
plt.rcParams['figure.dpi'] = 300

sns.histplot(lambert_TFs["LOEUF"], bins = np.arange(0, 2.1, 0.1))
plt.axvline(0.6, 0,2, color = "r")
plt.title("LOEUF scores of Lambert TFs");

# %% [markdown]
# ## 2. Adding LOEUF to all SFARI Genes

# %%
SFARI_genes = pd.read_csv("../data/SFARI-Gene_genes_01-23-2023release_03-21-2023export.csv")
SFARI_genes
# Out:
#       status gene-symbol                                          gene-name  \
# 0          9        ABAT                   4-aminobutyrate aminotransferase
# 1          9      ABCA10  ATP-binding cassette, sub-family A (ABC1), mem...
# 2          9      ABCA13         ATP binding cassette subfamily A member 13
# 3          9       ABCA7  ATP-binding cassette, sub-family A (ABC1), mem...
# 4          9        ABL2  ABL proto-oncogene 2, non-receptor tyrosine ki...
# ...      ...         ...                                                ...
# 1113       9      ZNF774                            Zinc finger protein 774
# 1114       9     ZNF804A                           Zinc finger protein 804A
# 1115       9      ZNF827                            Zinc finger protein 827
# 1116       9      ZSWIM6                 zinc finger SWIM-type containing 6
# 1117       9      ZWILCH                          zwilchkinetochore protein
#
#            ensembl-id chromosome  \
# 0     ENSG00000183044         16
# 1     ENSG00000154263         17
# 2     ENSG00000179869          7
# 3     ENSG00000064687         19
# 4     ENSG00000143322          1
# ...               ...        ...
# 1113  ENSG00000196391         15
# 1114  ENSG00000170396          2
# 1115  ENSG00000151612          4
# 1116  ENSG00000130449          5
# 1117  ENSG00000174442         15
#
#                                        genetic-category  gene-score  \
# 0        Rare Single Gene Mutation, Genetic Association         2.0
# 1                             Rare Single Gene Mutation         2.0
# 2                 Rare Single Gene Mutation, Functional         2.0
# 3                             Rare Single Gene Mutation         2.0
# 4                 Rare Single Gene Mutation, Functional         3.0
# ...                                                 ...         ...
# 1113                          Rare Single Gene Mutation         2.0
# 1114  Rare Single Gene Mutation, Genetic Association...         2.0
# 1115     Rare Single Gene Mutation, Genetic Association         2.0
# 1116  Rare Single Gene Mutation, Syndromic, Genetic ...         NaN
# 1117                          Rare Single Gene Mutation         2.0
#
#       syndromic  eagle  number-of-reports
# 0             0    NaN                  7
# 1             0    NaN                  2
# 2             0    NaN                 10
# 3             0    NaN                  5
# 4             0    NaN                 10
# ...         ...    ...                ...
# 1113          0    NaN                  4
# 1114          0    NaN                 16
# 1115          0    NaN                  3
# 1116          1    NaN                  6
# 1117          0    NaN                  5
#
# [1118 rows x 10 columns]

# %%
SFARI_genes = pd.merge(SFARI_genes, gnomad_lof_metrics, how = "left", left_on = "ensembl-id", right_on = "gene_id")
SFARI_genes
# Out:
#       status gene-symbol                                          gene-name  \
# 0          9        ABAT                   4-aminobutyrate aminotransferase
# 1          9      ABCA10  ATP-binding cassette, sub-family A (ABC1), mem...
# 2          9      ABCA13         ATP binding cassette subfamily A member 13
# 3          9       ABCA7  ATP-binding cassette, sub-family A (ABC1), mem...
# 4          9        ABL2  ABL proto-oncogene 2, non-receptor tyrosine ki...
# ...      ...         ...                                                ...
# 1113       9      ZNF774                            Zinc finger protein 774
# 1114       9     ZNF804A                           Zinc finger protein 804A
# 1115       9      ZNF827                            Zinc finger protein 827
# 1116       9      ZSWIM6                 zinc finger SWIM-type containing 6
# 1117       9      ZWILCH                          zwilchkinetochore protein
#
#            ensembl-id chromosome  \
# 0     ENSG00000183044         16
# 1     ENSG00000154263         17
# 2     ENSG00000179869          7
# 3     ENSG00000064687         19
# 4     ENSG00000143322          1
# ...               ...        ...
# 1113  ENSG00000196391         15
# 1114  ENSG00000170396          2
# 1115  ENSG00000151612          4
# 1116  ENSG00000130449          5
# 1117  ENSG00000174442         15
#
#                                        genetic-category  gene-score  \
# 0        Rare Single Gene Mutation, Genetic Association         2.0
# 1                             Rare Single Gene Mutation         2.0
# 2                 Rare Single Gene Mutation, Functional         2.0
# 3                             Rare Single Gene Mutation         2.0
# 4                 Rare Single Gene Mutation, Functional         3.0
# ...                                                 ...         ...
# 1113                          Rare Single Gene Mutation         2.0
# 1114  Rare Single Gene Mutation, Genetic Association...         2.0
# 1115     Rare Single Gene Mutation, Genetic Association         2.0
# 1116  Rare Single Gene Mutation, Syndromic, Genetic ...         NaN
# 1117                          Rare Single Gene Mutation         2.0
#
#       syndromic  eagle  number-of-reports     gene          gene_id  LOEUF  \
# 0             0    NaN                  7     ABAT  ENSG00000183044  0.871
# 1             0    NaN                  2   ABCA10  ENSG00000154263  1.044
# 2             0    NaN                 10   ABCA13  ENSG00000179869  1.063
# 3             0    NaN                  5    ABCA7  ENSG00000064687  1.368
# 4             0    NaN                 10     ABL2  ENSG00000143322  0.578
# ...         ...    ...                ...      ...              ...    ...
# 1113          0    NaN                  4   ZNF774  ENSG00000196391  1.645
# 1114          0    NaN                 16  ZNF804A  ENSG00000170396  0.370
# 1115          0    NaN                  3   ZNF827  ENSG00000151612  0.197
# 1116          1    NaN                  6   ZSWIM6  ENSG00000130449  0.146
# 1117          0    NaN                  5   ZWILCH  ENSG00000174442  1.061
#
#            transcript
# 0     ENST00000268251
# 1     ENST00000690296
# 2     ENST00000435803
# 3     ENST00000263094
# 4     ENST00000502732
# ...               ...
# 1113  ENST00000354377
# 1114  ENST00000302277
# 1115  ENST00000508784
# 1116  ENST00000252744
# 1117  ENST00000307897
#
# [1118 rows x 14 columns]

# %%
sns.histplot(SFARI_genes["LOEUF"], stat = "density", bins = np.arange(0, 2.1, 0.1))
# Out:
# <Axes: xlabel='LOEUF', ylabel='Density'>

# %% [markdown]
# ## 3. Adding LOEUF to all SFARI TFs

# %%
SFARI_TFs = lambert_TFs[lambert_TFs["gene_id"].isin(SFARI_genes["ensembl-id"])]
SFARI_TFs
# Out:
#               gene_id    gene  LOEUF       transcript
# 10    ENSG00000117139   KDM5B  0.858  ENST00000367265
# 11    ENSG00000189079   ARID2  0.224  ENST00000334344
# 13    ENSG00000126705   AHDC1  0.168  ENST00000673934
# 15    ENSG00000116539   ASH1L  0.104  ENST00000392403
# 23    ENSG00000135365  PHF21A  0.149  ENST00000676320
# ...               ...     ...    ...              ...
# 1589  ENSG00000008441    NFIX  0.092  ENST00000592199
# 1592  ENSG00000141646   SMAD4  0.227  ENST00000342988
# 1605  ENSG00000136535    TBR1  0.246  ENST00000389554
# 1606  ENSG00000184058    TBX1  0.703  ENST00000649276
# 1614  ENSG00000122145   TBX22    NaN              NaN
#
# [126 rows x 4 columns]

# %%
known_ADs = pd.read_csv("../output/known_ADs_considering_isoforms_and_canonical.csv")
SFARI_TFs_with_ADs = SFARI_TFs[SFARI_TFs["gene"].isin(known_ADs["Gene"])]
SFARI_TFs
# Out:
#               gene_id    gene  LOEUF       transcript
# 10    ENSG00000117139   KDM5B  0.858  ENST00000367265
# 11    ENSG00000189079   ARID2  0.224  ENST00000334344
# 13    ENSG00000126705   AHDC1  0.168  ENST00000673934
# 15    ENSG00000116539   ASH1L  0.104  ENST00000392403
# 23    ENSG00000135365  PHF21A  0.149  ENST00000676320
# ...               ...     ...    ...              ...
# 1589  ENSG00000008441    NFIX  0.092  ENST00000592199
# 1592  ENSG00000141646   SMAD4  0.227  ENST00000342988
# 1605  ENSG00000136535    TBR1  0.246  ENST00000389554
# 1606  ENSG00000184058    TBX1  0.703  ENST00000649276
# 1614  ENSG00000122145   TBX22    NaN              NaN
#
# [126 rows x 4 columns]

# %%
sns.histplot(SFARI_TFs["LOEUF"], bins = np.arange(0, 2.1, 0.1))
plt.axvline(0.6, 0,2, color = "r")
plt.title("LOEUF scores of SFARI TFs");

# %% [markdown]
# ## 4. Adding LOEUF to SFARI TF hits

# %%
# From http://localhost:8888/notebooks/Desktop/Staller_Lab/SFARI/soto_analysis/notebooks/All%20hit%20gene%20names.ipynb

hits = ['ARX',
 'CAMTA2',
 'CASZ1',
 'ERG',
 'IKZF1',
 'MEIS2',
 'NCOA1',
 'NKX2-2',
 'NR1D1',
 'NR4A2',
 'OTX1',
 'PAX5',
 'PAX6',
 'PITX1',
 'RORA',
 'TCF7L2',
 'YY1']

# %%
SFARI_TF_hits = SFARI_TFs[SFARI_TFs["gene"].isin(hits)]
SFARI_TF_hits
# Out:
#               gene_id    gene  LOEUF       transcript
# 100   ENSG00000084676   NCOA1  0.298  ENST00000348332
# 215   ENSG00000130940   CASZ1  0.285  ENST00000377022
# 252   ENSG00000185811   IKZF1  0.320  ENST00000331340
# 346   ENSG00000100811     YY1  0.200  ENST00000262238
# 976   ENSG00000108509  CAMTA2  0.512  ENST00000348066
# 1033  ENSG00000157554     ERG  0.234  ENST00000288319
# 1153  ENSG00000148737  TCF7L2  0.474  ENST00000627217
# 1161  ENSG00000004848     ARX    NaN              NaN
# 1272  ENSG00000134138   MEIS2  0.255  ENST00000561208
# 1287  ENSG00000125820  NKX2-2  0.640  ENST00000377142
# 1301  ENSG00000115507    OTX1  0.508  ENST00000282549
# 1310  ENSG00000069011   PITX1  0.575  ENST00000265340
# 1353  ENSG00000007372    PAX6  0.226  ENST00000640368
# 1439  ENSG00000126368   NR1D1  0.476  ENST00000246672
# 1456  ENSG00000153234   NR4A2  0.093  ENST00000339562
# 1468  ENSG00000069667    RORA  0.207  ENST00000335670
# 1549  ENSG00000196092    PAX5  0.361  ENST00000358127

# %%
sns.histplot(SFARI_TF_hits["LOEUF"], bins = np.arange(0, 2.1, 0.1), color = 'g')
plt.axvline(0.6, 0,2, color = "r")
plt.title("LOEUF scores of SFARI TF hits");

# %%
sns.histplot(lambert_TFs["LOEUF"], alpha = 0.25, bins = np.arange(0, 2.1, 0.1), color = "gray", stat = "density", label = "All TFs")
sns.histplot(SFARI_genes["LOEUF"], alpha = 0.25,  bins = np.arange(0, 2.1, 0.1), color = "purple", stat = "density", label = "SFARI Genes")
sns.histplot(SFARI_TFs["LOEUF"], alpha = 0.25,  bins = np.arange(0, 2.1, 0.1), color = "b", stat = "density", label = "SFARI TFs")
sns.histplot(SFARI_TF_hits["LOEUF"], alpha = 0.25,  bins = np.arange(0, 2.1, 0.1), color = 'green', stat = "density", label = "SFARI TF Hits")
plt.axvline(0.6, 0,2, color = "r")
plt.legend();

# %% [markdown]
# Plotting

# %%
plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2)
plt.ylim(0, 2.4)
plt.xlim(-0.6, 2.6)
sns.kdeplot(lambert_TFs["LOEUF"], color = "gray", label = "All TFs")
plt.legend();

# %%
plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2)
plt.ylim(0, 2.4)
plt.xlim(-0.6, 2.6)
sns.kdeplot(lambert_TFs["LOEUF"], color = "gray", label = "All TFs")
sns.kdeplot(SFARI_genes["LOEUF"], color = "purple", label = "SFARI Genes")

plt.legend();

# %%
sns.set_context('talk')
plt.figure(figsize = (10, 6))
plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2)
#plt.ylim(0, 2.4)
plt.xlim(-0.6, 2.6)
sns.kdeplot(lambert_TFs["LOEUF"], color = "gray", label = "All TFs")
sns.kdeplot(SFARI_genes["LOEUF"], color = "purple", label = "SFARI Genes")
sns.kdeplot(SFARI_TFs_with_ADs["LOEUF"], label = "SFARI TFs with ADs")
sns.despine()
plt.legend();

# %%
plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2)
#plt.ylim(0, 2.4)
plt.xlim(-0.6, 2.6)
sns.kdeplot(lambert_TFs["LOEUF"], color = "gray", label = "All TFs")
sns.kdeplot(SFARI_genes["LOEUF"], color = "purple", label = "SFARI Genes")
sns.kdeplot(SFARI_TFs_with_ADs["LOEUF"], label = "SFARI TFs with ADs")
plt.legend();

# %%
plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2)
plt.ylim(0, 2.4)

plt.xlim(-0.6, 2.6)
sns.kdeplot(lambert_TFs["LOEUF"], color = "gray", label = "All TFs")
sns.kdeplot(SFARI_genes["LOEUF"], color = "purple", label = "SFARI Genes")
sns.kdeplot(SFARI_TFs_with_ADs["LOEUF"], label = "SFARI TFs with ADs")
sns.kdeplot(SFARI_TF_hits["LOEUF"], color = 'red', label = "SFARI TF Hits")
plt.legend();

# %% [markdown]
# KS Test python

# %%
import numpy as np
from scipy import stats

# %%
stats.ks_2samp(lambert_TFs["LOEUF"], SFARI_genes["LOEUF"]).pvalue
# Out:
# nan

# %%
stats.ks_2samp(lambert_TFs["LOEUF"], SFARI_TFs_with_ADs["LOEUF"]).pvalue
# Out:
# nan

# %%
stats.ks_2samp(lambert_TFs["LOEUF"], SFARI_TF_hits["LOEUF"]).pvalue
# Out:
# nan

# %%
stats.ks_2samp(SFARI_genes["LOEUF"], SFARI_TFs_with_ADs["LOEUF"]).pvalue
# Out:
# nan

# %%
stats.ks_2samp(SFARI_genes["LOEUF"], SFARI_TF_hits["LOEUF"]).pvalue
# Out:
# nan

# %%
stats.ks_2samp(SFARI_TFs_with_ADs["LOEUF"], SFARI_TF_hits["LOEUF"]).pvalue
# Out:
# nan

# %%
0.05 / 6
# Out:
# 0.008333333333333333

# %% [markdown]
# ---
# ## Adding alpha missense gene constraint scores

# %% [markdown]
# Downloaded here: https://zenodo.org/records/10813168

# %%
alphamissense_gene = pd.read_csv("../data/AlphaMissense_gene_hg38.tsv", sep = "\t", header = 3)
alphamissense_gene["transcript"] = alphamissense_gene["transcript_id"].str.split(".").str[0]
alphamissense_gene
# Out:
#             transcript_id  mean_am_pathogenicity       transcript
# 0      ENST00000000233.10               0.742270  ENST00000000233
# 1       ENST00000000412.8               0.378343  ENST00000000412
# 2       ENST00000001008.6               0.422290  ENST00000001008
# 3       ENST00000001146.6               0.466606  ENST00000001146
# 4       ENST00000002125.9               0.351480  ENST00000002125
# ...                   ...                    ...              ...
# 19228   ENST00000673386.1               0.209559  ENST00000673386
# 19229   ENST00000673439.1               0.349771  ENST00000673439
# 19230   ENST00000673466.1               0.669078  ENST00000673466
# 19231   ENST00000673477.1               0.287994  ENST00000673477
# 19232   ENST00000673563.1               0.218294  ENST00000673563
#
# [19233 rows x 3 columns]

# %%
lambert_TFs
# Out:
#               gene_id    gene  LOEUF       transcript
# 0     ENSG00000137203  TFAP2A  0.334  ENST00000379613
# 1     ENSG00000008196  TFAP2B  0.353  ENST00000393655
# 2     ENSG00000087510  TFAP2C  0.417  ENST00000201031
# 3     ENSG00000008197  TFAP2D  0.389  ENST00000008391
# 4     ENSG00000116819  TFAP2E  1.418  ENST00000373235
# ...               ...     ...    ...              ...
# 1634  ENSG00000177683   THAP5  1.089  ENST00000415914
# 1635  ENSG00000174796   THAP6  1.028  ENST00000311638
# 1636  ENSG00000184436   THAP7  1.147  ENST00000215742
# 1637  ENSG00000161277   THAP8  1.615  ENST00000292894
# 1638  ENSG00000168152   THAP9  0.791  ENST00000302236
#
# [1639 rows x 4 columns]

# %%
lambert_TFs = pd.merge(lambert_TFs, alphamissense_gene, on = "transcript")
lambert_TFs
# Out:
#               gene_id    gene  LOEUF       transcript       transcript_id  \
# 0     ENSG00000008196  TFAP2B  0.353  ENST00000393655   ENST00000393655.4
# 1     ENSG00000087510  TFAP2C  0.417  ENST00000201031   ENST00000201031.3
# 2     ENSG00000008197  TFAP2D  0.389  ENST00000008391   ENST00000008391.3
# 3     ENSG00000116819  TFAP2E  1.418  ENST00000373235   ENST00000373235.4
# 4     ENSG00000116017  ARID3A  0.442  ENST00000263620   ENST00000263620.8
# ...               ...     ...    ...              ...                 ...
# 1053  ENSG00000041988   THAP3  1.241  ENST00000054650   ENST00000054650.8
# 1054  ENSG00000176946   THAP4  0.585  ENST00000407315   ENST00000407315.6
# 1055  ENSG00000177683   THAP5  1.089  ENST00000415914   ENST00000415914.4
# 1056  ENSG00000161277   THAP8  1.615  ENST00000292894   ENST00000292894.2
# 1057  ENSG00000168152   THAP9  0.791  ENST00000302236  ENST00000302236.10
#
#       mean_am_pathogenicity
# 0                  0.614557
# 1                  0.465959
# 2                  0.536534
# 3                  0.504094
# 4                  0.407205
# ...                     ...
# 1053               0.375345
# 1054               0.404626
# 1055               0.287857
# 1056               0.287022
# 1057               0.246075
#
# [1058 rows x 6 columns]

# %%
sns.set_theme(rc={'figure.figsize':(6,6)})
sns.set_style("white")
plt.ylim(0, 1)
sns.scatterplot(data = lambert_TFs, x = "LOEUF", y = "mean_am_pathogenicity", size = 0.1, legend = False);

# %%
# Running into same issue

# %%
SFARI_TF_hits
# Out:
#               gene_id    gene  LOEUF       transcript
# 100   ENSG00000084676   NCOA1  0.298  ENST00000348332
# 215   ENSG00000130940   CASZ1  0.285  ENST00000377022
# 252   ENSG00000185811   IKZF1  0.320  ENST00000331340
# 346   ENSG00000100811     YY1  0.200  ENST00000262238
# 976   ENSG00000108509  CAMTA2  0.512  ENST00000348066
# 1033  ENSG00000157554     ERG  0.234  ENST00000288319
# 1153  ENSG00000148737  TCF7L2  0.474  ENST00000627217
# 1161  ENSG00000004848     ARX    NaN              NaN
# 1272  ENSG00000134138   MEIS2  0.255  ENST00000561208
# 1287  ENSG00000125820  NKX2-2  0.640  ENST00000377142
# 1301  ENSG00000115507    OTX1  0.508  ENST00000282549
# 1310  ENSG00000069011   PITX1  0.575  ENST00000265340
# 1353  ENSG00000007372    PAX6  0.226  ENST00000640368
# 1439  ENSG00000126368   NR1D1  0.476  ENST00000246672
# 1456  ENSG00000153234   NR4A2  0.093  ENST00000339562
# 1468  ENSG00000069667    RORA  0.207  ENST00000335670
# 1549  ENSG00000196092    PAX5  0.361  ENST00000358127

# %%
lambert_TFs["SFARI_TF_with_AD"] = [_ in list(SFARI_TFs_with_ADs['gene_id']) for _ in lambert_TFs["gene_id"]]
lambert_TFs["SFARI_TF_hit"] = [_ in list(SFARI_TF_hits['gene_id']) for _ in lambert_TFs["gene_id"]]
#lambert_TFs["Category"] = lambert_TFs["SFARI_TF_hit"].map({False:"TF",True:"SFARI TF Hit"})

categories = []
for i in lambert_TFs.index:
    row = lambert_TFs.iloc[i]
    if row["SFARI_TF_hit"]:
        categories.append("SFARI TF Hit")
    elif row["SFARI_TF_with_AD"]:
        categories.append("SFARI_TF with AD")
    else:
        categories.append("TF")
        
lambert_TFs["Category"] = categories
lambert_TFs
# Out:
#               gene_id    gene  LOEUF       transcript       transcript_id  \
# 0     ENSG00000008196  TFAP2B  0.353  ENST00000393655   ENST00000393655.4
# 1     ENSG00000087510  TFAP2C  0.417  ENST00000201031   ENST00000201031.3
# 2     ENSG00000008197  TFAP2D  0.389  ENST00000008391   ENST00000008391.3
# 3     ENSG00000116819  TFAP2E  1.418  ENST00000373235   ENST00000373235.4
# 4     ENSG00000116017  ARID3A  0.442  ENST00000263620   ENST00000263620.8
# ...               ...     ...    ...              ...                 ...
# 1053  ENSG00000041988   THAP3  1.241  ENST00000054650   ENST00000054650.8
# 1054  ENSG00000176946   THAP4  0.585  ENST00000407315   ENST00000407315.6
# 1055  ENSG00000177683   THAP5  1.089  ENST00000415914   ENST00000415914.4
# 1056  ENSG00000161277   THAP8  1.615  ENST00000292894   ENST00000292894.2
# 1057  ENSG00000168152   THAP9  0.791  ENST00000302236  ENST00000302236.10
#
#       mean_am_pathogenicity  SFARI_TF_with_AD  SFARI_TF_hit Category
# 0                  0.614557             False         False       TF
# 1                  0.465959             False         False       TF
# 2                  0.536534             False         False       TF
# 3                  0.504094             False         False       TF
# 4                  0.407205             False         False       TF
# ...                     ...               ...           ...      ...
# 1053               0.375345             False         False       TF
# 1054               0.404626             False         False       TF
# 1055               0.287857             False         False       TF
# 1056               0.287022             False         False       TF
# 1057               0.246075             False         False       TF
#
# [1058 rows x 9 columns]

# %%
import scipy as sp

# %%
sns.set_theme(rc={'figure.figsize':(6,6)})
sns.set_style("white")
sns.scatterplot(data = lambert_TFs, x = "LOEUF", y = "mean_am_pathogenicity", legend = True, 
                color = "gray", label = "TF",
                alpha = 0.25, s = 25, linewidth = 0, palette = ["gray", "b", "green"]);

r, p = sp.stats.pearsonr(x=lambert_TFs.dropna()['LOEUF'], y=lambert_TFs.dropna()['mean_am_pathogenicity'])
ax = plt.gca()
plt.text(.05, .9, "Pearson's r ={:.2f}".format(r), transform=ax.transAxes)
plt.ylabel("Mean AlphaMissense Pathogenicity")

plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2);
# Out:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_99466/2958546760.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data = lambert_TFs, x = "LOEUF", y = "mean_am_pathogenicity", legend = True,

# %%
sns.set_theme(rc={'figure.figsize':(6,6)})
sns.set_style("white")
sns.scatterplot(data = lambert_TFs, x = "LOEUF", y = "mean_am_pathogenicity", legend = True, label = "All TFs",
                color = "gray", 
                alpha = 0.25, s = 25, linewidth = 0);

sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_with_AD"]], x = "LOEUF", y = "mean_am_pathogenicity", 
                legend = True, label = "SFARI TFs with ADs",
                color = "b", 
                alpha = 0.75, s = 25, linewidth = 0, palette = ["gray", "b", "green"]);

r, p = sp.stats.pearsonr(x=lambert_TFs.dropna()['LOEUF'], y=lambert_TFs.dropna()['mean_am_pathogenicity'])
ax = plt.gca()
plt.text(.05, .9, "Pearson's r ={:.2f}".format(r), transform=ax.transAxes)

plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2);
# Out:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_99466/206861679.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_with_AD"]], x = "LOEUF", y = "mean_am_pathogenicity",

# %%
import scipy as sp

# %%
sns.set_theme(rc={'figure.figsize':(6,6)})
sns.set_style("white")
sns.scatterplot(data = lambert_TFs, x = "LOEUF", y = "mean_am_pathogenicity", legend = True, label = "TF",
                color = "gray", 
                alpha = 0.25, s = 25, linewidth = 0);

sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_with_AD"]], x = "LOEUF", y = "mean_am_pathogenicity", 
                legend = True, label = "SFARI TFs with ADs",
                color = "b", 
                alpha = 0.75, s = 25, linewidth = 0);

# sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_hit"]], x = "LOEUF", y = "mean_am_pathogenicity", 
#                 legend = True, label = "SFARI TF Hits",
#                 color = "red",
#                 alpha = 1, s = 25, linewidth = 0);

r, p = sp.stats.pearsonr(x=lambert_TFs.dropna()['LOEUF'], y=lambert_TFs.dropna()['mean_am_pathogenicity'])
ax = plt.gca()
plt.text(.05, .9, "Pearson's r ={:.2f}".format(r), transform=ax.transAxes)

plt.ylabel("Mean AlphaMissense Pathogenicity")
plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 3
#       1 sns.set_theme(rc={'figure.figsize':(6,6)})
#       2 sns.set_style("white")
# ----> 3 sns.scatterplot(data = lambert_TFs, x = "LOEUF", y = "mean_am_pathogenicity", legend = True, label = "TF",
#       4                 color = "gray",
#       5                 alpha = 0.25, s = 25, linewidth = 0);
#       7 sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_with_AD"]], x = "LOEUF", y = "mean_am_pathogenicity",
#       8                 legend = True, label = "SFARI TFs with ADs",
#       9                 color = "b",
#      10                 alpha = 0.75, s = 25, linewidth = 0);
#      12 # sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_hit"]], x = "LOEUF", y = "mean_am_pathogenicity",
#      13 #                 legend = True, label = "SFARI TF Hits",
#      14 #                 color = "red",
#      15 #                 alpha = 1, s = 25, linewidth = 0);
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `mean_am_pathogenicity` for `y`. An entry with this name does not appear in `data`.

# %%
sns.set_theme(rc={'figure.figsize':(6,6)})
sns.set_style("white")
sns.scatterplot(data = lambert_TFs, x = "LOEUF", y = "mean_am_pathogenicity", legend = True, label = "TF",
                color = "gray", 
                alpha = 0.25, s = 25, linewidth = 0);

sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_with_AD"]], x = "LOEUF", y = "mean_am_pathogenicity", 
                legend = True, label = "SFARI TFs with ADs",
                color = "b", 
                alpha = 0.75, s = 25, linewidth = 0);

sns.scatterplot(data = lambert_TFs[lambert_TFs["SFARI_TF_hit"]], x = "LOEUF", y = "mean_am_pathogenicity", 
                legend = True, label = "SFARI TF Hits",
                color = "red",
                alpha = 1, s = 25, linewidth = 0);

r, p = sp.stats.pearsonr(x=lambert_TFs.dropna()['LOEUF'], y=lambert_TFs.dropna()['mean_am_pathogenicity'])
ax = plt.gca()
plt.text(.05, .9, "Pearson's r ={:.2f}".format(r), transform=ax.transAxes)

plt.ylabel("Mean AlphaMissense Pathogenicity")
plt.axvline(0.6, 0,2, color = "gray", alpha = 0.2);

# %%
lambert_TFs

# %%
min_hit_LOEUF = min(lambert_TFs[lambert_TFs["SFARI_TF_hit"]]["LOEUF"])
min_hit_LOEUF

# %%
lambert_TFs[(lambert_TFs["Category"] == "SFARI_TF with AD") & (lambert_TFs["LOEUF"] < min_hit_LOEUF)]

# %%
lambert_TFs[(lambert_TFs["Category"] == "SFARI_TF with AD") & (lambert_TFs["LOEUF"] < min_hit_LOEUF)][["gene", "LOEUF", "mean_am_pathogenicity"]].sort_values(by = "mean_am_pathogenicity", ascending = False)

# %%
max_hit_am_pathog = max(lambert_TFs[lambert_TFs["SFARI_TF_hit"]]["mean_am_pathogenicity"])
max_hit_am_pathog

# %%
lambert_TFs[(lambert_TFs["Category"] == "SFARI_TF with AD") & (lambert_TFs["mean_am_pathogenicity"] > max_hit_am_pathog)]

# %%
lambert_TFs[(lambert_TFs["Category"] == "SFARI_TF with AD") & (lambert_TFs["mean_am_pathogenicity"] > max_hit_am_pathog)][["gene", "LOEUF", "mean_am_pathogenicity"]].sort_values(by = "LOEUF")

# %%
import scipy as sp

# %%
r, p = sp.stats.pearsonr(x=lambert_TFs.dropna()['LOEUF'], y=lambert_TFs.dropna()['mean_am_pathogenicity'])
r

# %%
p

# %%
# Bottom 5 and top 5 LOEUF SFARI TFs with ADs(not hits)
lambert_TFs[lambert_TFs["Category"] == "SFARI_TF with AD"].sort_values(by = "LOEUF")

# %%
bottom_5_loeuf_sfari_TFs_with_ADs = lambert_TFs[lambert_TFs["Category"] == "SFARI_TF with AD"].sort_values(by = "LOEUF")[:5]
bottom_5_loeuf_sfari_TFs_with_ADs[["gene", "LOEUF"]]

# %%
bottom_5_loeuf_sfari_TFs_with_ADs = lambert_TFs[lambert_TFs["Category"] == "SFARI_TF with AD"].sort_values(by = "LOEUF")[-5:]
bottom_5_loeuf_sfari_TFs_with_ADs[["gene", "LOEUF"]]

# %% [markdown]
# Adding K/S stat

# %%
lambert_TFs["Category"].value_counts()
