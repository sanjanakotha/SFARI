# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import subprocess
from scipy.stats import chisquare
import os

# import scipy.stats as stats

# %% [markdown]
# Prepared variant list at
# http://localhost:8888/lab/workspaces/auto-E/tree/Desktop/Staller_Lab/SFARI/notebooks/Zoonomia.ipynb?

# %%
! python3 ../scripts/get_full_mutations.py --variants_filename zoonomia_15.bed  --variants_folder /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/ --sort_TFs true --sort_variants true
# Out:
# Sorting TF bed files.
# 1 ENST00000359486
# 2 ENST00000379044
# 3 ENST00000437473
# 4 lengths
# 5 ENST00000339562
# 6 ENST00000348332
# 7 ENST00000367265
# 8 ENST00000342988
# 9 ENST00000372583
# 10 ENST00000262238
# 11 ENST00000303329
# 12 ENST00000315869
# 13 ENST00000241001
# 14 ENST00000348066
# 15 ENST00000428368
# 16 ENST00000318003
# 17 ENST00000341099
# 18 ENST00000056233
# 19 ENST00000331340
# 20 ENST00000356073
# 21 ENST00000265340
# 22 ENST00000377142
# 23 ENST00000262518
# 24 ENST00000239243
# 25 ENST00000373294
# 26 ENST00000288319
# 27 ENST00000309446
# 28 ENST00000561208
# 29 ENST00000355995
# 30 ENST00000395324
# 31 sorted
# 32 ENST00000335670
# 33 ENST00000312233
# 34 ENST00000373036
# 35 .ipynb_checkpoints
# 36 ENST00000434704
# 37 ENST00000380013
# 38 ENST00000355311
# 39 ENST00000377022
# 40 ENST00000250916
# 41 ENST00000389506
# 42 ENST00000246672
# 43 ENST00000317216
# 44 ENST00000403491
# 45 ENST00000592199
# 46 ENST00000358127
# 47 ENST00000282549
# ...

# %%
! python3 ../scripts/get_full_mutations_domains.py --domain none --variants_filename zoonomia_15.bed
# Out:
# 1 O15062
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000307750.bed. Exiting.
# 2 Q86XF7
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000314228.bed. Exiting.
# 3 Q5XKR4
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000306422.bed. Exiting.
# 4 Q5TA89
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000378453.bed. Exiting.
# 5 O43623
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000020945.bed. Exiting.
# 6 O14978
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000219069.bed. Exiting.
# 7 Q8N587
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000302851.bed. Exiting.
# 8 P37231
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000287820.bed. Exiting.
# 9 Q86YP4
# Error: Unable to open file ../outputs/mutations/cds_zoonomia_15/ENST00000360315.bed. Exiting.
# 10 Q8IWY8
# ...

# %% [markdown]
# ---
# All TFs

# %%
! python3 ../scripts/get_full_mutations.py --variants_filename zoonomia_all_TF_cds.bed  --variants_folder /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/ --sort_TFs true --sort_variants true
# Out:
# Sorting TF bed files.
# ...
# 100%|██████████████████████████████████████| 1561/1561 [00:05<00:00, 265.48it/s]
#
# Sorting variants. at /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/zoonomia_all_TF_cds.bed
#
#
# /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/sorted/zoonomia_all_TF_cds.bed
# Starting intersecting CDS bed files and variants.
# ...
# Intersecting: 100%|█████████████████████████| 1561/1561 [01:26<00:00, 18.09it/s]
# Done intersecting.

# %%
! python3 ../scripts/get_full_mutations_domains.py --domain none --variants_filename zoonomia_all_TF_cds.bed
# Out:
# 1 O15062
# 2 Q86XF7
# 3 Q5XKR4
# 4 Q5TA89
# 5 O43623
# 6 O14978
# 7 Q8N587
# 8 P37231
# 9 Q86YP4
# 10 Q8IWY8
# 11 Q9UEG4
# 12 P19793
# 13 C9JLR9
# 14 Q16665
# 15 O75346
# 16 P10242
# 17 P16989
# 18 P10070
# 19 Q96MA1
# 20 Q96CK0
# 21 Q12800
# 22 Q96MM3
# 23 Q14938
# 24 Q6NSZ9
# 25 Q9NRM2
# 26 P0CI00
# 27 Q96DT7
# 28 Q96SZ4
# 29 P51449
# 30 Q499Z4
# 31 Q9BXG8
# 32 Q86UZ6
# 33 Q9BWX5
# 34 Q49AG3
# 35 Q14593
# 36 Q5TC79
# 37 O95935
# 38 O15266
# 39 Q9HBE1
# 40 P12524
# 41 Q96BR9
# 42 Q96LX8
# 43 Q6VB84
# 44 O14529
# 45 Q8NB50
# 46 Q86VE0
# 47 Q5SVQ8
# 48 Q8IW36
# 49 Q96N22
# 50 Q8WTV1
# 51 Q8N1W2
# 52 Q9P0T4
# 53 P61244
# 54 P52630
# 55 Q16600
# 56 Q96KM6
# 57 O14770
# 58 Q9UFW8
# 59 Q9UBR4
# 60 Q9BQW3
# 61 Q8TBC5
# 62 O14545
# 63 P15336
# 64 Q9UMN6
# 65 A8MTQ0
# 66 Q9UL49
# 67 Q2KHR2
# 68 Q9GZZ0
# 69 Q86WP2
# 70 Q9H4T2
# 71 P10827
# 72 Q9BU19
# 73 P58304
# 74 Q9UL40
# 75 P78367
# 76 O43670
# 77 A6NP11
# 78 Q6BEB4
# 79 P18847
# 80 Q15424
# 81 Q32MQ0
# 82 P11308
# 83 O15499
# 84 Q15047
# ...

# %% [markdown]
# ---
# All TFs, Zoonoma 447 way

# %%
! python3 ../scripts/get_full_mutations.py --variants_filename zoonomia_447_all_TF_cds.bed  --variants_folder /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/ --sort_TFs true --sort_variants true
# Out:
# Sorting TF bed files.
# ...
# 100%|██████████████████████████████████████| 1561/1561 [00:04<00:00, 326.93it/s]
#
# Sorting variants. at /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/zoonomia_447_all_TF_cds.bed
#
#
# /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/sorted/zoonomia_447_all_TF_cds.bed
# Starting intersecting CDS bed files and variants.
# ...
# Intersecting: 100%|█████████████████████████| 1561/1561 [01:26<00:00, 18.08it/s]
# Done intersecting.

# %%
! python3 ../scripts/get_full_mutations_domains.py --domain none --variants_filename zoonomia_447_all_TF_cds.bed
# Out:
# 1 O15062
# 2 Q86XF7
# 3 Q5XKR4
# 4 Q5TA89
# 5 O43623
# 6 O14978
# 7 Q8N587
# 8 P37231
# 9 Q86YP4
# 10 Q8IWY8
# 11 Q9UEG4
# 12 P19793
# 13 C9JLR9
# 14 Q16665
# 15 O75346
# 16 P10242
# 17 P16989
# 18 P10070
# 19 Q96MA1
# 20 Q96CK0
# 21 Q12800
# 22 Q96MM3
# 23 Q14938
# 24 Q6NSZ9
# 25 Q9NRM2
# 26 P0CI00
# 27 Q96DT7
# 28 Q96SZ4
# 29 P51449
# 30 Q499Z4
# 31 Q9BXG8
# 32 Q86UZ6
# 33 Q9BWX5
# 34 Q49AG3
# 35 Q14593
# 36 Q5TC79
# 37 O95935
# 38 O15266
# 39 Q9HBE1
# 40 P12524
# 41 Q96BR9
# 42 Q96LX8
# 43 Q6VB84
# 44 O14529
# 45 Q8NB50
# 46 Q86VE0
# 47 Q5SVQ8
# 48 Q8IW36
# 49 Q96N22
# 50 Q8WTV1
# 51 Q8N1W2
# 52 Q9P0T4
# 53 P61244
# 54 P52630
# 55 Q16600
# 56 Q96KM6
# 57 O14770
# 58 Q9UFW8
# 59 Q9UBR4
# 60 Q9BQW3
# 61 Q8TBC5
# 62 O14545
# 63 P15336
# 64 Q9UMN6
# 65 A8MTQ0
# 66 Q9UL49
# 67 Q2KHR2
# 68 Q9GZZ0
# 69 Q86WP2
# 70 Q9H4T2
# 71 P10827
# 72 Q9BU19
# 73 P58304
# 74 Q9UL40
# 75 P78367
# 76 O43670
# 77 A6NP11
# 78 Q6BEB4
# 79 P18847
# 80 Q15424
# 81 Q32MQ0
# 82 P11308
# 83 O15499
# 84 Q15047
# ...
