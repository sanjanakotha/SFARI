# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import subprocess
from scipy.stats import chisquare
import os
import glob

# import scipy.stats as stats

# %%
# %load_ext autoreload

# %autoreload 2
import pandas as pd
import numpy as np
# %aimport Variant_analysis_helper_functions


#import protfasta
import os

# %% [markdown]
# # Running enrichment analysis scripts

# %%
import os

def run_full_pipeline(variants_filename):
    """
    Runs the full mutation pipeline for a given variants file.
    Checks directories and prints warnings if they exist.
    """
    variants_folder = "/Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/"

    # Run scripts sequentially
    print("\nRunning get_full_mutations.py ...")
    os.system(f"python3 ../scripts/get_full_mutations.py --variants_filename {variants_filename} --variants_folder {variants_folder} --sort_TFs true --sort_variants true")
    
    print("\nRunning classify_mutations.py ...")
    os.system(f"python3 ../scripts/classify_mutations.py --variants_filename {variants_filename}")
    
    print("\nRunning get_mutations_domains_snv_classified.py ...")
    os.system(f"python3 ../scripts/get_mutations_domains_snv_classified.py --domain none --variants_filename {variants_filename}")

# %%
# Probands only first (~2 min to run)
run_full_pipeline("probands_only_fixed.bed")
# Out:
# Running get_full_mutations.py ...
# Sorting TF bed files.
#  14%|█▍        | 215/1561 [00:00<00:05, 266.41it/s]Unexpected file format.  Please use tab-delimited BED, GFF, or VCF. Perhaps you have non-integer starts or ends at line 1?
# 100%|██████████| 1561/1561 [00:05<00:00, 285.92it/s]
# Sorting variants. at /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/probands_only_fixed.bed
#
#
# /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/sorted/probands_only_fixed.bed
# Starting intersecting CDS bed files and variants.
# Intersecting:  72%|███████▏  | 1130/1561 [00:09<00:03, 117.73it/s]
# Skipping directory ../outputs/mutations/cds_bed_format/sorted
# Intersecting:  76%|███████▋  | 1193/1561 [00:09<00:02, 136.66it/s]
# Skipping directory ../outputs/mutations/cds_bed_format/.ipynb_checkpoints
# Intersecting: 100%|██████████| 1561/1561 [00:12<00:00, 126.98it/s]
# Done intersecting.
#
# Running classify_mutations.py ...
# Classifying:: 100%|██████████| 1559/1559 [01:44<00:00, 14.92it/s]
# Running get_mutations_domains_snv_classified.py ...
# Created directory ../outputs/mutations/domains_probands_only_fixed_snv_classified
# Classifying:  13%|█▎        | 202/1560 [00:00<00:00, 1861.13it/s]
#  does not have an ENST code
# Classifying:  67%|██████▋   | 1051/1560 [00:01<00:00, 833.02it/s]
# sorted does not have an ENST code
# Classifying: 100%|██████████| 1560/1560 [00:01<00:00, 862.68it/s]

# %%
# Next, all probands (~3 min to run)
run_full_pipeline("all_probands_fixed.bed")
# Out:
# Running get_full_mutations.py ...
# Sorting TF bed files.
#  12%|█▏        | 193/1561 [00:00<00:04, 322.57it/s]Unexpected file format.  Please use tab-delimited BED, GFF, or VCF. Perhaps you have non-integer starts or ends at line 1?
# 100%|██████████| 1561/1561 [00:04<00:00, 321.98it/s]
# Sorting variants. at /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/all_probands_fixed.bed
#
#
# /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/sorted/all_probands_fixed.bed
# Starting intersecting CDS bed files and variants.
# Intersecting:  72%|███████▏  | 1122/1561 [00:13<00:05, 74.50it/s]
# Skipping directory ../outputs/mutations/cds_bed_format/sorted
# Intersecting:  76%|███████▋  | 1193/1561 [00:14<00:04, 80.55it/s]
# Skipping directory ../outputs/mutations/cds_bed_format/.ipynb_checkpoints
# Intersecting: 100%|██████████| 1561/1561 [00:18<00:00, 83.34it/s]
# Done intersecting.
#
# Running classify_mutations.py ...
# Classifying:: 100%|██████████| 1559/1559 [02:42<00:00,  9.60it/s]
# Running get_mutations_domains_snv_classified.py ...
# Created directory ../outputs/mutations/domains_all_probands_fixed_snv_classified
# Classifying:  12%|█▎        | 195/1560 [00:00<00:00, 1943.92it/s]
#  does not have an ENST code
# Classifying:  69%|██████▊   | 1072/1560 [00:01<00:00, 714.42it/s]
# sorted does not have an ENST code
# Classifying: 100%|██████████| 1560/1560 [00:01<00:00, 853.32it/s]

# %%
# Siblings only (~20s min to run)
run_full_pipeline("siblings_only_fixed.bed")
# Out:
#   0%|          | 0/1561 [00:00<?, ?it/s]
# Running get_full_mutations.py ...
# Sorting TF bed files.
#  13%|█▎        | 196/1561 [00:00<00:04, 319.30it/s]Unexpected file format.  Please use tab-delimited BED, GFF, or VCF. Perhaps you have non-integer starts or ends at line 1?
# 100%|██████████| 1561/1561 [00:04<00:00, 332.56it/s]
# Intersecting:   5%|▌         | 81/1561 [00:00<00:01, 792.70it/s]
# Sorting variants. at /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/siblings_only_fixed.bed
#
#
# /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/sorted/siblings_only_fixed.bed
# Starting intersecting CDS bed files and variants.
# Intersecting:  73%|███████▎  | 1135/1561 [00:01<00:00, 676.46it/s]
# Skipping directory ../outputs/mutations/cds_bed_format/sorted
# Skipping directory ../outputs/mutations/cds_bed_format/.ipynb_checkpoints
# Intersecting: 100%|██████████| 1561/1561 [00:02<00:00, 652.83it/s]
# Classifying::   0%|          | 0/1559 [00:00<?, ?it/s]
# Done intersecting.
#
# Running classify_mutations.py ...
# Classifying:: 100%|██████████| 1559/1559 [00:07<00:00, 201.71it/s]
# Running get_mutations_domains_snv_classified.py ...
# Created directory ../outputs/mutations/domains_siblings_only_fixed_snv_classified
# Classifying:  14%|█▍        | 219/1560 [00:00<00:00, 2000.52it/s]
#  does not have an ENST code
# Classifying:  75%|███████▌  | 1174/1560 [00:01<00:00, 943.34it/s]
# sorted does not have an ENST code
# Classifying: 100%|██████████| 1560/1560 [00:01<00:00, 960.54it/s]

# %%
# all siblings (~1.5 min to run)
run_full_pipeline("all_siblings_fixed.bed")
# Out:
#   0%|          | 0/1561 [00:00<?, ?it/s]
# Running get_full_mutations.py ...
# Sorting TF bed files.
#  13%|█▎        | 196/1561 [00:00<00:04, 335.84it/s]Unexpected file format.  Please use tab-delimited BED, GFF, or VCF. Perhaps you have non-integer starts or ends at line 1?
# 100%|██████████| 1561/1561 [00:04<00:00, 337.23it/s]
# Intersecting:   0%|          | 0/1561 [00:00<?, ?it/s]
# Sorting variants. at /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/all_siblings_fixed.bed
#
#
# /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/sorted/all_siblings_fixed.bed
# Starting intersecting CDS bed files and variants.
# Intersecting:  71%|███████▏  | 1115/1561 [00:06<00:02, 176.90it/s]
# Skipping directory ../outputs/mutations/cds_bed_format/sorted
# Intersecting:  76%|███████▋  | 1191/1561 [00:06<00:02, 176.67it/s]
# Skipping directory ../outputs/mutations/cds_bed_format/.ipynb_checkpoints
# Intersecting: 100%|██████████| 1561/1561 [00:09<00:00, 173.44it/s]
# Done intersecting.
#
# Running classify_mutations.py ...
# Classifying:: 100%|██████████| 1559/1559 [01:08<00:00, 22.83it/s]
# Running get_mutations_domains_snv_classified.py ...
# Created directory ../outputs/mutations/domains_all_siblings_fixed_snv_classified
# Classifying:  13%|█▎        | 204/1560 [00:00<00:00, 2015.02it/s]
#  does not have an ENST code
# Classifying:  72%|███████▏  | 1118/1560 [00:01<00:00, 880.33it/s]
# sorted does not have an ENST code
# Classifying: 100%|██████████| 1560/1560 [00:01<00:00, 877.92it/s]

# %% [markdown]
# # Analyze output

# %%
## Generating output

# %%
proband_only_output = Variant_analysis_helper_functions.return_results(-1, 1, 
                                                       domain_types = ["AD", "DBD", "IDR"], 
                                                       print_output = False,
                                                      variant_filename = "probands_only_fixed")
proband_only_output
# Out:
# Processing ENST codes: 100%|██████████| 45/45 [00:02<00:00, 18.83it/s]
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 0        ARNT2    Q9HBZ2           2154          122          0.056639
# 1          ARX    Q96QS3           1689           92          0.054470
# 2        CASZ1    Q86V15           5280          419          0.079356
# 3       CC2D1A    Q6P1N0           2856          243          0.085084
# 4       CAMTA2    O94983           3609          273          0.075644
# 5         EBF3    Q9H4W6           1791           81          0.045226
# 6         EGR3    Q06889           1164           69          0.059278
# 7         ESR2    Q92731           1593          126          0.079096
# 8        GLIS1    Q8NBF1           1863          171          0.091787
# 9          ERG    P11308           1440           84          0.058333
# 10      HIVEP3    Q5T1R4           7221          535          0.074089
# 11       IKZF1    Q13422           1560          106          0.067949
# 12       KDM5B    Q9UGL1           4635          353          0.076160
# 13       KLF16    Q9BXK1            759           73          0.096179
# 14        KLF7    O75840            909           48          0.052805
# 15       KMT2A    Q03164          11910          580          0.048699
# 16       MEF2C    Q06413           1422           45          0.031646
# 17       MEIS2    O14770           1434           66          0.046025
# 18        MSX2    P35548            804           60          0.074627
# 19        MTF1    Q14872           2262          127          0.056145
# 20       MYT1L    Q9UL68           3561          168          0.047178
# 21       NCOA1    Q15788           4326          306          0.070735
# 22      NFE2L3    Q9Y4A8           2085          212          0.101679
# 23        NFIA    Q12857           1530           65          0.042484
# 24        NFIX    Q14938           1509           53          0.035123
# 25       NR1D1    P20393           1845          124          0.067209
# 26       NR4A2    P43354           1797           90          0.050083
# 27      NKX2-2    O95096            822           68          0.082725
# 28        OTX1    P32242           1065           58          0.054460
# 29        PAX5    Q02548           1176           56          0.047619
# 30        PAX6    P26367           1269           58          0.045705
# 31       PITX1    P78337            945           88          0.093122
# 32        RORA    P35398           1572           88          0.055980
# 33       SMAD4    Q13485           1659           49          0.029536
# 34       SRCAP    Q6ZRS2           9693          789          0.081399
# 35       TBX22    Q9Y458           1563           75          0.047985
# 36       TCF20    Q9UGU0           5883          437          0.074282
# 37        TCF4    P15884           2004           83          0.041417
# 38      TCF7L2    Q9NQB0           1860          117          0.062903
# 39        TET2    Q6N021           6009          407          0.067732
# 40        TFE3    P19532           1728           72          0.041667
# 41        THRA    P10827           1473           61          0.041412
# 42         YY1    P25490           1245           42          0.033735
# 43         VDR    P11473           1284           99          0.077103
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
#
# 17                     0.386041                    0.009026
# 18                     1.000000                    1.000000
# 19                     1.000000                    1.000000
# 20                     0.611851                    0.803597
# 21                     0.432707                    0.425549
# 22                     0.317666                    0.308494
# 23                     1.000000                    1.000000
# 24                     1.000000                    1.000000
# 25                     0.790580                    1.000000
# 26                     0.442390                    0.395531
# 27                     0.589134                    0.604176
# 28                     1.000000                    0.677795
# 29                     1.000000                    1.000000
# 30                     1.000000                    1.000000
# 31                     0.325545                    0.180720
# 32                     0.411601                    1.000000
# 33                     0.313331                    0.586410
# 34                     1.000000                    0.589868
# 35                     0.671937                    0.635150
# 36                     0.826476                    0.667732
# 37                     1.000000                    1.000000
# 38                     1.000000                    1.000000
# 39                     1.000000                    1.000000
# 40                     1.000000                    1.000000
# 41                     0.575640                    0.612057
# 42                     1.000000                    1.000000
# 43                     0.649988                    0.648302

# %%
all_proband_output = Variant_analysis_helper_functions.return_results(-1, 1, 
                                                       domain_types = ["AD", "DBD", "IDR"], 
                                                       print_output = False,
                                                      variant_filename = "all_probands_fixed")
all_proband_output
# Out:
# Processing ENST codes: 100%|██████████| 45/45 [00:02<00:00, 22.00it/s]
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 0        ARNT2    Q9HBZ2           2154          186          0.086351
# 1          ARX    Q96QS3           1689          128          0.075784
# 2        CASZ1    Q86V15           5280          644          0.121970
# 3       CC2D1A    Q6P1N0           2856          384          0.134454
# 4       CAMTA2    O94983           3609          402          0.111388
# 5         EBF3    Q9H4W6           1791          117          0.065327
# 6         EGR3    Q06889           1164           91          0.078179
# 7         ESR2    Q92731           1593          180          0.112994
# 8        GLIS1    Q8NBF1           1863          281          0.150832
# 9          ERG    P11308           1440          111          0.077083
# 10      HIVEP3    Q5T1R4           7221          869          0.120343
# 11       IKZF1    Q13422           1560          148          0.094872
# 12       KDM5B    Q9UGL1           4635          473          0.102050
# 13       KLF16    Q9BXK1            759          107          0.140975
# 14        KLF7    O75840            909           69          0.075908
# 15       KMT2A    Q03164          11910          835          0.070109
# 16       MEF2C    Q06413           1422           54          0.037975
# 17       MEIS2    O14770           1434          110          0.076709
# 18        MSX2    P35548            804          104          0.129353
# 19        MTF1    Q14872           2262          193          0.085323
# 20       MYT1L    Q9UL68           3561          243          0.068239
# 21       NCOA1    Q15788           4326          424          0.098012
# 22      NFE2L3    Q9Y4A8           2085          305          0.146283
# 23        NFIA    Q12857           1530           85          0.055556
# 24        NFIX    Q14938           1509           70          0.046388
# 25       NR1D1    P20393           1845          187          0.101355
# 26       NR4A2    P43354           1797          139          0.077351
# 27      NKX2-2    O95096            822           99          0.120438
# 28        OTX1    P32242           1065           82          0.076995
# 29        PAX5    Q02548           1176           87          0.073980
# 30        PAX6    P26367           1269           76          0.059890
# 31       PITX1    P78337            945          119          0.125926
# 32        RORA    P35398           1572          124          0.078880
# 33       SMAD4    Q13485           1659           70          0.042194
# 34       SRCAP    Q6ZRS2           9693         1109          0.114412
# 35       TBX22    Q9Y458           1563          112          0.071657
# 36       TCF20    Q9UGU0           5883          627          0.106578
# 37        TCF4    P15884           2004          110          0.054890
# 38      TCF7L2    Q9NQB0           1860          175          0.094086
# 39        TET2    Q6N021           6009          564          0.093859
# 40        TFE3    P19532           1728          123          0.071181
# 41        THRA    P10827           1473          100          0.067889
# 42         YY1    P25490           1245           78          0.062651
# 43         VDR    P11473           1284          147          0.114486
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
#
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals
# 0                      0.666122                5.056034e-01
# 1                      1.000000                8.344381e-01
# 2                      0.595542                2.181408e-01
# 3                      0.115831                6.327631e-02
# 4                      0.034790                7.868511e-02
# 5                      0.015813                2.193664e-01
# 6                      0.722500                8.401068e-01
# 7                      1.000000                6.989314e-01
# 8                      0.297756                3.995105e-01
# 9                      0.858066                1.000000e+00
# 10                     0.026889                5.731541e-03
# 11                     0.277078                7.902361e-02
# 12                     0.858768                7.182344e-01
# 13                     0.687522                2.657442e-01
# 14                     0.859108                5.531339e-01
# 15                     0.338152                3.401504e-01
# 16                     1.000000                3.315131e-01
# 17                     0.081541                9.195432e-07
# 18                     0.243256                5.314483e-01
# 19                     0.614589                1.808893e-02
# 20                     1.000000                1.000000e+00
# 21                     0.264096                4.386398e-01
# 22                     0.744092                3.924232e-01
# 23                     1.000000                1.000000e+00
# 24                     0.627174                4.143910e-01
# 25                     0.217160                4.201241e-01
# 26                     0.322663                1.633784e-01
# 27                     0.348505                5.637862e-02
# 28                     1.000000                8.510084e-01
# 29                     1.000000                6.189305e-01
# 30                     0.382910                2.745587e-05
# 31                     0.828312                4.918969e-01
# 32                     0.010480                3.415920e-01
# 33                     0.044292                2.133810e-01
# 34                     0.046875                5.219167e-01
# 35                     1.000000                8.358719e-01
# 36                     0.587707                5.264724e-01
# 37                     0.342550                3.328660e-01
# 38                     0.384995                3.788916e-01
# 39                     1.000000                1.000000e+00
# 40                     0.914149                9.098805e-02
# 41                     0.432224                4.752600e-01
# 42                     0.240338                2.210737e-02
# 43                     0.816113                8.465110e-01

# %%
## What is significant?

# %%
print("all_proband")
print("AD vs DBD significant:")
all_proband_AD_vs_DBD_sig = Variant_analysis_helper_functions.return_bh_sig(all_proband_output, "ADvsDBD_fisher_exact_p_vals", 0.1)
all_proband_AD_vs_DBD_sig["all_proband AD_vs_DBD_sig"] = True
display(all_proband_AD_vs_DBD_sig)

print("\nAD vs IDR significant:")
all_proband_AD_vs_IDR_sig = Variant_analysis_helper_functions.return_bh_sig(all_proband_output, "ADvsIDR_fisher_exact_p_vals", 0.1)
all_proband_AD_vs_IDR_sig["all_proband AD_vs_IDR_sig"] = True
display(all_proband_AD_vs_IDR_sig)

print("\nAD vs TF significant:")
all_proband_AD_vs_TF_sig = Variant_analysis_helper_functions.return_bh_sig(all_proband_output, "ADvsTF_fisher_exact_p_vals", 0.1)
all_proband_AD_vs_TF_sig["all_proband AD_vs_TF_sig"] = True
display(all_proband_AD_vs_TF_sig)

merged_summary_results_all_proband = (
    all_proband_AD_vs_DBD_sig[["gene-symbol", "all_proband AD_vs_DBD_sig"]]
    .merge(
        all_proband_AD_vs_IDR_sig[["gene-symbol", "all_proband AD_vs_IDR_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .merge(
        all_proband_AD_vs_TF_sig[["gene-symbol", "all_proband AD_vs_TF_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .fillna(False)
)

merged_summary_results_all_proband
# Out:
# all_proband
# AD vs DBD significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/3023181200.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_proband_AD_vs_DBD_sig["all_proband AD_vs_DBD_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 0        ARNT2    Q9HBZ2           2154          186          0.086351
# 1          ARX    Q96QS3           1689          128          0.075784
# 2        CASZ1    Q86V15           5280          644          0.121970
# 4       CAMTA2    O94983           3609          402          0.111388
# 8        GLIS1    Q8NBF1           1863          281          0.150832
# 9          ERG    P11308           1440          111          0.077083
# 10      HIVEP3    Q5T1R4           7221          869          0.120343
# 11       IKZF1    Q13422           1560          148          0.094872
# 13       KLF16    Q9BXK1            759          107          0.140975
# 14        KLF7    O75840            909           69          0.075908
# 17       MEIS2    O14770           1434          110          0.076709
# 19        MTF1    Q14872           2262          193          0.085323
# 20       MYT1L    Q9UL68           3561          243          0.068239
# 27      NKX2-2    O95096            822           99          0.120438
# 29        PAX5    Q02548           1176           87          0.073980
# 30        PAX6    P26367           1269           76          0.059890
# 31       PITX1    P78337            945          119          0.125926
# 40        TFE3    P19532           1728          123          0.071181
# 42         YY1    P25490           1245           78          0.062651
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 0             582           45          0.077320             162
# 1             273           22          0.080586             171
# 2             465           80          0.172043             825
# 4             882           90          0.102041             339
# 8             522           75          0.143678             381
# 9             573           45          0.078534             240
# 10           2592          285          0.109954             282
# 11            246           30          0.121951             279
# 13            132           22          0.166667             219
# 14            300           22          0.073333             219
# 17            414           54          0.130435             174
# 19            891           93          0.104377             450
# 20            822           59          0.071776             552
# 27            162           28          0.172840             171
# 29            165           18          0.109091             375
# 30            456           39          0.085526             546
# 31            150           23          0.153333             171
# 40           1059           88          0.083097             162
# 42            288           29          0.100694             294
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 0              4           0.024691            1116           100
# 1              3           0.017544            1512           125
# 2             51           0.061818            3444           486
# 4             16           0.047198            1941           239
# 8             37           0.097113            1323           218
# 9              6           0.025000             912            87
# 10            16           0.056738            6804           842
# 11            17           0.060932             909            94
# 13            18           0.082192             537            91
# 14             4           0.018265             657            65
# 17             4           0.022989             918           100
# 19            15           0.033333            1770           176
# 20            14           0.025362            3177           222
# 27             9           0.052632             645            90
# 29            10           0.026667             852            77
# 30            15           0.027473             666            60
# 31             6           0.035088             759           111
# 40             3           0.018519            1272           102
# 42             9           0.030612             879            67
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 0            0.089606                 1.843289e-02
# 1            0.082672                 5.040910e-03
# 2            0.141115                 1.192617e-09
# 4            0.123132                 2.029065e-03
# 8            0.164777                 4.074287e-02
# 9            0.095395                 3.813343e-03
# 10           0.123751                 4.024099e-03
# 11           0.103410                 2.075444e-02
# 13           0.169460                 2.319677e-02
# 14           0.098935                 3.994777e-03
# 17           0.108932                 1.512673e-05
# 19           0.099435                 2.112647e-06
# 20           0.069877                 1.182923e-04
# 27           0.139535                 7.260823e-04
# 29           0.090376                 1.866071e-04
# 30           0.090090                 6.070569e-05
# 31           0.146245                 2.980492e-04
# 40           0.080189                 1.902400e-03
# 42           0.076223                 6.542710e-04
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 0                      0.411581                    0.388653
# 1                      1.000000                    0.709099
# 2                      0.079235                    0.001042
# 4                      0.113652                    0.325080
# 8                      0.288948                    0.614509
# 9                      0.302960                    0.919664
# 10                     0.069987                    0.045649
# 11                     0.416797                    0.123059
# 13                     1.000000                    0.338360
# 14                     0.226379                    0.894639
# 17                     0.267082                    0.000003
# 19                     0.683277                    0.010877
# 20                     0.878295                    0.636628
# 27                     0.319299                    0.030320
# 29                     0.464790                    0.076192
# 30                     0.830859                    0.006295
# 31                     0.801804                    0.283099
# 40                     0.819831                    0.016191
# 42                     0.216009                    0.003511
#
#     all_proband AD_vs_DBD_sig
# 0                        True
# 1                        True
# 2                        True
# 4                        True
# 8                        True
# 9                        True
# 10                       True
# 11                       True
# 13                       True
# 14                       True
# 17                       True
# 19                       True
# 20                       True
# 27                       True
# 29                       True
# 30                       True
# 31                       True
# 40                       True
# 42                       True
# AD vs IDR significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/3023181200.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_proband_AD_vs_IDR_sig["all_proband AD_vs_IDR_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 26       NR4A2    P43354           1797          139          0.077351
# 32        RORA    P35398           1572          124          0.078880
# 34       SRCAP    Q6ZRS2           9693         1109          0.114412
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 26            318           11          0.034591             210
# 32            342           13          0.038012             210
# 34           5712          632          0.110644             117
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 26            10           0.047619             885            70
# 32             4           0.019048             522            70
# 34             7           0.059829            7284           945
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 26           0.079096                     0.498792
# 32           0.134100                     0.310427
# 34           0.129736                     0.098263
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 26                     0.005840                    0.001077
# 32                     0.000001                    0.000940
# 34                     0.000957                    0.163313
#
#     all_proband AD_vs_IDR_sig
# 26                       True
# 32                       True
# 34                       True
# AD vs TF significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/3023181200.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_proband_AD_vs_TF_sig["all_proband AD_vs_TF_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 2        CASZ1    Q86V15           5280          644          0.121970
# 17       MEIS2    O14770           1434          110          0.076709
# 19        MTF1    Q14872           2262          193          0.085323
# 26       NR4A2    P43354           1797          139          0.077351
# 30        PAX6    P26367           1269           76          0.059890
# 32        RORA    P35398           1572          124          0.078880
# 40        TFE3    P19532           1728          123          0.071181
# 42         YY1    P25490           1245           78          0.062651
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 2             465           80          0.172043             825
# 17            414           54          0.130435             174
# 19            891           93          0.104377             450
# 26            318           11          0.034591             210
# 30            456           39          0.085526             546
# 32            342           13          0.038012             210
# 40           1059           88          0.083097             162
# 42            288           29          0.100694             294
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 2             51           0.061818            3444           486
# 17             4           0.022989             918           100
# 19            15           0.033333            1770           176
# 26            10           0.047619             885            70
# 30            15           0.027473             666            60
# 32             4           0.019048             522            70
# 40             3           0.018519            1272           102
# 42             9           0.030612             879            67
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 2            0.141115                 1.192617e-09
# 17           0.108932                 1.512673e-05
# 19           0.099435                 2.112647e-06
# 26           0.079096                 4.987919e-01
# 30           0.090090                 6.070569e-05
# 32           0.134100                 3.104267e-01
# 40           0.080189                 1.902400e-03
# 42           0.076223                 6.542710e-04
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 2                      0.079235                    0.001042
# 17                     0.267082                    0.000003
# 19                     0.683277                    0.010877
# 26                     0.005840                    0.001077
# 30                     0.830859                    0.006295
# 32                     0.000001                    0.000940
# 40                     0.819831                    0.016191
# 42                     0.216009                    0.003511
#
#     all_proband AD_vs_TF_sig
# 2                       True
# 17                      True
# 19                      True
# 26                      True
# 30                      True
# 32                      True
# 40                      True
# 42                      True
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/3023181200.py:29: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
#    gene-symbol  all_proband AD_vs_DBD_sig  all_proband AD_vs_IDR_sig  \
# 0        ARNT2                       True                      False
# 1          ARX                       True                      False
# 2       CAMTA2                       True                      False
# 3        CASZ1                       True                      False
# 4          ERG                       True                      False
# 5        GLIS1                       True                      False
# 6       HIVEP3                       True                      False
# 7        IKZF1                       True                      False
# 8        KLF16                       True                      False
# 9         KLF7                       True                      False
# 10       MEIS2                       True                      False
# 11        MTF1                       True                      False
# 12       MYT1L                       True                      False
# 13      NKX2-2                       True                      False
# 14       NR4A2                      False                       True
# 15        PAX5                       True                      False
# 16        PAX6                       True                      False
# 17       PITX1                       True                      False
# 18        RORA                      False                       True
# 19       SRCAP                      False                       True
# 20        TFE3                       True                      False
# 21         YY1                       True                      False
#
#     all_proband AD_vs_TF_sig
# 0                      False
# 1                      False
# 2                      False
# 3                       True
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
# 10                      True
# 11                      True
# 12                     False
# 13                     False
# 14                      True
# 15                     False
# 16                      True
# 17                     False
# 18                      True
# 19                     False
# 20                      True
# 21                      True

# %%
print("all_sibling")
print("AD vs DBD significant:")
all_sibling_AD_vs_DBD_sig = Variant_analysis_helper_functions.return_bh_sig(all_sibling_output, "ADvsDBD_fisher_exact_p_vals", 0.1)
all_sibling_AD_vs_DBD_sig["all_sibling AD_vs_DBD_sig"] = True
display(all_sibling_AD_vs_DBD_sig)

print("\nAD vs IDR significant:")
all_sibling_AD_vs_IDR_sig = Variant_analysis_helper_functions.return_bh_sig(all_sibling_output, "ADvsIDR_fisher_exact_p_vals", 0.1)
all_sibling_AD_vs_IDR_sig["all_sibling AD_vs_IDR_sig"] = True
display(all_sibling_AD_vs_IDR_sig)

print("\nAD vs TF significant:")
all_sibling_AD_vs_TF_sig = Variant_analysis_helper_functions.return_bh_sig(all_sibling_output, "ADvsTF_fisher_exact_p_vals", 0.1)
all_sibling_AD_vs_TF_sig["all_sibling AD_vs_TF_sig"] = True
display(all_sibling_AD_vs_TF_sig)

merged_summary_results_all_sibling = (
    all_sibling_AD_vs_DBD_sig[["gene-symbol", "all_sibling AD_vs_DBD_sig"]]
    .merge(
        all_sibling_AD_vs_IDR_sig[["gene-symbol", "all_sibling AD_vs_IDR_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .merge(
        all_sibling_AD_vs_TF_sig[["gene-symbol", "all_sibling AD_vs_TF_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .fillna(False)
)

merged_summary_results_all_sibling
# Out:
# all_sibling
# AD vs DBD significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/2950554497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sibling_AD_vs_DBD_sig["all_sibling AD_vs_DBD_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 10      HIVEP3    Q5T1R4           7221          376          0.052070
# 17       MEIS2    O14770           1434           52          0.036262
# 19        MTF1    Q14872           2262           78          0.034483
# 20       MYT1L    Q9UL68           3561           98          0.027520
# 30        PAX6    P26367           1269           21          0.016548
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 10           2592          110          0.042438             282
# 17            414           32          0.077295             174
# 19            891           41          0.046016             450
# 20            822           22          0.026764             552
# 30            456           17          0.037281             546
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 10             3           0.010638            6804           365
# 17             2           0.011494             918            48
# 19             4           0.008889            1770            74
# 20             3           0.005435            3177            88
# 30             0           0.000000             666            18
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 10           0.053645                     0.005481
# 17           0.052288                     0.000819
# 19           0.041808                     0.000157
# 20           0.027699                     0.003251
# 30           0.027027                     0.000001
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 10                     0.026889                5.731541e-03
# 17                     0.081541                9.195432e-07
# 19                     0.614589                1.808893e-02
# 20                     1.000000                1.000000e+00
# 30                     0.382910                2.745587e-05
#
#     all_sibling AD_vs_DBD_sig
# 10                       True
# 17                       True
# 19                       True
# 20                       True
# 30                       True
# AD vs IDR significant:
# Empty DataFrame
# Columns: [gene-symbol, uniprotID, TF_cds_length, TF_missense, TF_missense_prop, AD_cds_length, AD_missense, AD_missense_prop, DBD_cds_length, DBD_missense, DBD_missense_prop, IDR_cds_length, IDR_missense, IDR_missense_prop, ADvsDBD_fisher_exact_p_vals, ADvsIDR_fisher_exact_p_vals, ADvsTF_fisher_exact_p_vals, all_sibling AD_vs_IDR_sig]
# Index: []
# AD vs TF significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/2950554497.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sibling_AD_vs_TF_sig["all_sibling AD_vs_TF_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 10      HIVEP3    Q5T1R4           7221          376          0.052070
# 17       MEIS2    O14770           1434           52          0.036262
# 30        PAX6    P26367           1269           21          0.016548
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 10           2592          110          0.042438             282
# 17            414           32          0.077295             174
# 30            456           17          0.037281             546
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 10             3           0.010638            6804           365
# 17             2           0.011494             918            48
# 30             0           0.000000             666            18
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 10           0.053645                     0.005481
# 17           0.052288                     0.000819
# 30           0.027027                     0.000001
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 10                     0.026889                5.731541e-03
# 17                     0.081541                9.195432e-07
# 30                     0.382910                2.745587e-05
#
#     all_sibling AD_vs_TF_sig
# 10                      True
# 17                      True
# 30                      True
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/2950554497.py:29: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
#   gene-symbol  all_sibling AD_vs_DBD_sig  all_sibling AD_vs_IDR_sig  \
# 0      HIVEP3                       True                      False
# 1       MEIS2                       True                      False
# 2        MTF1                       True                      False
# 3       MYT1L                       True                      False
# 4        PAX6                       True                      False
#
#    all_sibling AD_vs_TF_sig
# 0                      True
# 1                      True
# 2                     False
# 3                     False
# 4                      True

# %%
# What genes are significant AD vs DBD in proband, but not in siblings?
set(all_proband_AD_vs_DBD_sig["gene-symbol"]) - set(all_sibling_AD_vs_DBD_sig["gene-symbol"])
# Out:
# {'ARNT2',
#  'ARX',
#  'CAMTA2',
#  'CASZ1',
#  'ERG',
#  'GLIS1',
#  'IKZF1',
#  'KLF16',
#  'KLF7',
#  'NKX2-2',
#  'PAX5',
#  'PITX1',
#  'TFE3',
#  'YY1'}

# %%
# What genes are significant AD vs DBD in proband and in siblings?
set(all_proband_AD_vs_DBD_sig["gene-symbol"]) & set(all_sibling_AD_vs_DBD_sig["gene-symbol"])
# Out:
# {'HIVEP3', 'MEIS2', 'MTF1', 'MYT1L', 'PAX6'}

# %%
# What genes are significant AD vs IDR in proband, but not in siblings?
set(all_proband_AD_vs_IDR_sig["gene-symbol"]) - set(all_sibling_AD_vs_IDR_sig["gene-symbol"])
# Out:
# {'NR4A2', 'RORA', 'SRCAP'}

# %%
# What genes are significant AD vs IDR in proband, & in siblings?
set(all_proband_AD_vs_IDR_sig["gene-symbol"]) & set(all_sibling_AD_vs_IDR_sig["gene-symbol"])
# Out:
# set()

# %%
print("sibling_only")
print("AD vs DBD significant:")
sibling_only_AD_vs_DBD_sig = Variant_analysis_helper_functions.return_bh_sig(sibling_only_output, "ADvsDBD_fisher_exact_p_vals", 0.1)
sibling_only_AD_vs_DBD_sig["sibling_only AD_vs_DBD_sig"] = True
display(sibling_only_AD_vs_DBD_sig)

print("\nAD vs IDR significant:")
sibling_only_AD_vs_IDR_sig = Variant_analysis_helper_functions.return_bh_sig(sibling_only_output, "ADvsIDR_fisher_exact_p_vals", 0.1)
sibling_only_AD_vs_IDR_sig["sibling_only AD_vs_IDR_sig"] = True
display(sibling_only_AD_vs_IDR_sig)

print("\nAD vs IDR significant:")
sibling_only_AD_vs_TF_sig = Variant_analysis_helper_functions.return_bh_sig(sibling_only_output, "ADvsTF_fisher_exact_p_vals", 0.1)
sibling_only_AD_vs_TF_sig["sibling_only AD_vs_TF_sig"] = True
display(sibling_only_AD_vs_TF_sig)

merged_summary_results_sibling_only = (
    sibling_only_AD_vs_DBD_sig[["gene-symbol", "sibling_only AD_vs_DBD_sig"]]
    .merge(
        sibling_only_AD_vs_IDR_sig[["gene-symbol", "sibling_only AD_vs_IDR_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .merge(
        sibling_only_AD_vs_TF_sig[["gene-symbol", "sibling_only AD_vs_TF_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .fillna(False)
)

merged_summary_results_sibling_only
# Out:
# sibling_only
# AD vs DBD significant:
# Empty DataFrame
# Columns: [gene-symbol, uniprotID, TF_cds_length, TF_missense, TF_missense_prop, AD_cds_length, AD_missense, AD_missense_prop, DBD_cds_length, DBD_missense, DBD_missense_prop, IDR_cds_length, IDR_missense, IDR_missense_prop, ADvsDBD_fisher_exact_p_vals, ADvsIDR_fisher_exact_p_vals, ADvsTF_fisher_exact_p_vals, sibling_only AD_vs_DBD_sig]
# Index: []
# AD vs IDR significant:
# Empty DataFrame
# Columns: [gene-symbol, uniprotID, TF_cds_length, TF_missense, TF_missense_prop, AD_cds_length, AD_missense, AD_missense_prop, DBD_cds_length, DBD_missense, DBD_missense_prop, IDR_cds_length, IDR_missense, IDR_missense_prop, ADvsDBD_fisher_exact_p_vals, ADvsIDR_fisher_exact_p_vals, ADvsTF_fisher_exact_p_vals, sibling_only AD_vs_IDR_sig]
# Index: []
# AD vs IDR significant:
# Empty DataFrame
# Columns: [gene-symbol, uniprotID, TF_cds_length, TF_missense, TF_missense_prop, AD_cds_length, AD_missense, AD_missense_prop, DBD_cds_length, DBD_missense, DBD_missense_prop, IDR_cds_length, IDR_missense, IDR_missense_prop, ADvsDBD_fisher_exact_p_vals, ADvsIDR_fisher_exact_p_vals, ADvsTF_fisher_exact_p_vals, sibling_only AD_vs_TF_sig]
# Index: []
# Empty DataFrame
# Columns: [gene-symbol, sibling_only AD_vs_DBD_sig, sibling_only AD_vs_IDR_sig, sibling_only AD_vs_TF_sig]
# Index: []

# %%
print("proband_only")
print("AD vs DBD significant:")
proband_only_AD_vs_DBD_sig = Variant_analysis_helper_functions.return_bh_sig(proband_only_output, "ADvsDBD_fisher_exact_p_vals", 0.1)
proband_only_AD_vs_DBD_sig["proband_only AD_vs_DBD_sig"] = True
display(proband_only_AD_vs_DBD_sig)

print("\nAD vs IDR significant:")
proband_only_AD_vs_IDR_sig = Variant_analysis_helper_functions.return_bh_sig(proband_only_output, "ADvsIDR_fisher_exact_p_vals", 0.1)
proband_only_AD_vs_IDR_sig["proband_only AD_vs_IDR_sig"] = True
display(proband_only_AD_vs_IDR_sig)

print("\nAD vs TF significant:")
proband_only_AD_vs_TF_sig = Variant_analysis_helper_functions.return_bh_sig(proband_only_output, "ADvsTF_fisher_exact_p_vals", 0.1)
proband_only_AD_vs_TF_sig["proband_only AD_vs_TF_sig"] = True
display(proband_only_AD_vs_TF_sig)

merged_summary_results_proband_only = (
    proband_only_AD_vs_DBD_sig[["gene-symbol", "proband_only AD_vs_DBD_sig"]]
    .merge(
        proband_only_AD_vs_IDR_sig[["gene-symbol", "proband_only AD_vs_IDR_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .merge(
        proband_only_AD_vs_TF_sig[["gene-symbol", "proband_only AD_vs_TF_sig"]],
        on="gene-symbol",
        how="outer"
    )
    .fillna(False)
)

merged_summary_results_proband_only
# Out:
# proband_only
# AD vs DBD significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/2282225671.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proband_only_AD_vs_DBD_sig["proband_only AD_vs_DBD_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 1          ARX    Q96QS3           1689           92          0.054470
# 2        CASZ1    Q86V15           5280          419          0.079356
# 9          ERG    P11308           1440           84          0.058333
# 17       MEIS2    O14770           1434           66          0.046025
# 19        MTF1    Q14872           2262          127          0.056145
# 20       MYT1L    Q9UL68           3561          168          0.047178
# 28        OTX1    P32242           1065           58          0.054460
# 29        PAX5    Q02548           1176           56          0.047619
# 31       PITX1    P78337            945           88          0.093122
# 42         YY1    P25490           1245           42          0.033735
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 1             273           15          0.054945             171
# 2             465           54          0.116129             825
# 9             573           34          0.059337             240
# 17            414           28          0.067633             174
# 19            891           57          0.063973             450
# 20            822           43          0.052311             552
# 28            549           36          0.065574             171
# 29            165           12          0.072727             375
# 31            150           18          0.120000             171
# 42            288           14          0.048611             294
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 1              2           0.011696            1512            90
# 2             28           0.033939            3444           316
# 9              4           0.016667             912            67
# 17             2           0.011494             918            60
# 19            14           0.031111            1770           111
# 20            13           0.023551            3177           152
# 28             3           0.017544             903            55
# 29             8           0.021333             852            48
# 31             4           0.023392             759            83
# 42             4           0.013605             879            37
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 1            0.059524                 2.165165e-02
# 2            0.091754                 1.792745e-08
# 9            0.073465                 6.231543e-03
# 17           0.065359                 3.363443e-03
# 19           0.062712                 9.865666e-03
# 20           0.047844                 7.984813e-03
# 28           0.060908                 1.182698e-02
# 29           0.056338                 5.811411e-03
# 31           0.109354                 6.722993e-04
# 42           0.042093                 1.648262e-02
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 1                      0.888959                    1.000000
# 2                      0.091996                    0.003849
# 9                      0.340755                    0.908894
# 17                     0.905271                    0.017446
# 19                     0.932727                    0.192273
# 20                     0.586226                    0.452876
# 28                     0.738390                    0.106293
# 29                     0.468807                    0.113515
# 31                     0.671624                    0.221129
# 42                     0.620724                    0.134526
#
#     proband_only AD_vs_DBD_sig
# 1                         True
# 2                         True
# 9                         True
# 17                        True
# 19                        True
# 20                        True
# 28                        True
# 29                        True
# 31                        True
# 42                        True
# AD vs IDR significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/2282225671.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proband_only_AD_vs_IDR_sig["proband_only AD_vs_IDR_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 32        RORA    P35398           1572           88           0.05598
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 32            342            8          0.023392             210
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 32             4           0.019048             522            48
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 32           0.091954                          1.0
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 32                      0.00003                    0.002027
#
#     proband_only AD_vs_IDR_sig
# 32                        True
# AD vs TF significant:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/2282225671.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proband_only_AD_vs_TF_sig["proband_only AD_vs_TF_sig"] = True
#    gene-symbol uniprotID  TF_cds_length  TF_missense  TF_missense_prop  \
# 2        CASZ1    Q86V15           5280          419          0.079356
# 32        RORA    P35398           1572           88          0.055980
#
#     AD_cds_length  AD_missense  AD_missense_prop  DBD_cds_length  \
# 2             465           54          0.116129             825
# 32            342            8          0.023392             210
#
#     DBD_missense  DBD_missense_prop  IDR_cds_length  IDR_missense  \
# 2             28           0.033939            3444           316
# 32             4           0.019048             522            48
#
#     IDR_missense_prop  ADvsDBD_fisher_exact_p_vals  \
# 2            0.091754                 1.792745e-08
# 32           0.091954                 1.000000e+00
#
#     ADvsIDR_fisher_exact_p_vals  ADvsTF_fisher_exact_p_vals  \
# 2                      0.091996                    0.003849
# 32                     0.000030                    0.002027
#
#     proband_only AD_vs_TF_sig
# 2                        True
# 32                       True
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/2282225671.py:29: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
#    gene-symbol  proband_only AD_vs_DBD_sig  proband_only AD_vs_IDR_sig  \
# 0          ARX                        True                       False
# 1        CASZ1                        True                       False
# 2          ERG                        True                       False
# 3        MEIS2                        True                       False
# 4         MTF1                        True                       False
# 5        MYT1L                        True                       False
# 6         OTX1                        True                       False
# 7         PAX5                        True                       False
# 8        PITX1                        True                       False
# 9         RORA                       False                        True
# 10         YY1                        True                       False
#
#     proband_only AD_vs_TF_sig
# 0                       False
# 1                        True
# 2                       False
# 3                       False
# 4                       False
# 5                       False
# 6                       False
# 7                       False
# 8                       False
# 9                        True
# 10                      False

# %%
merged_all_four = merged_summary_results_all_proband.merge(merged_summary_results_all_sibling, on="gene-symbol", how="outer") \
               .merge(merged_summary_results_proband_only, on="gene-symbol", how="outer") \
               .merge(merged_summary_results_sibling_only, on="gene-symbol", how="outer").fillna(False)
merged_all_four["hit_count"] = merged_all_four.drop(columns = 'gene-symbol').sum(axis = 1)
merged_all_four = merged_all_four.sort_values(by = 'hit_count', ascending=False)
merged_all_four
# Out:
# /var/folders/hw/xx051vr9457c7lrngf2mypgr0000gn/T/ipykernel_22449/679700256.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .merge(merged_summary_results_sibling_only, on="gene-symbol", how="outer").fillna(False)
#    gene-symbol  all_proband AD_vs_DBD_sig  all_proband AD_vs_IDR_sig  \
# 10       MEIS2                       True                      False
# 11        MTF1                       True                      False
# 19        RORA                      False                       True
# 3        CASZ1                       True                      False
# 17        PAX6                       True                      False
# 12       MYT1L                       True                      False
# 22         YY1                       True                      False
# 6       HIVEP3                       True                      False
# 1          ARX                       True                      False
# 14       NR4A2                      False                       True
# 16        PAX5                       True                      False
# 4          ERG                       True                      False
# 18       PITX1                       True                      False
# 21        TFE3                       True                      False
# 7        IKZF1                       True                      False
# 8        KLF16                       True                      False
# 9         KLF7                       True                      False
# 5        GLIS1                       True                      False
# 13      NKX2-2                       True                      False
# 15        OTX1                      False                      False
# 2       CAMTA2                       True                      False
# 20       SRCAP                      False                       True
# 0        ARNT2                       True                      False
#
#     all_proband AD_vs_TF_sig  all_sibling AD_vs_DBD_sig  \
# 10                      True                       True
# 11                      True                       True
# 19                      True                      False
# 3                       True                      False
# 17                      True                       True
# 12                     False                       True
# 22                      True                      False
# 6                      False                       True
# 1                      False                      False
# 14                      True                      False
# 16                     False                      False
# 4                      False                      False
# 18                     False                      False
# 21                      True                      False
# 7                      False                      False
# 8                      False                      False
# 9                      False                      False
# 5                      False                      False
# 13                     False                      False
# 15                     False                      False
# 2                      False                      False
# 20                     False                      False
# 0                      False                      False
#
#     all_sibling AD_vs_IDR_sig  all_sibling AD_vs_TF_sig  \
# 10                      False                      True
# 11                      False                     False
# 19                      False                     False
# 3                       False                     False
# 17                      False                      True
# 12                      False                     False
# 22                      False                     False
# 6                       False                      True
# 1                       False                     False
# 14                      False                     False
# 16                      False                     False
# 4                       False                     False
# 18                      False                     False
# 21                      False                     False
# 7                       False                     False
# 8                       False                     False
# 9                       False                     False
# 5                       False                     False
# 13                      False                     False
# 15                      False                     False
# 2                       False                     False
# 20                      False                     False
# 0                       False                     False
#
#     proband_only AD_vs_DBD_sig  proband_only AD_vs_IDR_sig  \
# 10                        True                       False
# 11                        True                       False
# 19                       False                        True
# 3                         True                       False
# 17                       False                       False
# 12                        True                       False
# 22                        True                       False
# 6                        False                       False
# 1                         True                       False
# 14                       False                       False
# 16                        True                       False
# 4                         True                       False
# 18                        True                       False
# 21                       False                       False
# 7                        False                       False
# 8                        False                       False
# 9                        False                       False
# 5                        False                       False
# 13                       False                       False
# 15                        True                       False
# 2                        False                       False
# 20                       False                       False
# 0                        False                       False
#
#     proband_only AD_vs_TF_sig  sibling_only AD_vs_DBD_sig  \
# 10                      False                       False
# 11                      False                       False
# 19                       True                       False
# 3                        True                       False
# 17                      False                       False
# 12                      False                       False
# 22                      False                       False
# 6                       False                       False
# 1                       False                       False
# 14                      False                       False
# 16                      False                       False
# 4                       False                       False
# 18                      False                       False
# 21                      False                       False
# 7                       False                       False
# 8                       False                       False
# 9                       False                       False
# 5                       False                       False
# 13                      False                       False
# 15                      False                       False
# 2                       False                       False
# 20                      False                       False
# 0                       False                       False
#
#     sibling_only AD_vs_IDR_sig  sibling_only AD_vs_TF_sig  hit_count
# 10                       False                      False          5
# 11                       False                      False          4
# 19                       False                      False          4
# 3                        False                      False          4
# 17                       False                      False          4
# 12                       False                      False          3
# 22                       False                      False          3
# 6                        False                      False          3
# 1                        False                      False          2
# 14                       False                      False          2
# 16                       False                      False          2
# 4                        False                      False          2
# 18                       False                      False          2
# 21                       False                      False          2
# 7                        False                      False          1
# 8                        False                      False          1
# 9                        False                      False          1
# 5                        False                      False          1
# 13                       False                      False          1
# 15                       False                      False          1
# 2                        False                      False          1
# 20                       False                      False          1
# 0                        False                      False          1

# %%
cc_genes = pd.read_csv("../../output/caitlin_experiment/all_annotations_in_15_ads.csv")
cc_genes = set(cc_genes["Gene"])
cc_genes
# Out:
# {'CAMTA2',
#  'ERG',
#  'IKZF1',
#  'MEIS2',
#  'NCOA1',
#  'NKX2-2',
#  'NR4A2',
#  'PAX5',
#  'PAX6',
#  'PITX1'}

# %%
# Genes that were never significant
set(all_proband_output["gene-symbol"]) - set(merged_all_four["gene-symbol"])
# Out:
# {'CC2D1A',
#  'EBF3',
#  'EGR3',
#  'ESR2',
#  'KDM5B',
#  'KMT2A',
#  'MEF2C',
#  'MSX2',
#  'NCOA1',
#  'NFE2L3',
#  'NFIA',
#  'NFIX',
#  'NR1D1',
#  'SMAD4',
#  'TBX22',
#  'TCF20',
#  'TCF4',
#  'TCF7L2',
#  'TET2',
#  'THRA',
#  'VDR'}

# %%
## CC genes not significant
cc_genes & set(all_proband_output["gene-symbol"]) - set(merged_all_four["gene-symbol"])
# Out:
# {'NCOA1'}

# %%
## CC genes are significant
merged_all_four["cc"] = merged_all_four["gene-symbol"].isin(cc_genes)
merged_all_four[merged_all_four["cc"]]
# Out:
#    gene-symbol  all_proband AD_vs_DBD_sig  all_proband AD_vs_IDR_sig  \
# 10       MEIS2                       True                      False
# 17        PAX6                       True                      False
# 14       NR4A2                      False                       True
# 16        PAX5                       True                      False
# 4          ERG                       True                      False
# 18       PITX1                       True                      False
# 7        IKZF1                       True                      False
# 13      NKX2-2                       True                      False
# 2       CAMTA2                       True                      False
#
#     all_proband AD_vs_TF_sig  all_sibling AD_vs_DBD_sig  \
# 10                      True                       True
# 17                      True                       True
# 14                      True                      False
# 16                     False                      False
# 4                      False                      False
# 18                     False                      False
# 7                      False                      False
# 13                     False                      False
# 2                      False                      False
#
#     all_sibling AD_vs_IDR_sig  all_sibling AD_vs_TF_sig  \
# 10                      False                      True
# 17                      False                      True
# 14                      False                     False
# 16                      False                     False
# 4                       False                     False
# 18                      False                     False
# 7                       False                     False
# 13                      False                     False
# 2                       False                     False
#
#     proband_only AD_vs_DBD_sig  proband_only AD_vs_IDR_sig  \
# 10                        True                       False
# 17                       False                       False
# 14                       False                       False
# 16                        True                       False
# 4                         True                       False
# 18                        True                       False
# 7                        False                       False
# 13                       False                       False
# 2                        False                       False
#
#     proband_only AD_vs_TF_sig  sibling_only AD_vs_DBD_sig  \
# 10                      False                       False
# 17                      False                       False
# 14                      False                       False
# 16                      False                       False
# 4                       False                       False
# 18                      False                       False
# 7                       False                       False
# 13                      False                       False
# 2                       False                       False
#
#     sibling_only AD_vs_IDR_sig  sibling_only AD_vs_TF_sig  hit_count    cc
# 10                       False                      False          5  True
# 17                       False                      False          4  True
# 14                       False                      False          2  True
# 16                       False                      False          2  True
# 4                        False                      False          2  True
# 18                       False                      False          2  True
# 7                        False                      False          1  True
# 13                       False                      False          1  True
# 2                        False                      False          1  True

# %%
merged_all_four.to_csv("../../output/sibling_analysis_results_fixed.csv", index=False)

# %%
def plot_comparison(output, ax=None, domains_to_plot=None, legend=True):
    """
    Plot missense SNP frequencies for selected domains using Seaborn colorblind palette.
    
    Parameters:
    - output: DataFrame with columns like 'AD_missense_prop', 'DBD_missense_prop', etc.
    - ax: matplotlib axes object. If None, a new figure and axes are created.
    - domains_to_plot: list of domain names to plot. Options: 'AD', 'DBD', 'IDR_outside_AD', 'TF_outside_AD'.
                       Default: all of them.
    """
    sns.set_context('poster')
    palette = sns.color_palette("colorblind")

    # Fixed mapping of domain to palette index
    domain_colors = {
        "TF_outside_AD": palette[0],
        "AD": palette[1],
        "DBD": palette[2],
        "IDR_outside_AD": palette[3]
    }

    if ax is None:
        fig, ax = plt.subplots(figsize=(10, 6), dpi=300)

    # Compute TF outside AD if needed
    rest_of_TF_prop = (output["TF_missense"] - output["AD_missense"]) \
                      / (output["TF_cds_length"] - output["AD_cds_length"])

    # Default domains
    if domains_to_plot is None:
        domains_to_plot = ["TF_outside_AD", "AD", "DBD", "IDR_outside_AD"]

    for domain in domains_to_plot:
        color = domain_colors.get(domain)
        if domain == "TF_outside_AD":
            sns.kdeplot(rest_of_TF_prop, label="TF outside AD", color=color, ax=ax)
        elif domain == "AD":
            sns.kdeplot(output["AD_missense_prop"], label="AD", color=color, ax=ax)
        elif domain == "DBD":
            sns.kdeplot(output["DBD_missense_prop"], label="DBD", color=color, ax=ax)
        elif domain == "IDR_outside_AD":
            sns.kdeplot(output["IDR_missense_prop"], label="IDR outside AD", color=color, ax=ax)
        else:
            raise ValueError(f"Unknown domain: {domain}")

    ax.set_xlabel("Missense SNP Frequency")
    if legend:
        ax.legend(bbox_to_anchor = (1,1))
    sns.despine(ax=ax)
    
    return ax

# %%
fig, ax = plt.subplots(figsize = (10, 6), dpi = 300)

plot_comparison(all_proband_output, ax=ax, legend=True)

# Add descriptive labels to each subplot
#set_labels = ["Proband\nOnly", "Sibling\nOnly", "All\nProband", "All\nSibling"]
# for ax, label in zip(axs, set_labels):
#     # Position in axes coordinates (0,1 is top-left)
#     ax.text(0.02, 0.95, label, transform=ax.transAxes, fontsize=12,
#             verticalalignment='top', ha = 'left')
    


# # Add a single legend outside the plot
# handles, labels = axs[0].get_legend_handles_labels()  # get legend from first plot
# fig.legend(handles, labels, bbox_to_anchor=(0.95,0.95), fontsize=12, title="Domain", title_fontsize=12)

# fig.tight_layout(rect=[0, 0, 0.85, 1], pad =0.5)  # leave space on the right for legend
# fig.supxlabel("Missense SNP Proportion", y = -0.05, x = 0.45)
# fig.supylabel("Density", x = -0.05)
# fig.tight_layout(pad=0.5)
# Out:
# <Axes: xlabel='Missense SNP Frequency', ylabel='Density'>

# %%
fig, axs = plt.subplots(2,2, width_ratios=(1, 1), figsize = (10, 6), dpi = 300)
axs = axs.flatten()


plot_comparison(all_proband_output, ax = axs[0], legend=False)
plot_comparison(all_sibling_output, ax = axs[1], legend=False)
plot_comparison(proband_only_output, ax = axs[2], legend=False)
plot_comparison(sibling_only_output, ax = axs[3], legend=False)

# Add descriptive labels to each subplot
set_labels = ["All\nProband", "All\nSibling", "Proband\nOnly", "Sibling\nOnly"]
for ax, label in zip(axs, set_labels):
    # Position in axes coordinates (0,1 is top-left)
    ax.text(0.02, 0.95, label, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', ha = 'left')
    
for ax in axs:
    ax.set_xlabel("")
    ax.set_ylabel("")

# Add a single legend outside the plot
handles, labels = axs[0].get_legend_handles_labels()  # get legend from first plot
fig.legend(handles, labels, bbox_to_anchor=(0.95,0.95), fontsize=12, title="Domain", title_fontsize=12)

fig.tight_layout(rect=[0, 0, 0.85, 1], pad =0.5)  # leave space on the right for legend
fig.supxlabel("Missense SNP Proportion", y = -0.05, x = 0.45)
fig.supylabel("Density", x = -0.05)
# fig.tight_layout(pad=0.5)
# Out:
# Text(-0.05, 0.5, 'Density')
