# %%
import pandas as pd

# %%
VDR_muts = pd.read_csv("../outputs/mutations/domains_expanded_iWES_v2_variants_snv_classified/ENST00000395324.bed", sep = "\t", header = None)
VDR_muts
# Out:
#      0         1         2    3                4  5  6                7   8   \
# 0    12  47857680  47857681  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 1    12  47865048  47865049  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 2    12  47865049  47865050  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 3    12  47865050  47865051  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 4    12  47865062  47865063  DBD  ENSG00000111424  .  -  ENST00000395324  12
# ..   ..       ...       ...  ...              ... .. ..              ...  ..
# 106  12  47855791  47855792   AD  ENSG00000111424  .  -  ENST00000395324  12
# 107  12  47855792  47855793   AD  ENSG00000111424  .  -  ENST00000395324  12
# 108  12  47855794  47855795   AD  ENSG00000111424  .  -  ENST00000395324  12
# 109  12  47855797  47855798   AD  ENSG00000111424  .  -  ENST00000395324  12
# 110  12  47855799  47855800   AD  ENSG00000111424  .  -  ENST00000395324  12
#
# ...

# %%
labels = []
for i in range(len(VDR_muts)):
    if VDR_muts[19].iloc[i] < 0.01 / 100:
        labels.append("rare")
    else:
        labels.append("common")
labels
# Out:
# ['rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
# ...

# %%
VDR_muts["short_id"] = ">g." + VDR_muts[2].astype(str) + VDR_muts[17] + ">" + VDR_muts[18]
VDR_muts
# Out:
#       0         1         2    3                4  5  6                7   8  \
# 0    12  47857680  47857681  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 1    12  47865048  47865049  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 2    12  47865049  47865050  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 3    12  47865050  47865051  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 4    12  47865062  47865063  DBD  ENSG00000111424  .  -  ENST00000395324  12
# ..   ..       ...       ...  ...              ... .. ..              ...  ..
# 106  12  47855791  47855792   AD  ENSG00000111424  .  -  ENST00000395324  12
# 107  12  47855792  47855793   AD  ENSG00000111424  .  -  ENST00000395324  12
# 108  12  47855794  47855795   AD  ENSG00000111424  .  -  ENST00000395324  12
# 109  12  47855797  47855798   AD  ENSG00000111424  .  -  ENST00000395324  12
# 110  12  47855799  47855800   AD  ENSG00000111424  .  -  ENST00000395324  12
#
# ...

# %%
VDR_muts["level"] = labels
VDR_muts
# Out:
#       0         1         2    3                4  5  6                7   8  \
# 0    12  47857680  47857681  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 1    12  47865048  47865049  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 2    12  47865049  47865050  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 3    12  47865050  47865051  DBD  ENSG00000111424  .  -  ENST00000395324  12
# 4    12  47865062  47865063  DBD  ENSG00000111424  .  -  ENST00000395324  12
# ..   ..       ...       ...  ...              ... .. ..              ...  ..
# 106  12  47855791  47855792   AD  ENSG00000111424  .  -  ENST00000395324  12
# 107  12  47855792  47855793   AD  ENSG00000111424  .  -  ENST00000395324  12
# 108  12  47855794  47855795   AD  ENSG00000111424  .  -  ENST00000395324  12
# 109  12  47855797  47855798   AD  ENSG00000111424  .  -  ENST00000395324  12
# 110  12  47855799  47855800   AD  ENSG00000111424  .  -  ENST00000395324  12
#
# ...

# %%
VDR_muts[["short_id", "level"]].to_csv("../outputs/Touss_VDR")
# Out:
#            short_id level
# 0    >g.47857681C>A  rare
# 1    >g.47865049T>G  rare
# 2    >g.47865050C>T  rare
# 3    >g.47865051C>T  rare
# 4    >g.47865063G>A  rare
# ..              ...   ...
# 106  >g.47855792T>C  rare
# 107  >g.47855793C>T  rare
# 108  >g.47855795A>G  rare
# 109  >g.47855798A>G  rare
# 110  >g.47855800G>C  rare
#
# [111 rows x 2 columns]
