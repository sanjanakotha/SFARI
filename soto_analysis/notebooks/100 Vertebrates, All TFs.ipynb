# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import subprocess
from scipy.stats import chisquare
import os

# import scipy.stats as stats

# %% [markdown]
# Prepared variant list at
# http://localhost:8888/lab/workspaces/auto-E/tree/Desktop/Staller_Lab/SFARI/notebooks/Zoonomia.ipynb?

# %% [markdown]
# ---
# All TFs

# %%
! python3 ../scripts/get_full_mutations.py --variants_filename 100_verteb_all_TF_cds.bed  --variants_folder /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/ --sort_TFs true --sort_variants true
# Out:
# Sorting TF bed files.
# ...
# 100%|██████████████████████████████████████| 1561/1561 [00:08<00:00, 176.86it/s]
#
# Sorting variants. at /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/100_verteb_all_TF_cds.bed
#
#
# /Users/sanjanakotha/Desktop/Staller_Lab/SFARI/soto_analysis/raw_files/sorted/100_verteb_all_TF_cds.bed
# Starting intersecting CDS bed files and variants.
# ...
# Intersecting: 100%|█████████████████████████| 1561/1561 [01:31<00:00, 17.04it/s]
# Done intersecting.

# %%
! python3 ../scripts/get_full_mutations_domains.py --domain none --variants_filename 100_verteb_all_TF_cds.bed
# Out:
# 1 O15062
# 2 Q86XF7
# 3 Q5XKR4
# 4 Q5TA89
# 5 O43623
# 6 O14978
# 7 Q8N587
# 8 P37231
# 9 Q86YP4
# 10 Q8IWY8
# 11 Q9UEG4
# 12 P19793
# 13 C9JLR9
# 14 Q16665
# 15 O75346
# 16 P10242
# 17 P16989
# 18 P10070
# 19 Q96MA1
# 20 Q96CK0
# 21 Q12800
# 22 Q96MM3
# 23 Q14938
# 24 Q6NSZ9
# 25 Q9NRM2
# 26 P0CI00
# 27 Q96DT7
# 28 Q96SZ4
# 29 P51449
# 30 Q499Z4
# 31 Q9BXG8
# 32 Q86UZ6
# 33 Q9BWX5
# 34 Q49AG3
# 35 Q14593
# 36 Q5TC79
# 37 O95935
# 38 O15266
# 39 Q9HBE1
# 40 P12524
# 41 Q96BR9
# 42 Q96LX8
# 43 Q6VB84
# 44 O14529
# 45 Q8NB50
# 46 Q86VE0
# 47 Q5SVQ8
# 48 Q8IW36
# 49 Q96N22
# 50 Q8WTV1
# 51 Q8N1W2
# 52 Q9P0T4
# 53 P61244
# 54 P52630
# 55 Q16600
# 56 Q96KM6
# 57 O14770
# 58 Q9UFW8
# 59 Q9UBR4
# 60 Q9BQW3
# 61 Q8TBC5
# 62 O14545
# 63 P15336
# 64 Q9UMN6
# 65 A8MTQ0
# 66 Q9UL49
# 67 Q2KHR2
# 68 Q9GZZ0
# 69 Q86WP2
# 70 Q9H4T2
# 71 P10827
# 72 Q9BU19
# 73 P58304
# 74 Q9UL40
# 75 P78367
# 76 O43670
# 77 A6NP11
# 78 Q6BEB4
# 79 P18847
# 80 Q15424
# 81 Q32MQ0
# 82 P11308
# 83 O15499
# 84 Q15047
# ...
